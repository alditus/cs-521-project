# %%
# import pandas library for data management
# import Stanford Core NLP for data analisys
            
import pandas as pd
from pycorenlp import StanfordCoreNLP
import numpy as np
import util
import importlib
import nlp_util
import preprocessing

#java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
#https://www.quora.com/What-is-the-most-use-of-features-for-text-classification-except-N-Gram-POS-and-Bag-of-Words

# %%
# Load all the files
tr_file, va_file, te_file = util.load_files()

# %%
tr_dict = util.tsv_to_dict(tsv_file=tr_file, columns=['Id','Label','Statement'])

# %%
tr_dict['statement'][0]
# Out:
# 'Says the Annies List political group supports third-trimester abortions on demand.'

# %%
from empath import Empath
lexicon = Empath()

# %%
lexicon.analyze("Says the Annies List political group supports third-trimester abortions on demand.", normalize=True)
# Out:
# {'help': 0.0,
#  'office': 0.0,
#  'dance': 0.0,
#  'money': 0.0,
#  'wedding': 0.0,
#  'domestic_work': 0.0,
#  'sleep': 0.0,
#  'medical_emergency': 0.0,
#  'cold': 0.0,
#  'hate': 0.0,
#  'cheerfulness': 0.0,
#  'aggression': 0.0,
#  'occupation': 0.0,
#  'envy': 0.0,
#  'anticipation': 0.0,
#  'family': 0.0,
#  'vacation': 0.0,
#  'crime': 0.0,
#  'attractive': 0.0,
#  'masculine': 0.0,
#  'prison': 0.0,
#  'health': 0.0,
#  'pride': 0.0,
#  'dispute': 0.0,
#  'nervousness': 0.0,
#  'government': 0.0,
#  'weakness': 0.0,
#  'horror': 0.0,
#  'swearing_terms': 0.0,
#  'leisure': 0.0,
#  'suffering': 0.0,
#  'royalty': 0.0,
#  'wealthy': 0.0,
#  'tourism': 0.0,
#  'furniture': 0.0,
#  'school': 0.0,
#  'magic': 0.0,
#  'beach': 0.0,
#  'journalism': 0.0,
#  'morning': 0.0,
#  'banking': 0.0,
#  'social_media': 0.0,
#  'exercise': 0.0,
#  'night': 0.0,
#  'kill': 0.0,
#  'blue_collar_job': 0.0,
#  'art': 0.0,
#  'ridicule': 0.0,
#  'play': 0.0,
#  'computer': 0.0,
# ...

# %%
lexicon.create_category("", ["deception"], model="nytimes", size=300)
# Out:
# ["deception", "deceit", "concealment", "dishonesty", "subterfuge", "deceptions", "lying", "duplicity", "falsehood", "illegality", "trickery", "lies", "obfuscation", "falsehoods", "chicanery", "entrapment", "manipulation", "criminality", "malice", "evasion", "ignorance", "treachery", "conspiracies", "blackmail", "cover-up", "recklessness", "stupidity", "misdeeds", "bad_judgment", "opportunism", "self-deception", "evasions", "incompetence", "mendacity", "true_nature", "coercion", "falsity", "misrepresentation", "cowardice", "hubris", "coverup", "willfully", "disinformation", "transgression", "reckless_disregard", "half-truths", "complicity", "disloyalty", "financial_gain", "manipulations", "greed", "innuendo", "exaggerations", "callousness", "fakery", "venality", "delusion", "vindictiveness", "culpability", "criminal_intent", "carelessness", "witch_hunt", "perversion", "personal_gain", "cheating", "malfeasance", "misbehavior", "supposition", "criminal_behavior", "illegal_activity", "ru
# ...
