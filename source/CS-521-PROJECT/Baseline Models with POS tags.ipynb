# %%
# pos tagging for fake news statement
## use pos-tagging to build features
import pandas as pd
import numpy as np
from pycorenlp import StanfordCoreNLP
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import re
import nltk

# import utility libraries
import util
import preprocessing
import importlib
import string

# libraries for model testing and selection
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import KFold
from sklearn import linear_model
from sklearn import metrics
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score
# Out:
# NLP_Task ready to use.
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\ensemble\weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from sklearn.ensemble import ExtraTreesClassifier

# %%
import nlp_util

# %%
importlib.reload(preprocessing)
# Out:
# NLP_Task ready to use.
# <module 'preprocessing' from 'D:\\UIC\\Fall 2018\\Statistical NLP\\Project\\jurat-aldo-project\\cs-521-project.git\\source\\CS-521-PROJECT\\preprocessing.py'>

# %% [markdown]
# # Load training files

# %%
# load files
tr_file, va_file, te_file = util.load_files()
tr_dict = util.tsv_to_dict(tsv_file=tr_file)
va_dict = util.tsv_to_dict(tsv_file=va_file)

# %% [markdown]
# # Preprocess data

# %%
## Data without punctuation
tr_data_no_punctuation = preprocessing.clean_text(sentences=tr_dict['statement'], remove_punctuation=True)
va_data_no_punctuation = preprocessing.clean_text(sentences=va_dict['statement'], remove_punctuation=True)

## Data without punctuation and uppercases
tr_data_no_punct_upper = preprocessing.clean_text(sentences=tr_dict['statement'], remove_punctuation=True, lower_case= True)
va_data_no_punct_upper = preprocessing.clean_text(sentences=va_dict['statement'], remove_punctuation=True, lower_case= True)

## Data without punctuation, uppercases and stopwords
tr_data_no_punct_upper_stopw = preprocessing.clean_text(sentences=tr_dict['statement'], remove_punctuation=True, lower_case=True, stop_words=True)
va_data_no_punct_upper_stopw = preprocessing.clean_text(sentences=va_dict['statement'], remove_punctuation=True, lower_case=True, stop_words=True)

# %% [markdown]
# # Extracting POS tags grouped by unigrams, bigrams and trigrams

# %%
# POS extracted for no preprocessed data
unigram_pos, bigrams_pos, trigram_pos = preprocessing.extract_POS(tr_dict['statement'])
unigram_pos_va, bigrams_pos_va, trigram_pos_va = preprocessing.extract_POS(statements=va_dict['statement'])

# POS without punctuation
unigram_pos_no_p, bigrams_pos_no_p, trigram_pos_no_p = preprocessing.extract_POS(tr_data_no_punctuation)
unigram_pos_no_p_va, bigrams_pos_no_p_va, trigram_pos_no_p_va = preprocessing.extract_POS(va_data_no_punctuation)

# POS withoutn punctuation and with lower case
unigram_pos_no_p_u, bigrams_pos_no_p_u, trigram_pos_no_p_u = preprocessing.extract_POS(tr_data_no_punct_upper)
unigram_pos_no_p_u_va, bigrams_pos_no_p_u_va, trigram_pos_no_p_u_va = preprocessing.extract_POS(va_data_no_punct_upper)

# POW without punctuation, lower case and with no stop words
unigram_pos_no_p_u_sw, bigrams_pos_no_p_u_sw, trigram_pos_no_p_u_sw = preprocessing.extract_POS(tr_data_no_punct_upper_stopw)
unigram_pos_no_p_u_sw_va, bigrams_pos_no_p_u_sw_va, trigram_pos_no_p_u_sw_va = preprocessing.extract_POS(va_data_no_punct_upper_stopw)
# Out:
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished
# Extracting POS Tags
# Finished

# %%
fivegrams_no_punct = nlp_task.POS_groupping(unigram_pos_no_p, grams=5)

# %%
fivegrams_no_punct_va = nlp_task.POS_groupping(unigram_pos_no_p_va, grams=5)

# %%
fivegrams_list_tr, five_gramcount = nlp_task.UniquePosTags(fivegrams_no_punct, return_counts=True)

# %%
filteredFivegrams = [(x) for x in five_gramcount if five_gramcount[x]>3]

# %%
importlib.reload(nlp_util)
nlp_task = nlp_util.NLP_Task()
# Out:
# NLP_Task ready to use.

# %%
# Unique POS by different preprocessing type of text
# Unigram of unclean data
unigram_list_tr = nlp_task.UniquePosTags(unigram_pos)
unigram_list_va = nlp_task.UniquePosTags(unigram_pos_va)

# Unigram of no punctuation data
unigram_list_tr_no_p = nlp_task.UniquePosTags(unigram_pos_no_p)
unigram_list_va_no_p = nlp_task.UniquePosTags(unigram_pos_no_p_va)

# Unigram of no punctuation and with lower case
unigram_list_tr_no_p_u = nlp_task.UniquePosTags(unigram_pos_no_p_u) 
unigram_list_va_no_p_u = nlp_task.UniquePosTags(unigram_pos_no_p_u_va)

# Unigram of no punctuation, without lower case and without stop words
unigram_list_tr_no_p_u_sw = nlp_task.UniquePosTags(unigram_pos_no_p_u_sw)
unigram_list_va_no_p_u_sw = nlp_task.UniquePosTags(unigram_pos_no_p_u_sw_va)

# %%
# Bigram POS by different preprocessing type of text
# Bigram of unclean data
bigram_list_tr = nlp_task.UniquePosTags(bigrams_pos)
bigram_list_va = nlp_task.UniquePosTags(bigrams_pos_va)

# Bigram of no punctuation data
bigram_list_tr_no_p = nlp_task.UniquePosTags(bigrams_pos_no_p)
bigram_list_va_no_p = nlp_task.UniquePosTags(bigrams_pos_no_p_va)

# Bigram of no punctuation and with lower case
bigram_list_tr_no_p_u = nlp_task.UniquePosTags(bigrams_pos_no_p_u) 
bigram_list_va_no_p_u = nlp_task.UniquePosTags(bigrams_pos_no_p_u_va)

# Bigram of no punctuation, without lower case and without stop words
bigram_list_tr_no_p_u_sw = nlp_task.UniquePosTags(bigrams_pos_no_p_u_sw)
bigram_list_va_no_p_u_sw = nlp_task.UniquePosTags(bigrams_pos_no_p_u_sw_va)

# %% [markdown]
# # Removing duplicated POS in bigrams
# ## RAW DATA

# %%
list_to_remove = unigram_list_tr#['NNP','CD']
removed_pos = nlp_task.RemoveConsecutiveTags(list_to_remove,unigram_pos)
removed_pos_bigrams = nlp_task.POS_groupping(grams=2,sentences_pos=removed_pos)

removed_pos_va =  nlp_task.RemoveConsecutiveTags(list_to_remove,unigram_pos_va)
removed_pos_bigrams_va = nlp_task.POS_groupping(grams=2,sentences_pos=removed_pos_va)

#LIST OF UNIQUE BIGRAMS AFTER REMOVING CONSECUTIVE SAME TAGS
removed_unique_bigrams = nlp_task.UniquePosTags(postags=removed_pos_bigrams)

# %%
removed_pos_va
# Out:
# [['<s>', 'PRP', 'VBP', 'RBR', 'NNPS', 'VBG', 'RB', 'IN', 'DT', 'NNS', '.'],
#  ['<s>',
#   'WRB',
#   'NNP',
#   'VBD',
#   'VBN',
#   'IN',
#   'NN',
#   ',',
#   'PRP',
#   'VBD',
#   'NNP',
#   'VB',
#   'DT',
#   'NNP',
#   ',',
#   'CC',
#   'RB',
#   'DT',
#   'NNP',
#   '-LRB-',
#   'PRP$',
#   'NN',
#   'TO',
#   'PRP$',
#   'NNP',
#   ',',
#   'CC',
#   'RB',
#   'JJ',
#   'NNS',
#   '-RRB-',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'VBG',
#   'NNS',
#   'VBG',
#   'IN',
#   'VBG',
#   'JJ',
#   'NN',
#   'NNS',
#   'CC',
#   'RB',
#   'VBG',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'TO',
#   'WRB',
#   'DT',
#   'NN',
#   'DT',
#   'CD',
#   'NNS',
#   'RB',
#   'VBD',
#   'IN',
#   'PRP',
#   'VBD',
#   'VBN',
#   '.'],
#  ['<s>', 'VBZ', 'RB', 'NN', 'IN', 'NNP', 'NNS', 'VBP', 'JJ', '.'],
#  ['<s>',
#   'IN',
#   'NNS',
#   'IN',
#   'NNS',
#   'WDT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBP',
#   'RB',
#   'JJ',
#   ',',
#   '``',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'RB',
#   ',',
#   'PRP',
#   'VBZ',
#   'IN',
#   'JJR',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'VBZ',
#   'WRB',
#   'VBN',
#   'NNS',
#   'VBP',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   ',',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'VBP',
#   ':',
#   'RB',
#   ',',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'VBP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'NNS',
#   'IN',
#   'NNS',
#   'TO',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'NNS',
#   'JJ',
#   'TO',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'WRB',
#   'NNS',
#   'VBP',
#   'VBN',
#   'TO',
#   'VB',
#   'IN',
#   'PRP$',
#   'NN',
#   'MD',
#   'VB',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'PRP$',
#   'NN',
#   'RB',
#   'IN',
#   'CD',
#   'VBG',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'NNS',
#   'IN',
#   'CD',
#   'IN',
#   'PRP$',
#   'NNS',
#   'TO',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'VBG',
#   'TO',
#   'VB',
#   'CC',
#   'RB',
#   'VB',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'VBD',
#   'IN',
#   'NNPS',
#   'VBZ',
#   'MD',
#   'VB',
#   'NNP',
#   'TO',
#   'VB',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'CD',
#   'NNP',
#   'NNS',
#   'VBD',
#   'NNS',
#   'IN',
#   'CD',
#   ',',
#   'CC',
#   'CD',
#   'IN',
#   'PRP',
#   'VBD',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>', 'NN', 'NNS', 'VBP', 'VBN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBD',
#   'RB',
#   '$',
#   'CD',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'TO',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'NNS',
#   'CC',
#   'NNS',
#   'TO',
#   'VB',
#   'NNS',
#   'WDT',
#   'VBP',
#   'RB',
#   'JJ',
#   'TO',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'VBG',
#   'NNP',
#   ',',
#   'VBG',
#   'NNP',
#   'CC',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'NNS',
#   'TO',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'VBN', 'NN', 'NNS', 'IN', 'CD', 'NN', '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'CD',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   'CC',
#   'VB',
#   'PRP',
#   'RB',
#   'TO',
#   'NNP',
#   '.'],
#  ['<s>',
#   'IN',
#   'PRP',
#   'VBP',
#   'VB',
#   'NNS',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   ',',
#   'PRP$',
#   'NN',
#   'VB',
#   'RP',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'DT',
#   'JJ',
#   'VBZ',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.',
#   '<s>',
#   'IN',
#   'VBN',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'RB',
#   'VBG',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'VBZ', 'VBN', 'IN', 'NN', 'MD', 'VB', 'DT', 'NN', '.'],
#  ['<s>', 'NNP', 'VBZ', 'VBN', 'NN', 'NNS', 'IN', 'DT', 'JJ', 'NN'],
#  ['<s>',
#   'NNP',
#   'IN',
#   'NNP',
#   'MD',
#   'VB',
#   'CD',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP$',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBD', 'RB', '$', 'CD', 'IN', 'NN', '.'],
#  ['<s>',
#   'IN',
#   'NNS',
#   'NN',
#   'CC',
#   'VB',
#   'JJR',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'RBR',
#   'IN',
#   'NNS',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'VBN',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'CD',
#   'JJR',
#   'NNS',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'TO',
#   'NNP',
#   'VBD',
#   'VBN',
#   'JJ',
#   'TO',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNS',
#   'CC',
#   'NN',
#   'JJR',
#   'IN',
#   'VBD',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'JJR',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBG',
#   'WRB',
#   'JJ',
#   'NNS',
#   '-LRB-',
#   'PRP',
#   'MD',
#   'VB',
#   '-RRB-',
#   'VBN',
#   'IN',
#   'DT',
#   ':',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>', 'NN', 'CD', 'VBZ', 'NNP', 'NNS', 'IN', 'NNS', 'CC', 'NNS', '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'CC',
#   'IN',
#   'DT',
#   'NNP',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'RBR',
#   'NNS',
#   'VBP',
#   'DT',
#   'NNP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NNS',
#   'VBP',
#   'DT',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'NNS',
#   'IN',
#   'JJR',
#   'NNS',
#   '.',
#   '<s>',
#   'CC',
#   'NNP',
#   'NN',
#   'VBZ',
#   'VBN',
#   'RP',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['<s>', 'VBZ', 'PRP', 'VBD', 'RB', 'VB', 'NNPS', 'MD', 'NN', '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   'NNS',
#   ',',
#   'DT',
#   'NN',
#   'VBZ',
#   'CD',
#   'NN',
#   ',',
#   'VBN',
#   'TO',
#   'RB',
#   'CD',
#   'NN',
#   ',',
#   'CD',
#   'NN',
#   ',',
#   'CD',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'VBD',
#   'RBR',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBD',
#   '.'],
#  ['<s>',
#   'IN',
#   'PRP$',
#   'NN',
#   ',',
#   'JJR',
#   'NNS',
#   'IN',
#   'NNP',
#   'VBP',
#   'NN',
#   'TO',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NNS',
#   'PRP',
#   'IN',
#   'NNS',
#   'PRP',
#   'VBD',
#   ',',
#   'IN',
#   ',',
#   'CD',
#   'NNS',
#   'RB',
#   ',',
#   '-LRB-',
#   'WRB',
#   '-RRB-',
#   'PRP',
#   'VBD',
#   'VBG',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NNPS',
#   'RB',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBG',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'VBN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'RB',
#   'VBD',
#   'DT',
#   'IN',
#   'NNP',
#   'DT',
#   'NN',
#   'TO',
#   'NNP',
#   '.'],
#  ['<s>', 'NNP', '``', 'VBD', '$', 'CD', 'IN', 'NNP', 'NN', '.', "''"],
#  ['<s>',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '$',
#   'CD',
#   'IN',
#   'NNP',
#   'JJ',
#   'NN',
#   ',',
#   'NNP',
#   'RB',
#   'VBZ',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBD', '$', 'CD', 'IN', 'NNP', 'NNS', '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'NNPS',
#   'VBP',
#   'VBN',
#   'IN',
#   'DT',
#   'VBG',
#   'NN',
#   ',',
#   'WDT',
#   'VBZ',
#   'RBR',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NNS',
#   'PRP',
#   'VBD',
#   ',',
#   'EX',
#   'VBP',
#   'RB',
#   'CD',
#   'NNPS',
#   'VBG',
#   'RB',
#   'WP',
#   'MD',
#   'RB',
#   'VB',
#   'JJ',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'CD',
#   ',',
#   'PRP',
#   'VBD',
#   'NNS',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'VBG',
#   'DT',
#   'NNP',
#   'TO',
#   'VB',
#   'DT',
#   'RBR',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'TO',
#   'VB',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   '$',
#   'CD',
#   'VBG',
#   'DT',
#   'NNP',
#   ',',
#   'NNP',
#   'VB',
#   'NN',
#   'VBG',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBD',
#   ':',
#   'VBG',
#   'CC',
#   'VBG',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NN',
#   '.',
#   '<s>',
#   'IN',
#   'NNP',
#   ',',
#   'TO',
#   'NNP',
#   ',',
#   'TO',
#   'NNP',
#   ',',
#   'JJ',
#   'VBN',
#   'TO',
#   'PRP$',
#   'NNS',
#   'TO',
#   'VB',
#   'NNS',
#   'RB',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   'IN',
#   'NNP',
#   'VBP',
#   'VBN',
#   'PRP$',
#   'NN',
#   'NNS',
#   'RB',
#   'CC',
#   'VBG',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'CC',
#   'NNP',
#   'IN',
#   'PRP$',
#   'NNS',
#   'VBG',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   ',',
#   'NNP',
#   'VBD',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'WP',
#   'VBD',
#   'DT',
#   'NN',
#   ',',
#   'VBD',
#   'NN',
#   ',',
#   'VBD',
#   'DT',
#   'NN',
#   ',',
#   'VBG',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBG',
#   'IN',
#   'NN',
#   'NNS',
#   ',',
#   'VBG',
#   'TO',
#   'VB',
#   'PRP',
#   'TO',
#   'VB',
#   'NNS',
#   'VB',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'NNP',
#   'VBD',
#   'IN',
#   'CD',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'NNS',
#   'MD',
#   'VB',
#   'NN',
#   'WP',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'EX',
#   'VBZ',
#   'VBN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'VBD',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'IN',
#   'NNP',
#   'NNS',
#   'VBP',
#   'VBN',
#   'NN',
#   'NNS',
#   'RB',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'RB',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NNP',
#   'VBZ',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   'TO',
#   'NNS',
#   'PRP',
#   'VBP',
#   'IN',
#   ':',
#   'NNS',
#   ',',
#   'NN',
#   'IN',
#   'NNS',
#   ',',
#   'RB',
#   'JJ',
#   'NN',
#   ':',
#   'DT',
#   'RB',
#   'NNP',
#   'MD',
#   'VB',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NN',
#   'VBD',
#   'DT',
#   'NNS',
#   'IN',
#   'NNP',
#   ',',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   ',',
#   'VB',
#   ',',
#   'CC',
#   'RB',
#   'NN',
#   'VBD',
#   'NNP',
#   ',',
#   'NNP',
#   'NNS',
#   'VBP',
#   '.'],
#  ['<s>', 'DT', 'NN', 'IN', 'DT', 'NN', 'VBZ', 'IN', 'DT', 'JJ', '.'],
#  ['<s>',
#   'VBZ',
#   'NN',
#   'NNP',
#   'VBZ',
#   'PRP',
#   'VBZ',
#   'NNP',
#   'RB',
#   'CC',
#   'VBZ',
#   'TO',
#   'VB',
#   'PRP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NNS',
#   'VBP',
#   'DT',
#   'JJ',
#   'JJS',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'DT', 'JJ', 'NN'],
#  ['<s>',
#   'RB',
#   ',',
#   'NNPS',
#   'VBD',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP$',
#   'NN',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   '.',
#   '<s>',
#   'CD',
#   'NN',
#   'RB',
#   'PRP',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'PRP$',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'RB',
#   'VBD',
#   'JJ',
#   'NN',
#   'IN',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'NNP',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'WRB',
#   'NNPS',
#   'VBD',
#   'NNP',
#   'CC',
#   'DT',
#   'NNP',
#   ',',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'VBD',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   'NN',
#   'IN',
#   'CD',
#   ':',
#   'DT',
#   'JJS',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'JJS',
#   'NN',
#   'VBZ',
#   'WP',
#   'NNPS',
#   'VBP',
#   'VBN',
#   'VBG',
#   'IN',
#   'NNS',
#   'RB',
#   '.',
#   '<s>',
#   'IN',
#   'NNP',
#   ',',
#   'NNS',
#   'IN',
#   'VBG',
#   'NNS',
#   'MD',
#   'VB',
#   'PRP$',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'VBZ',
#   'CD',
#   'NNS',
#   'WP',
#   'VBP',
#   'VBG',
#   'WP',
#   'NNS',
#   'VBP',
#   'JJ',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'VBD', 'NNS', 'CC', 'NNS', 'IN', 'JJ', 'NNS', '.'],
#  ['<s>', 'VBG', 'NN', 'TO', 'NN', 'VBZ', 'NN', 'NNS', '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'RB',
#   'VBD',
#   'NNP',
#   'NN',
#   'CC',
#   'RB',
#   'VBZ',
#   'PRP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'VBZ',
#   'NN',
#   'NNS',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'NNS',
#   'JJ',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'CC',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'WP',
#   'VBD',
#   'VBG',
#   'DT',
#   'NN',
#   ',',
#   'IN',
#   'DT',
#   'NNP',
#   'NNS',
#   ',',
#   'VBD',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'IN',
#   'VBD',
#   'JJ',
#   'NNS',
#   'IN',
#   '.',
#   '<s>',
#   'PRP',
#   'RB',
#   'VB',
#   'DT',
#   ',',
#   'NN',
#   'VBN',
#   'PRP',
#   ',',
#   'CC',
#   'NN',
#   'VBP',
#   'PRP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'MD',
#   'VB',
#   'RB',
#   'JJ',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   ':',
#   'CC',
#   'PRP',
#   'VBP',
#   'VB',
#   'PRP',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'NN', 'VBN', 'DT', 'JJ', 'NN', 'VBN', 'IN', 'NNS', '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'JJR',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBP',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'VBG',
#   'PRP$',
#   'JJ',
#   'NNS',
#   'IN',
#   'VBG',
#   'PRP',
#   'IN',
#   'CD',
#   'VBG',
#   'NNS',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'DT', 'NNP', 'NN', '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NN',
#   'CC',
#   'NNP',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   '.'],
#  ['<s>', 'NNP', 'MD', 'VB', 'NN', ':', 'PRP', 'VBZ', 'CD', 'NNS', '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'WRB',
#   'PRP',
#   'VBZ',
#   'PRP',
#   'VBP',
#   'TO',
#   'VB',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'PRP$', 'NN', 'VBZ', '``', 'JJ', '.', "''"],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'TO',
#   'VB',
#   'NNP',
#   ',',
#   'VBG',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NN',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP'],
#  ['<s>',
#   'IN',
#   'PRP',
#   'JJ',
#   'VBN',
#   'IN',
#   'NNP',
#   ',',
#   'RB',
#   'CD',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'JJR',
#   'NNS',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'NNP',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'NNS',
#   'CC',
#   'VBZ',
#   '.'],
#  ['<s>',
#   'CD',
#   'NN',
#   'IN',
#   'VBG',
#   'NNS',
#   'IN',
#   'CD',
#   'VBD',
#   'JJR',
#   'NN',
#   'IN',
#   'PRP$',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'CC',
#   'NNP',
#   'VBP',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'VBP',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBD', 'IN', 'DT', 'NN', 'CC', 'VBD', 'IN', 'NNP', '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   'IN',
#   'NNS',
#   'DT',
#   'NN',
#   ',',
#   'VBG',
#   'PRP',
#   'JJR',
#   'IN',
#   'DT',
#   'CC',
#   'CD',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   '``',
#   'VBD',
#   '$',
#   'CD',
#   'IN',
#   'NNP',
#   'IN',
#   'DT',
#   'NN',
#   'WRB',
#   'PRP',
#   'VBD',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'WDT',
#   'VBP',
#   'DT',
#   'RBS',
#   'TO',
#   'NNP',
#   ',',
#   'JJ',
#   'IN',
#   'VBG',
#   'DT',
#   'NNS',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'NNP',
#   'VBD',
#   'VBG',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'RB',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'NNP',
#   'MD',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'VBG',
#   'VBN',
#   'CD',
#   'NN',
#   'TO',
#   'VB',
#   'NNP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'WP',
#   'VBZ',
#   'VBN',
#   'RP',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'WP',
#   'PRP',
#   'MD',
#   'VB',
#   'TO',
#   'VB',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   'IN',
#   'NNP',
#   '.',
#   '<s>',
#   'DT',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'RB',
#   'VBD',
#   'PRP',
#   'VBZ',
#   'NN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'TO',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   ',',
#   'NN',
#   'NNS',
#   ',',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'IN',
#   'NNP',
#   'CD',
#   'CC',
#   'CD',
#   'NNP',
#   'NNS',
#   'VBP',
#   'RB',
#   'VBN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'MD',
#   'RB',
#   'VB',
#   '-LRB-',
#   'NNP',
#   'NNPS',
#   '-RRB-',
#   'NN',
#   'IN',
#   'PRP',
#   'VBD',
#   'VBG',
#   'PRP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'NNS',
#   'RB',
#   'DT',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   'VBD',
#   'RB',
#   'DT',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'PRP',
#   ',',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNPS',
#   'RB',
#   'VBD',
#   'TO',
#   'DT',
#   'NN',
#   'WDT',
#   'NNPS',
#   'VBD',
#   ',',
#   'IN',
#   'NNP',
#   'VBD',
#   'MD',
#   'VB',
#   'DT',
#   'VB',
#   '.'],
#  ['<s>',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   'NN',
#   'VBZ',
#   'VBG',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '-LRB-',
#   'IN',
#   'NN',
#   '-RRB-',
#   'VBD',
#   'IN',
#   'RB',
#   'VBZ',
#   'PRP',
#   'JJ',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'PRP',
#   'VBP',
#   'PRP',
#   'VBP',
#   'PRP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   ',',
#   'PRP',
#   'VBP',
#   'VBG',
#   'DT',
#   'IN',
#   'DT',
#   'RBS',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NNS',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NNP',
#   'NN',
#   ',',
#   'DT',
#   '``',
#   'NN',
#   ',',
#   "''",
#   'DT',
#   '``',
#   'NNP',
#   ',',
#   "''",
#   'CC',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'DT',
#   'NNP',
#   'TO',
#   'VB',
#   'NNP',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJ',
#   'NNS',
#   'MD',
#   'VB',
#   'VBN',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'JJ',
#   'CC',
#   'JJ',
#   '``',
#   'JJ',
#   'NN',
#   "''",
#   'NN',
#   ',',
#   'DT',
#   'NNP',
#   'NN',
#   'VBZ',
#   'VBN',
#   'NNP',
#   'NNS',
#   'TO',
#   '``',
#   'VB',
#   'NNP',
#   'NNPS',
#   'TO',
#   'JJ',
#   'NNS',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'RB',
#   'JJ',
#   'NN',
#   'IN',
#   'PRP',
#   'CC',
#   'PRP$',
#   'NN',
#   'MD',
#   'VB',
#   'TO',
#   'NNP',
#   'TO',
#   'NNP',
#   'CC',
#   'RB',
#   'CC',
#   'VB',
#   'VBN',
#   'RP',
#   'IN',
#   'DT',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'VBD',
#   'IN',
#   'NN',
#   'JJ',
#   'NN',
#   ',',
#   'PRP',
#   'VBD',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'WRB',
#   'PRP',
#   'VBD',
#   'NN',
#   ',',
#   'RB',
#   'VBD',
#   'NN',
#   'NNS',
#   'VBP',
#   'PRP',
#   'RB',
#   'VBD',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'RB',
#   'CD',
#   'NN',
#   'JJ',
#   'CC',
#   '-LRB-',
#   'DT',
#   'NNP',
#   'NN',
#   '-RRB-',
#   'VBD',
#   'PRP$',
#   'NN',
#   'TO',
#   'CD',
#   'NN',
#   'IN',
#   'VBN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'VBD',
#   '-LRB-',
#   'DT',
#   'NN',
#   '-RRB-',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'CD',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBD',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'VBD',
#   'JJ',
#   ',',
#   'RB',
#   'IN',
#   'PRP',
#   'VBD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'JJ',
#   'NNS',
#   'VBG',
#   'NNP',
#   'IN',
#   'NNS',
#   'CC',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'TO',
#   'VB',
#   'NNS',
#   'IN',
#   'JJ',
#   'NNS',
#   'RB',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'VBG',
#   'PRP$',
#   'NN',
#   'VBN',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'CD',
#   'VBG',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   '-LRB-',
#   'NNP',
#   'IN',
#   'NNP',
#   '-RRB-',
#   'VBP',
#   'VBN',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   'IN',
#   'DT',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'VBZ',
#   'RB',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'DT',
#   'RB',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'IN',
#   'NNP',
#   'NN',
#   'IN',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NNP',
#   'IN',
#   'NN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   '.',
#   '<s>',
#   'EX',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'NNS',
#   'VBG',
#   'TO',
#   'VB',
#   'RB',
#   'TO',
#   'VBG',
#   'DT',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   ',',
#   'PRP',
#   'VBD',
#   ',',
#   'VBN',
#   ',',
#   'CC',
#   ',',
#   'IN',
#   'DT',
#   'NNS',
#   ',',
#   'VBN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   'WDT',
#   'VBD',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NN',
#   'NNS',
#   'WDT',
#   'VBP',
#   'DT',
#   'JJ',
#   'CC',
#   'JJ',
#   '.'],
#  ['<s>',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NN',
#   '.',
#   '<s>',
#   'PRP$',
#   'NN',
#   'VBN',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'NN',
#   'WDT',
#   'VBD',
#   'VBN',
#   'IN',
#   'NNP',
#   'CC',
#   'VBN',
#   ',',
#   'VBD',
#   'VBN',
#   'IN',
#   'NNP',
#   ',',
#   'RB',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   '``',
#   'VBD',
#   'PRP',
#   'VBD',
#   '``',
#   'VBN',
#   "''",
#   'WRB',
#   'VBD',
#   'IN',
#   'NNS',
#   'VBP',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'VBZ',
#   'RBS',
#   'NNP',
#   'NNS',
#   'VBP',
#   'CD',
#   'IN',
#   'CD',
#   'NN',
#   'NNS',
#   'IN',
#   'VBN',
#   'NN',
#   '.'],
#  ['<s>',
#   'VB',
#   'PRP',
#   'WP',
#   'NNP',
#   'NN',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   '.',
#   '<s>',
#   'PRP',
#   'VBP',
#   'VB',
#   'VBN',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP',
#   '.'],
#  ['<s>', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['<s>', 'PRP', 'VBD', 'DT', 'JJ', 'NN', 'VBG', 'IN', 'NNP', '.'],
#  ['<s>',
#   'VBZ',
#   'NN',
#   'VBG',
#   'IN',
#   'DT',
#   'NNP',
#   'MD',
#   'RB',
#   'VB',
#   'CC',
#   'VB',
#   'JJ',
#   'IN',
#   'NNS',
#   'WP',
#   'VBP',
#   'RB',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NNS',
#   'MD',
#   'RB',
#   'VB',
#   'VBG',
#   'NN',
#   'IN',
#   'NNS',
#   'WDT',
#   'VBP',
#   'IN',
#   'DT',
#   'NN',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'RB',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'DT',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'NNS',
#   'DT',
#   'NN',
#   'CC',
#   'VBZ',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   'NNS',
#   'IN',
#   'RB',
#   'TO',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'EX',
#   'VBP',
#   'VBN',
#   'CD',
#   'NNS',
#   'VBD',
#   'CC',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   '.',
#   '<s>',
#   'CD',
#   'VBP',
#   'VBG',
#   'DT',
#   'NN',
#   'RB',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   'NNS',
#   'MD',
#   'VB',
#   'VBG',
#   'TO',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'IN',
#   'CD',
#   'CC',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'MD',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   'NN',
#   '.',
#   '<s>',
#   'NNS',
#   'VBP',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'RB',
#   'VBG',
#   'VBN',
#   'RB',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NN',
#   'IN',
#   'NNS',
#   'TO',
#   'DT',
#   'NNP',
#   'NN',
#   'NNP',
#   'MD',
#   'VB',
#   '$',
#   'CD',
#   'TO',
#   'VB',
#   '.'],
#  ['<s>',
#   'NNPS',
#   'VBP',
#   'RB',
#   'JJR',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'IN',
#   'DT',
#   'NN',
#   'VBD',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   '.',
#   '<s>',
#   ':',
#   'PRP',
#   'VBZ',
#   'VBN',
#   'PRP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'PRP',
#   '.',
#   '<s>',
#   'DT',
#   'VBP',
#   'PRP$',
#   'NNS',
#   ',',
#   'RB',
#   'NN',
#   '.',
#   '<s>',
#   'IN',
#   'PRP',
#   'VBP',
#   'VB',
#   'WRB',
#   'PRP',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'JJ',
#   'NNP',
#   'NN',
#   'NNS',
#   'VBP',
#   'CD',
#   'NNS',
#   'IN',
#   '-LRB-',
#   'NNS',
#   'IN',
#   '-RRB-',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   '.',
#   '<s>',
#   'NNP',
#   'VBZ',
#   'NNS',
#   'TO',
#   'VB',
#   'NNS',
#   'IN',
#   'VBG',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'NNS',
#   'VBZ',
#   'NN',
#   'TO',
#   'VB',
#   'NNS',
#   'CC',
#   'NN',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NN',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'IN',
#   'NNS',
#   'NN',
#   'IN',
#   'PRP',
#   'VBD',
#   'PRP',
#   'RP',
#   'IN',
#   'PRP$',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'NN',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   '.',
#   '<s>',
#   'CD',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   '.',
#   '<s>',
#   'CD',
#   'NN',
#   'VBD',
#   'RB',
#   'VB',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>', 'PRP', 'RB', 'VBD', 'DT', 'JJ', 'NNP', '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   'WP',
#   'VBP',
#   'IN',
#   'CD',
#   'TO',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'VB',
#   'PRP$',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'CD',
#   'VBP',
#   'IN',
#   'VBG',
#   'NN',
#   'TO',
#   'VB',
#   'NNP',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'JJ',
#   'IN',
#   'JJ',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NNS',
#   'VBP',
#   'VBN',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'NN',
#   'VBZ',
#   'JJ',
#   'NN',
#   ':',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'RB',
#   'VB',
#   'IN',
#   'CD',
#   ',',
#   'PRP$',
#   'VBN',
#   'RB',
#   'TO',
#   'VB',
#   'IN',
#   'VBG',
#   '.'],
#  ['<s>',
#   'RB',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'VBP',
#   'VBG',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'JJ',
#   'IN',
#   'DT',
#   'NNS',
#   'TO',
#   'VB',
#   'DT',
#   'NNP',
#   'NNPS',
#   'VBN',
#   'IN',
#   'PRP$',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   ',',
#   'NNS',
#   'VBP',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'CC',
#   'NNS',
#   ',',
#   'VBN',
#   'TO',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   ',',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'NN',
#   'NNS',
#   'IN',
#   'CD',
#   'JJ',
#   'NNS',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'DT',
#   'NNP',
#   'IN',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>', 'VB', 'NNP', 'VBZ', 'VBG', 'NNS', 'IN', 'NN', '.'],
#  ['<s>', 'IN', 'JJ', 'NN', '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBG',
#   'JJ',
#   'NN',
#   'RB',
#   'VBZ',
#   'JJR',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'NNS',
#   'WDT',
#   'JJ',
#   'NNS',
#   'MD',
#   'RB',
#   'VB',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   'CC',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'PRP$',
#   'RB',
#   'JJ',
#   'IN',
#   'DT',
#   'NNP',
#   'NNS',
#   'TO',
#   'VB',
#   'NNPS',
#   'NNS',
#   ',',
#   'RB',
#   'VBN',
#   'TO',
#   'VB',
#   'JJ',
#   'NNS',
#   ',',
#   'RB',
#   'PRP',
#   'VBD',
#   'DT',
#   'NN',
#   'VBD',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNP',
#   ',',
#   'NNP',
#   'CC',
#   'NNP',
#   'VBD',
#   'NNS',
#   'IN',
#   'NNP',
#   'PRP',
#   'RB',
#   'JJ',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   'JJS',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'IN',
#   'NNPS',
#   'WP',
#   'RB',
#   'VBP',
#   'NNS',
#   'IN',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'NNS',
#   'NN',
#   'VBZ',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'IN',
#   'CD',
#   'VBD',
#   'RB',
#   'JJR',
#   'NNS',
#   'TO',
#   'DT',
#   'NNP',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   'NNS',
#   'VBD',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'JJ', 'VBP', 'TO', 'NNP', 'IN', 'VBG', 'NNS'],
#  ['<s>', 'PRP', 'RB', 'VBD', 'DT', 'NN', 'IN', 'NNP', '.'],
#  ['<s>',
#   'IN',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'RB',
#   'DT',
#   'JJ',
#   'NNS',
#   ',',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBN',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NNPS',
#   'NN',
#   'RB',
#   'VBD',
#   'IN',
#   'CD',
#   'JJ',
#   'NNS',
#   ',',
#   'VBG',
#   'DT',
#   'NN',
#   'RB',
#   'VBG',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'RB',
#   'WRB',
#   'IN',
#   'CD',
#   'NNS',
#   ',',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'NN',
#   'VBD',
#   'NNS',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   '.',
#   '<s>',
#   'NNP',
#   'VBD',
#   'NNS',
#   'VBG',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBG',
#   'NN',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'RB',
#   'IN',
#   '$',
#   'CD',
#   '-LRB-',
#   'CD',
#   '-RRB-',
#   'TO',
#   '$',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'EX',
#   'VBP',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'IN',
#   'NNP',
#   'NN',
#   'NNS',
#   'CC',
#   'JJ',
#   'NNS',
#   'CC',
#   'NNS',
#   'RB',
#   'IN',
#   'VBN',
#   'NNS',
#   'VBG',
#   'PRP$',
#   'NNS',
#   'IN',
#   'NNS',
#   'VBG',
#   'VBN',
#   'IN',
#   'NN',
#   'NNS',
#   'CC',
#   'NNS',
#   '.'],
#  ['<s>', 'DT', 'NNP', 'NN', 'VBZ', 'RB', 'JJ', 'IN', 'NN', 'NNS', '.'],
#  ['<s>', 'DT', 'NNP', 'NN', 'RB', 'VBD', 'DT', 'JJ', 'NN', '.'],
#  ['<s>', 'NNP', 'MD', 'VB', 'NNS', 'NN', 'IN', 'NN', 'IN', 'DT', 'NN'],
#  ['<s>',
#   'CD',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'RB',
#   ',',
#   'VBP',
#   'VBG',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'DT',
#   '$',
#   'CD',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNS',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'MD',
#   'VB',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   'NNPS',
#   'VBZ',
#   'RB',
#   'JJR',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'CC',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBZ',
#   'RB',
#   'JJ',
#   '.'],
#  ['<s>',
#   'WRB',
#   'NNP',
#   'NNS',
#   'NN',
#   'NNP',
#   'VBD',
#   'IN',
#   'NNP',
#   'VBD',
#   'CD',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NNS',
#   ',',
#   'RB',
#   'NNP',
#   'VBD',
#   'IN',
#   'RB',
#   '.'],
#  ['<s>', 'VBZ', 'RB', 'CD', 'NNPS', 'VBP', 'VBN', 'IN', 'NN', 'IN', 'CD', '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   'IN',
#   'NNS',
#   'NN',
#   'VBZ',
#   'DT',
#   '$',
#   'CD',
#   'JJ',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   'VBZ',
#   'CD',
#   ',',
#   'PRP',
#   'MD',
#   'VB',
#   'CD',
#   '.'],
#  ['<s>',
#   'PRP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'RP',
#   'IN',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   'RB',
#   ':',
#   'NNP',
#   'VBD',
#   'PRP',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NN',
#   ',',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'RB',
#   'VBN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'RB',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   ',',
#   'PRP$',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'CD',
#   'NN',
#   'CC',
#   'PRP',
#   'RB',
#   'VBP',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'CC',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   '.',
#   '<s>',
#   'NN',
#   'IN',
#   'DT',
#   '$',
#   'CD',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'VBN',
#   'NN',
#   'IN',
#   'NN',
#   'RB',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'DT',
#   'CD',
#   'WDT',
#   'VBD',
#   'JJ',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBG',
#   'DT',
#   'NN',
#   '-LRB-',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'NNS',
#   '-RRB-',
#   ',',
#   'RB',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   ',',
#   'CD',
#   'IN',
#   'NNP',
#   'POS',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   'VBZ',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'VBN',
#   'IN',
#   'DT',
#   'JJ',
#   '.',
#   '<s>',
#   'RB',
#   'VB',
#   'RP',
#   'IN',
#   'PRP',
#   'VBP',
#   'JJ',
#   '.'],
#  ['<s>', 'IN', 'NN', 'NNS', 'MD', 'VB', 'TO', 'PRP$', 'NNS', '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   '.',
#   '<s>',
#   'PRP',
#   'VBD',
#   'RP',
#   'PRP$',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'PRP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   ',',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'VBD',
#   'IN',
#   'NN',
#   'VBD',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBG',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'VB',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'VBD',
#   'JJ',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   '.',
#   '<s>',
#   'PRP',
#   'VBD',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'TO',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   ',',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'IN',
#   'WP',
#   'PRP',
#   'VBZ',
#   'TO',
#   'VB',
#   'JJ',
#   'NN',
#   ',',
#   'NN',
#   ',',
#   'CC',
#   'NN',
#   ':',
#   'IN',
#   'VBG',
#   'NNS',
#   ',',
#   'IN',
#   'VBG',
#   'RB',
#   ':',
#   '.'],
#  ['<s>',
#   'DT',
#   'RB',
#   'NN',
#   'VBG',
#   'RP',
#   'CD',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'VBZ',
#   'RB',
#   'CC',
#   'VBG',
#   'PRP',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   ',',
#   'PRP',
#   'VBD',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP',
#   'RP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBD',
#   'RP',
#   'PRP$',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBD',
#   'JJR',
#   'IN',
#   'DT',
#   'CD',
#   'PRP',
#   'VBD',
#   'IN',
#   '.'],
#  ['<s>', 'DT', 'NNS', 'NN', 'VBD', 'IN', 'NNP', 'RB', 'VBD', 'IN', 'NNP', '.'],
#  ['<s>',
#   'NN',
#   'VBZ',
#   'DT',
#   '$',
#   'CD',
#   'NN',
#   'DT',
#   'NNP',
#   'MD',
#   'VB',
#   'VBG',
#   '-LRB-',
#   'IN',
#   'CD',
#   '-RRB-',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'IN',
#   'DT',
#   'VBN',
#   'NNS',
#   'VBN',
#   'IN',
#   'VBG',
#   'NN',
#   'TO',
#   'DT',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'CD',
#   'NNS',
#   'IN',
#   ':',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBD',
#   'RB',
#   'JJ',
#   '.',
#   '<s>',
#   'NN',
#   ',',
#   'RB',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'NNP',
#   'NNS',
#   'IN',
#   'NNP',
#   'VBP',
#   'VBN',
#   'IN',
#   'NNS',
#   'CC',
#   'JJ',
#   'TO',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>',
#   'WRB',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   '$',
#   'CD',
#   ',',
#   'PRP',
#   'VBZ',
#   'DT',
#   'NNP',
#   'NN',
#   'MD',
#   'VB',
#   'CD',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'CC',
#   'DT',
#   'VBZ',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'VBG',
#   'NNP',
#   '.'],
#  ['<s>',
#   'JJS',
#   'NNPS',
#   'VBP',
#   'JJ',
#   'TO',
#   'VB',
#   'PRP',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'IN',
#   'PRP',
#   'CC',
#   'VB',
#   'IN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'NNP',
#   'IN',
#   'NNP',
#   'VB',
#   'RP',
#   'NNPS',
#   'NN',
#   'TO',
#   'PRP',
#   'IN',
#   'VBN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'VBZ',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   'TO',
#   'VB',
#   'CC',
#   'VB',
#   'NN',
#   'NNS',
#   'WDT',
#   'VBP',
#   'JJ',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'RB',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBD',
#   'JJ',
#   'NNS',
#   'CC',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'NNP',
#   '``',
#   'IN',
#   'DT',
#   '$',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'VBG',
#   'CC',
#   'VBG',
#   'NN',
#   'NNS',
#   'VBG',
#   'TO',
#   'VB',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>', 'DT', 'NNP', 'JJ', 'NN', 'IN', 'NN', 'VBZ', 'IN', 'NN', '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   ',',
#   'WRB',
#   'PRP',
#   'VBZ',
#   'TO',
#   'NN',
#   ',',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>', 'PRP', 'RB', 'VBD', 'JJ', 'NNS', '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'NNP',
#   'VBZ',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBN',
#   'DT',
#   'JJ',
#   'NNS',
#   'RB',
#   'VBD',
#   'CD',
#   'NN',
#   'CC',
#   'JJR',
#   'IN',
#   'DT',
#   'NNP',
#   'CD',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBD', 'JJ', 'NNS', 'TO', 'NNS', '.'],
#  ['<s>',
#   'RB',
#   'NN',
#   'VBZ',
#   'TO',
#   'VB',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   '.',
#   '<s>',
#   'NNS',
#   'WRB',
#   'PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'IN',
#   'NN',
#   'VBZ',
#   'DT',
#   'NN',
#   ',',
#   'VBN',
#   'IN',
#   'DT',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'NNS',
#   'VBP',
#   'NNP',
#   'MD',
#   'VB',
#   'JJR',
#   'IN',
#   'NNP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBG',
#   'DT',
#   'NN',
#   'TO',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'WDT',
#   'NN',
#   ',',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'VBZ',
#   'PRP',
#   'VB',
#   '.',
#   '<s>',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   'WDT',
#   'VBD',
#   'IN',
#   'PRP$',
#   'NN',
#   'CC',
#   'VBD',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'VBG',
#   'DT',
#   'RB',
#   'JJ',
#   'NN',
#   ',',
#   'WRB',
#   'NN',
#   'PRP',
#   'RB',
#   'VB',
#   'RP',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'DT',
#   'NNS',
#   '-LRB-',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '-RRB-',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'VBN', 'DT', 'NN', 'PRP', 'VBD', 'IN', 'DT', 'NN', '.'],
#  ['<s>', 'NNS', 'VBD', 'DT', 'JJS', 'IN', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['<s>',
#   'JJR',
#   'NNS',
#   'RB',
#   'VBP',
#   'IN',
#   'NNP',
#   'IN',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   ',',
#   'NNS',
#   'IN',
#   'NNP',
#   'NNS',
#   'RB',
#   'VBP',
#   'NN',
#   'CC',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   'MD',
#   'VB',
#   'NNP',
#   'NN',
#   'IN',
#   'NN',
#   ',',
#   'JJ',
#   'NNS',
#   ',',
#   'CC',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'NNS',
#   'RB',
#   ':',
#   'NNS',
#   ',',
#   'NNS',
#   ',',
#   'NN',
#   'NNS',
#   ',',
#   'JJ',
#   'NNS',
#   ',',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'POS',
#   'CD',
#   'NN',
#   'VBD',
#   '``',
#   'NN',
#   'TO',
#   'VB',
#   '``',
#   'JJ',
#   'NN',
#   "''",
#   'TO',
#   'NNS',
#   '.',
#   "''"],
#  ['<s>',
#   'VBG',
#   'NNPS',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'CC',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'VBZ',
#   'RB',
#   'WP',
#   'DT',
#   'NNPS',
#   'POS',
#   'NN',
#   'MD',
#   'VB',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   ',',
#   'DT',
#   'NNPS',
#   'VBD',
#   'DT',
#   'NNP',
#   'TO',
#   'DT',
#   'NNP',
#   'IN',
#   '``',
#   'JJ',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'NNPS',
#   'VBD',
#   'JJ',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'NNS',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'NNP',
#   'VBD',
#   'NN',
#   '.'],
#  ['<s>',
#   'RB',
#   'VB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'VBN',
#   'CD',
#   'NN',
#   'IN',
#   'VBG',
#   '.'],
#  ['<s>',
#   'RB',
#   'CD',
#   'NNS',
#   ',',
#   'VBG',
#   'NNP',
#   ',',
#   'VBP',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'NNS',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'WDT',
#   'MD',
#   'VB',
#   'VBN',
#   'DT',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'WDT',
#   'VBZ',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'NN',
#   'MD',
#   'VB',
#   'NNS',
#   'VBN',
#   'NN',
#   'IN',
#   'NNP',
#   'NNS',
#   'CC',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'DT',
#   'NNS',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'VBG',
#   'NNS',
#   'IN',
#   'NNP',
#   ',',
#   'CC',
#   'RB',
#   'PRP',
#   'VBZ',
#   'DT',
#   '``',
#   'JJ',
#   'NN',
#   "''",
#   'RB',
#   'IN',
#   '``',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   "''",
#   'CC',
#   '``',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   ',',
#   "''",
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'WRB',
#   'NNP',
#   'VBD',
#   'NN',
#   ',',
#   'NNP',
#   'VBD',
#   'CD',
#   'NN',
#   'NNS',
#   ',',
#   'DT',
#   'NN',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'VBD',
#   'TO',
#   'VB',
#   'IN',
#   'NN',
#   ',',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'RB',
#   'DT',
#   'JJ',
#   'NNP',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   'TO',
#   'VB',
#   'NNP',
#   'RB',
#   'IN',
#   'JJR',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'TO',
#   'NNS',
#   'VBG',
#   'NNS',
#   'IN',
#   'NNP',
#   'JJ',
#   'NNP',
#   'CC',
#   'NNPS',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'JJR',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NNP',
#   '.',
#   '<s>',
#   'VBZ',
#   '``',
#   'VBN',
#   'VBG',
#   'RP',
#   'IN',
#   'NNS',
#   '.',
#   "''"],
#  ['<s>',
#   'DT',
#   'NNP',
#   'NN',
#   'POS',
#   'JJS',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'CD',
#   'VBP',
#   '``',
#   'RBR',
#   'CC',
#   'RBR',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'CD',
#   'NNS',
#   'RB',
#   '.',
#   "''"],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'RB',
#   'VBN',
#   'JJ',
#   'IN',
#   'VBG',
#   'NNS',
#   '-LRB-',
#   'CC',
#   'VBP',
#   '-RRB-',
#   'DT',
#   'NN',
#   'IN',
#   'VBG',
#   'IN',
#   'NN',
#   '.',
#   '<s>',
#   ':',
#   'NNP',
#   '-LRB-',
#   'VBZ',
#   '-RRB-',
#   'CD',
#   'IN',
#   'DT',
#   'JJR',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'TO', 'VB', 'NNP', 'IN', 'DT', 'NN', 'IN', 'NNP', '.'],
#  ['<s>', 'PRP', 'VBD', 'DT', 'NN', '.'],
#  ['<s>',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'VBG',
#   'IN',
#   'VBG',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   ',',
#   'IN',
#   'DT',
#   '$',
#   'CD',
#   'JJ',
#   'NN',
#   ',',
#   'PRP',
#   'VBP',
#   'VBG',
#   'RBR',
#   'IN',
#   'NN',
#   ',',
#   'RB',
#   'CD',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'CD',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'PRP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NNP',
#   '.',
#   '<s>',
#   'NNPS',
#   'VBD',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>', 'PRP', 'VBP', 'CD', 'JJ', 'NNS', 'IN', 'CD', 'IN', 'DT', 'NNP', '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   ',',
#   'PRP$',
#   'NNS',
#   'IN',
#   'VBG',
#   'VBP',
#   'VBG',
#   'TO',
#   'VB',
#   'RP',
#   'IN',
#   'CD',
#   'NN',
#   '.',
#   '<s>',
#   'NNP',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'CD',
#   'NN',
#   'RBR',
#   'JJ',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NN',
#   'JJ',
#   'IN',
#   'CD',
#   'IN',
#   'PRP$',
#   'NNS',
#   'VBD',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'JJ',
#   'NNP',
#   '.'],
#  ['<s>',
#   'PRP',
#   'RB',
#   'VBP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'PRP',
#   'VBD',
#   'RP',
#   'IN',
#   '.'],
#  ['<s>',
#   'NN',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'PRP',
#   'VBD',
#   'PRP$',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'CC',
#   'DT',
#   'NN',
#   'VBZ',
#   'VBN',
#   'PRP',
#   'IN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'JJ',
#   'NNS',
#   'IN',
#   'CD',
#   ',',
#   'RB',
#   'NNS',
#   ',',
#   'RB',
#   'VBD',
#   'TO',
#   'VB',
#   ',',
#   'IN',
#   'DT',
#   'NNP',
#   '.',
#   '<s>',
#   'PRP',
#   'VBD',
#   'JJR',
#   'NNS',
#   'WP',
#   'VBD',
#   'TO',
#   'VB',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   'VBN',
#   'TO',
#   'DT',
#   'NN',
#   'VBG',
#   'DT',
#   'NNP',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   'NN',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'VBG',
#   'NN',
#   '.'],
#  ['<s>', 'VBN', 'DT', 'JJS', 'NN', 'IN', 'DT', 'NN', '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'CC',
#   'NNP',
#   'VBD',
#   'PRP',
#   'VBD',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'NN',
#   ',',
#   'IN',
#   'PRP',
#   'VBD',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'PRP',
#   'VBP',
#   'VB',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'NNS',
#   'VBP',
#   'VBN',
#   'PRP$',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'JJ',
#   'TO',
#   'NNP',
#   '.'],
#  ['<s>', 'DT', 'JJ', 'NN', 'VBZ', 'VBN', 'IN', 'CD', 'NN', 'IN', 'NNP', '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   'IN',
#   'JJ',
#   'NNS',
#   ',',
#   'NNS',
#   'VBG',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'CC',
#   'VBZ',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'EX',
#   'VBP',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'WRB',
#   'NNS',
#   'VBD',
#   'RP',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   ',',
#   'NNP',
#   'NN',
#   'IN',
#   'NNS',
#   'VBD',
#   'JJ',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'CC',
#   'NN',
#   'VBD',
#   'JJR',
#   'IN',
#   'VBN',
#   'IN',
#   'NNPS',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'IN',
#   'CD',
#   'JJ',
#   'NN',
#   'NNS',
#   'IN',
#   'NNP',
#   'MD',
#   'VB',
#   'VBN',
#   'RP',
#   'IN',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'RB',
#   'VBD',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'NNP',
#   'IN',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'CD',
#   'NNS',
#   'TO',
#   'VB',
#   'PRP$',
#   'JJ',
#   'NN',
#   ',',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   ',',
#   'CC',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   'VBD',
#   '``',
#   'VB',
#   'NNS',
#   ',',
#   'JJS',
#   'IN',
#   'WP',
#   ',',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'VBD',
#   'NNS',
#   '.',
#   "''"],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'DT',
#   'CD',
#   'NN',
#   'NNS',
#   'NN',
#   'VBG',
#   'TO',
#   'NN',
#   ',',
#   'NNS',
#   'CC',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'NNS',
#   'VBN',
#   'IN',
#   'NNP',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'VBG',
#   'NN',
#   'IN',
#   'NNP',
#   'CC',
#   'NNP',
#   '``',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   "''",
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'IN',
#   'PRP$',
#   'JJ',
#   'CD',
#   'NNS',
#   ',',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'PRP$',
#   'JJS',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'IN',
#   'CD',
#   'NNS',
#   ',',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBP',
#   'VBG',
#   'PRP$',
#   'NNS',
#   'RB',
#   ',',
#   'VBG',
#   'RP',
#   'CD',
#   'NN',
#   '.',
#   '<s>',
#   'NNS',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'DT', 'JJS', 'VBG', 'NN', 'IN', 'JJ', 'NNS', '.'],
#  ['<s>',
#   'WRB',
#   'PRP',
#   'VBD',
#   'DT',
#   'NNP',
#   ',',
#   'PRP',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'VB',
#   'WP',
#   ',',
#   'NN',
#   '.',
#   '<s>',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   '.',
#   '<s>',
#   'RB',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'JJ',
#   'NNS',
#   'TO',
#   'VB',
#   'PRP',
#   'RBR',
#   'JJ',
#   'TO',
#   'VB',
#   'IN',
#   'NNP',
#   'NNS',
#   'VBP',
#   'VBG',
#   'JJ',
#   'NN',
#   'IN',
#   'CD',
#   'NNS',
#   'TO',
#   'CD',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NN',
#   'MD',
#   'VB',
#   'VBN',
#   'NNP',
#   'NNS',
#   '$',
#   'CD',
#   'TO',
#   'VB',
#   '.'],
#  ['<s>', 'IN', 'CD', 'CC', 'CD', ',', 'NN', 'NNS', 'VBD', '.'],
#  ['<s>',
#   'VBZ',
#   'NN',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNS',
#   'VBP',
#   'TO',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   ',',
#   'RB',
#   'IN',
#   'VBG',
#   'DT',
#   'NN',
#   ',',
#   'PRP',
#   'VBD',
#   'NN',
#   'WP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   '-LRB-',
#   'IN',
#   'NN',
#   '-RRB-',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   'VBP',
#   'CD',
#   'NNS',
#   'RBR',
#   'JJ',
#   'TO',
#   'VB',
#   'VBN',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   ',',
#   'DT',
#   'JJ',
#   'NNP',
#   'MD',
#   'RB',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '-LRB-',
#   'NN',
#   'IN',
#   'VBG',
#   'NN',
#   '-RRB-',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   ',',
#   'EX',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'CC',
#   'NNS',
#   'IN',
#   'PRP$',
#   'NNP',
#   '.',
#   '<s>',
#   'NN',
#   '.',
#   '<s>',
#   'PRP$',
#   'NNP',
#   'VBZ',
#   'IN',
#   'JJ',
#   '.'],
#  ['<s>',
#   'PRP',
#   'VBP',
#   'RBR',
#   'IN',
#   'PRP$',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   'VBN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   ',',
#   'NNP',
#   ',',
#   'NNP',
#   'CC',
#   'NN',
#   'IN',
#   'NNP',
#   'NNS',
#   'VBP',
#   'DT',
#   'RB',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NN',
# ...
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>', 'IN', 'VBG', 'NN', 'NNS', 'IN', 'JJ', 'NNS'],
#  ['<s>', 'DT', 'NNPS', 'NN', 'VBZ', 'JJ', 'NN', 'IN', 'NN', '.'],
#  ['<s>',
#   'VBZ',
#   'PRP',
#   'VBD',
#   'VB',
#   'DT',
#   'JJ',
#   'NN',
#   'VB',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'NNS',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['<s>',
#   'RB',
#   'IN',
#   'NNP',
#   ',',
#   'NNP',
#   'JJ',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'RB',
#   'TO',
#   'VB',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBD',
#   'IN',
#   'PRP',
#   'MD',
#   'TO',
#   'VB',
#   'JJ',
#   'IN',
#   'PRP$',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNS',
#   'VBP',
#   'IN',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NNS',
#   'VBN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'CC',
#   'DT',
#   'NNPS',
#   'VBD',
#   'RB',
#   'CD',
#   'NN',
#   'WP',
#   'VBZ',
#   'NNP',
#   ',',
#   'CC',
#   'NNS',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'PRP$',
#   'JJ',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'CD',
#   'CC',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NN',
#   'NNS',
#   'VBP',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'NN', 'NNP', 'VBD', 'NNP', '``', 'JJ', 'NN', '.', "''"],
#  ['<s>', 'NNP', 'JJ', 'NN', 'VBZ', 'RB', 'JJ', '.'],
#  ['<s>',
#   'NNP',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'JJ',
#   '``',
#   'NN',
#   "''",
#   'NNS',
#   '.',
#   '<s>',
#   'PRP$',
#   'NNS',
#   'MD',
#   'VB',
#   'VBN',
#   'CC',
#   'PRP$',
#   'NNS',
#   'MD',
#   'VB',
#   'JJ',
#   '.'],
#  ['<s>',
#   'IN',
#   'CD',
#   'CC',
#   'DT',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   ',',
#   'NNP',
#   'VBZ',
#   'RB',
#   'VBD',
#   'IN',
#   'DT',
#   'VBN',
#   'NN',
#   'TO',
#   'VB',
#   'PRP$',
#   'NNS',
#   'IN',
#   'DT',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'IN',
#   'NNS',
#   'NN',
#   '.',
#   '<s>',
#   'NNP',
#   ',',
#   'IN',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'RB',
#   'CD',
#   'NNS',
#   'VBP',
#   'VBN',
#   'RP',
#   'IN',
#   'NNP',
#   'IN',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   'VBD',
#   'PRP$',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'NNS',
#   'IN',
#   'DT',
#   'JJS',
#   'NN',
#   'NNS',
#   ',',
#   'RB',
#   'IN',
#   'NN',
#   'VBP',
#   'DT',
#   'JJS',
#   'NN',
#   'NNS',
#   'CC',
#   'DT',
#   'JJS',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   ',',
#   'WRB',
#   'PRP',
#   'VBP',
#   'NNP',
#   'IN',
#   'TO',
#   'DT',
#   'NNS',
#   ':',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'JJ',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NNS',
#   '.',
#   '<s>',
#   'RB',
#   ',',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'RB',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NNS',
#   'TO',
#   'NNP',
#   'VBD',
#   'NN',
#   'NNS',
#   'VBG',
#   'NNP',
#   '-LRB-',
#   'JJ',
#   'NN',
#   'NNP',
#   '-RRB-',
#   'NNP',
#   ':',
#   'VBG',
#   'DT',
#   'NNP',
#   'TO',
#   'DT',
#   'JJ',
#   'VB',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'NNS',
#   'CC',
#   'VBG',
#   'CC',
#   'VBG',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'EX',
#   'VBZ',
#   'IN',
#   'CD',
#   'NNS',
#   'RBR',
#   'NN',
#   'IN',
#   'DT',
#   'VBN',
#   'NNP',
#   'NN',
#   'IN',
#   'EX',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'NNS',
#   'VBN',
#   'TO',
#   'VB',
#   'RB',
#   'NNPS',
#   'NN'],
#  ['<s>', 'NNS', 'IN', 'NN', 'RB', 'VBP', 'PRP$', 'NNS', 'NN', 'NNS', '.'],
#  ['<s>',
#   'EX',
#   'VBP',
#   'VBN',
#   'RBR',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'NN',
#   'IN',
#   ':',
#   'NNPS',
#   'IN',
#   'NNP',
#   'RB',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NNS',
#   'IN',
#   'NNP',
#   'IN',
#   'PRP',
#   'VBD',
#   'NNP',
#   '.'],
#  ['<s>',
#   'NNPS',
#   'CD',
#   'NN',
#   'IN',
#   'JJR',
#   'NNS',
#   'VBD',
#   'DT',
#   'NNS',
#   'VBG',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'VBZ', 'DT', 'CD', 'NN', 'IN', 'DT', 'NNP', 'NNS', '.'],
#  ['<s>', 'NNS', 'VBP', 'TO', 'VB', 'IN', 'NN', '.'],
#  ['<s>',
#   'RB',
#   'CD',
#   'NNS',
#   'VBP',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'RB',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   'POS',
#   'JJ',
#   'NN',
#   'VBZ',
#   'CD',
#   'JJ',
#   'NN',
#   'NNS',
#   ',',
#   '``',
#   'DT',
#   'VBZ',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'PRP',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'VBD',
#   'VBG',
#   'TO',
#   'VB',
#   'NN',
#   'NNS',
#   ',',
#   'PRP',
#   'RB',
#   'VBP',
#   'PRP$',
#   'VBG',
#   'TO',
#   'RB',
#   'VB',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'NNS',
#   'IN',
#   'CD',
#   'NNS',
#   'DT',
#   'NN',
#   'WDT',
#   'NNP',
#   'VBZ',
#   '.'],
#  ['<s>',
#   '-LRB-',
#   'NNP',
#   'NNPS',
#   'NNP',
#   '-RRB-',
#   'RB',
#   'VBD',
#   'CD',
#   'IN',
#   'PRP$',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBD',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'VBG',
#   'RB',
#   'IN',
#   'PRP',
#   'VBZ',
#   'IN',
#   'PRP',
#   'VBP',
#   ',',
#   'RB',
#   'NN',
#   'VB',
#   'NN',
#   '.'],
#  ['<s>', 'NNP', 'VBD', '$', 'CD', 'IN', 'NNP', ',', 'DT', 'NNP', 'NN', '.'],
#  ['<s>',
#   'RB',
#   ',',
#   'IN',
#   'DT',
#   'NN',
#   'DT',
#   'NN',
#   'VBZ',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   ',',
#   'JJ',
#   'VBN',
#   'IN',
#   'CD',
#   'NNS',
#   'IN',
#   'NN',
#   'NNS',
#   'CC',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'IN',
#   'JJR',
#   'NNS',
#   'CC',
#   'NNS',
#   'CD',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBD',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'NN',
#   'IN',
#   'DT',
#   '-LRB-',
#   'NNP',
#   'NNPS',
#   '-RRB-',
#   'NNS',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'NNP',
#   '-LRB-',
#   'VBD',
#   '-RRB-',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'NN',
#   'IN',
#   'DT',
#   '-LRB-',
#   'CD',
#   'JJ',
#   '-RRB-',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'WRB',
#   'PRP',
#   'VBP',
#   'NNP',
#   '.'],
#  ['<s>',
#   'CC',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'WRB',
#   'PRP',
#   'VBD',
#   'NN',
#   ',',
#   'PRP',
#   'VBD',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NN',
#   ':',
#   'NNP',
#   'VBZ',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NN',
#   'VBD',
#   ',',
#   'PRP',
#   'VBD',
#   'JJR',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'VBG', 'CD', 'NNS', '.'],
#  ['<s>',
#   'NNS',
#   'VBP',
#   'VBN',
#   'RP',
#   'DT',
#   'NNP',
#   'NN',
#   'CC',
#   'PDT',
#   'DT',
#   'NNS',
#   'VBG',
#   'VBN',
#   'IN',
#   'NNP',
#   'VBP',
#   'RB',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'JJ',
#   'NNS',
#   'RB',
#   'VBD',
#   'DT',
#   'NN',
#   'TO',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>', 'NNP', 'VBD', 'DT', 'JJ', 'NN', '.'],
#  ['<s>',
#   'CD',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NN',
#   'VBP',
#   'DT',
#   'JJ',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'NNS',
#   ':',
#   'MD',
#   'VB',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NN',
#   'VBZ',
#   'RB',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'NN',
#   '.',
#   '<s>',
#   'DT',
#   'NN',
#   'PRP$',
#   'JJR',
#   '.',
#   '<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   'CD',
#   'NN',
#   '.',
#   '<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'VBZ',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>', 'PRP', 'VBP', 'VBN', 'DT', 'NN', 'IN', 'NNP', '.'],
#  ['<s>',
#   'VBD',
#   'NN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NN',
#   'TO',
#   'VB',
#   'PRP$',
#   'NNS',
#   '.',
#   '<s>',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'VBD',
#   'NN',
#   'CD',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'CD',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'MD',
#   'VB',
#   'NN',
#   'NNS',
#   'TO',
#   'VB',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'VBD', 'DT', 'NN', 'IN', 'DT', 'NNP', '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'JJS',
#   'IN',
#   'NN',
#   'IN',
#   'PRP$',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NNP',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'CD',
#   'NNP',
#   'VBD',
#   'DT',
#   'NN',
#   'CC',
#   'NN',
#   'RB',
#   'JJ',
#   'CC',
#   'JJ',
#   '.'],
#  ['<s>', 'DT', 'JJ', 'NNS', 'NN', 'MD', 'VB', '``', 'NN', '.', "''"],
#  ['<s>',
#   'WRB',
#   'NNP',
#   'RB',
#   'VBD',
#   ',',
#   'EX',
#   'VBD',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'NN',
#   'EX',
#   'VBP',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'EX',
#   'MD',
#   'VB',
#   'RB',
#   'CD',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'CC',
#   'NNP',
#   'VBP',
#   'DT',
#   'JJ',
#   'JJS',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'WP',
#   'IN',
#   'CD',
#   'NN',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   ',',
#   'VBZ',
#   'VBN',
#   'PRP$',
#   'NN',
#   'NNS',
#   '.'],
#  ['<s>', 'VBZ', 'NN', 'VBZ', 'DT', 'NN', 'IN', 'NN', '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'VBN',
#   'TO',
#   'VB',
#   'RP',
#   'NNS',
#   ',',
#   'RB',
#   'IN',
#   'NN',
#   'CC',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'PRP$',
#   'CD',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   ',',
#   'PRP',
#   'VBP',
#   'VBN',
#   'PRP$',
#   'NN',
#   'VB',
#   'IN',
#   'DT',
#   'RB',
#   'JJ',
#   'NN',
#   'TO',
#   'DT',
#   'RB',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'NNP',
#   'IN',
#   'NNPS',
#   'JJ',
#   'NNP',
#   ',',
#   'WDT',
#   'VBD',
#   'VBG',
#   'JJ',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'VBZ',
#   'RB',
#   '$',
#   'CD',
#   'JJR',
#   'IN',
#   'WRB',
#   'NNP',
#   'VBD',
#   'VBN',
#   'IN',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'VBP',
#   'JJR',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'VBP',
#   'JJ',
#   ',',
#   'NNP',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'IN',
#   'DT',
#   'NNP',
#   'MD',
#   'VB',
#   'DT',
#   'NNP',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'DT',
#   'NNP',
#   'IN',
#   'NNP',
#   'IN',
#   'VBG',
#   'NNS',
#   '$',
#   'CD',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBZ',
#   'VBG',
#   'PRP$',
#   'NNP',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   ',',
#   'DT',
#   'NN',
#   'VBN',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'DT',
#   'NN',
#   'VBN',
#   'NNP',
#   'POS',
#   'NNP',
#   '.',
#   '<s>',
#   'PRP',
#   'VBP',
#   'VBN',
#   'JJ',
#   'NNS',
#   ',',
#   'CC',
#   'DT',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'JJR',
#   'IN',
#   '$',
#   'CD',
#   'IN',
#   'NN',
#   'WDT',
#   'VBZ',
#   'VBN',
#   'TO',
#   'VB',
#   'VBN',
#   'TO',
#   'JJ',
#   'NNS',
#   'CC',
#   'NNS',
#   'VBZ',
#   'VBG',
#   'VBN',
#   'TO',
#   'VB',
#   'DT',
#   'NNS',
#   'VBP',
#   'JJ',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'PRP$',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   'IN',
#   'NN',
#   '-LRB-',
#   'CC',
#   '-RRB-',
#   'VBD',
#   'NN',
#   'NNS',
#   'VBP',
#   'IN',
#   'PRP',
#   'VBD',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   'DT',
#   'PRP$',
#   'NN',
#   '-LRB-',
#   'NN',
#   '-RRB-',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'JJ',
#   'NNP',
#   'CD',
#   '.'],
#  ['<s>',
#   'JJ',
#   'NNS',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NNS',
#   'CC',
#   'NNP',
#   'VBZ',
#   'VBN',
#   'JJ',
#   'NNS',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NN',
#   'NNS',
#   'IN',
#   'JJ',
#   'NNS',
#   'IN',
#   'NNP',
#   'VBP',
#   'JJ',
#   'NN',
#   'NNS',
#   'CC',
#   'PRP$',
#   'NNS',
#   'VBP',
#   'IN',
#   'NN',
#   ':',
#   'CC',
#   'NNS',
#   'VBG',
#   'NNS',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'NN',
#   'VBZ',
#   'NN',
#   'NNS',
#   'IN',
#   'NNS',
#   'CC',
#   'DT',
#   'JJ',
#   'DT',
#   'MD',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   'NNS',
#   '$',
#   'CD',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'MD',
#   'VB',
#   'NN',
#   'IN',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'NNP',
#   'NNPS',
#   'IN',
#   'VBG',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'DT',
#   'NN',
#   'RB',
#   'VBZ',
#   'DT',
#   'CD',
#   'JJ',
#   'NN',
#   'VBG',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'JJ',
#   'NNS',
#   '.',
#   '<s>',
#   'NN',
#   '.',
#   '<s>',
#   'NNP',
#   '.',
#   '<s>',
#   'PRP$',
#   'RB',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'DT',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBD',
#   'VBG',
#   'TO',
#   'VB',
#   'IN',
#   'JJ',
#   'NN',
#   'VBD',
#   'RP',
#   'VBG',
#   'NNS',
#   '.',
#   '<s>',
#   'VBN',
#   'RP',
#   'VBG',
#   'NNS',
#   '.',
#   '<s>',
#   'CC',
#   'PRP',
#   'VBD',
#   'CD',
#   '.',
#   '<s>',
#   'CC',
#   'RB',
#   'PRP',
#   'VBZ',
#   'IN',
#   'PRP',
#   'MD',
#   'VB',
#   'CD',
#   ',',
#   'CC',
#   'PRP',
#   'VBP',
#   'RB',
#   'VB',
#   '.'],
#  ['<s>',
#   'VBG',
#   'TO',
#   'DT',
#   'NN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   ',',
#   'NNPS',
#   'VBP',
#   'VBN',
#   'TO',
#   'VB',
#   'IN',
#   'DT',
#   'NN',
#   'IN',
#   'PRP',
#   'VBP',
#   'IN',
#   'JJ',
#   'NN',
#   ',',
#   'VB',
#   'PRP$',
#   'JJ',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'VB',
#   'CC',
#   'VB',
#   'VBN',
#   '.'],
#  ['<s>',
#   'PRP',
#   '-LRB-',
#   'IN',
#   'NNP',
#   '-RRB-',
#   'VBP',
#   'DT',
#   'JJS',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'DT',
#   'NNP',
#   'NN',
#   'IN',
#   'NNP',
#   ',',
#   'PRP',
#   'VBP',
#   'IN',
#   'NNP',
#   'CC',
#   'JJS',
#   'IN',
#   'PRP$',
#   'NNS',
#   'VBP',
#   'IN',
#   'NNP',
#   '.'],
#  ['<s>',
#   'IN',
#   'NNP',
#   ',',
#   'NN',
#   'VBD',
#   'NNS',
#   'IN',
#   'NNS',
#   ',',
#   'NNS',
#   'IN',
#   'NNP',
#   'CD',
#   '.',
#   '<s>',
#   'NNS',
#   'IN',
#   'NNS',
#   '.'],
#  ['<s>',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'NN',
#   ',',
#   'NN',
#   'VBG',
#   'IN',
#   'JJ',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   '.',
#   '<s>',
#   'IN',
#   'PRP',
#   'VBP',
#   'DT',
#   'JJ',
#   'NN',
#   ',',
#   'NN',
#   'VBG',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'PRP',
#   'NN',
#   'NNS',
#   'IN',
#   'RB',
#   'JJ',
#   'NNS',
#   'IN',
#   'PRP',
#   'VBZ',
#   'JJR',
#   'IN',
#   'DT',
#   'NN',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   'IN',
#   'VB',
#   'PRP$',
#   'NNS',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>', 'VBZ', 'NNP', 'JJ', 'IN', 'DT', 'NN', '.'],
#  ['<s>',
#   'NNP',
#   'CC',
#   'PRP$',
#   'JJ',
#   'NNPS',
#   'VBD',
#   'IN',
#   'DT',
#   'NN',
#   'CC',
#   'RB',
#   'PRP$',
#   'NN',
#   'VBZ',
#   'VBN',
#   'RP',
#   '.'],
#  ['<s>',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   ',',
#   'CD',
#   'NN',
#   'IN',
#   'JJ',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'DT',
#   'NNP',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'DT',
#   'NNS',
#   'NN',
#   'IN',
#   'PRP',
#   'VBG',
#   'PRP',
#   'VBD',
#   'NN',
#   'NNS',
#   'IN',
#   'NN',
#   ',',
#   'WDT',
#   'VBZ',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'NNS',
#   'VBP',
#   'VBN',
#   'IN',
#   'NN',
#   'IN',
#   'RB',
#   'JJ',
#   'IN',
#   '$',
#   'CD',
#   '.'],
#  ['<s>',
#   'NNP',
#   '-LRB-',
#   'NNP',
#   '-RRB-',
#   'VBZ',
#   'TO',
#   'VB',
#   'DT',
#   'NN',
#   '-LRB-',
#   'IN',
#   'JJ',
#   'NNS',
#   '-RRB-',
#   'IN',
#   'CD',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNP',
#   'VBD',
#   '-LRB-',
#   'RB',
#   'VBN',
#   'NN',
#   'NNS',
#   '-RRB-',
#   'RB',
#   'IN',
#   'DT',
#   'VBG',
#   'DT',
#   'JJ',
#   'CD',
#   'NNS',
#   '.'],
#  ['<s>', 'NNP', 'VBZ', 'RB', 'VBN', 'TO', 'VB', 'JJ', '.'],
#  ['<s>',
#   'JJ',
#   'NNPS',
#   'MD',
#   'VB',
#   'IN',
#   'DT',
#   'NNP',
#   'NNPS',
#   'IN',
#   'RB',
#   'VBG',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'NNS',
#   'IN',
#   'NNP',
#   'POS',
#   'NN',
#   'MD',
#   '``',
#   'JJR',
#   'NN',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   'IN',
#   '$',
#   'CD',
#   'DT',
#   'NN',
#   '.',
#   "''"],
#  ['<s>',
#   'NNP',
#   'VBZ',
#   'RB',
#   'DT',
#   'JJ',
#   'NN',
#   'CC',
#   'NN',
#   '.',
#   '<s>',
#   'WRB',
#   'PRP',
#   'VBP',
#   'IN',
#   'PDT',
#   'DT',
#   'NN',
#   'CC',
#   'JJ',
#   'NNS',
#   'VB',
#   'RP',
#   'IN',
#   'NNS',
#   ',',
#   'VBD',
#   'RBR',
#   'IN',
#   'DT',
#   'NN',
#   '.'],
#  ['<s>',
#   'CD',
#   'NN',
#   'IN',
#   'DT',
#   'NN',
#   'VBZ',
#   'JJ',
#   'NN',
#   'TO',
#   'VB',
#   'NNS',
#   '.'],
#  ['<s>',
#   'NNS',
#   'IN',
#   'DT',
#   'NNP',
#   'VB',
#   'CD',
#   'NN',
#   'JJR',
#   'NN',
#   'IN',
#   'NNS',
#   'IN',
#   'DT',
#   'JJ',
#   'NN',
#   '.'],
#  ['<s>',
#   'VBZ',
#   'NNP',
#   'VBD',
#   'JJ',
#   'NNS',
#   'TO',
#   'JJ',
#   'NN',
#   'NNS',
#   'WDT',
#   'VBP',
#   'NNS',
#   'IN',
#   'JJR',
#   'NN',
#   'IN',
#   'NN',
#   '.'],
#  ...]

# %% [markdown]
# # Removing duplicated POS in trigrams

# %%
list_to_remove = ['NNP','CD','NN']
removed_pos_trigrams = nlp_task.POS_groupping(grams=3,sentences_pos=removed_pos)
removed_pos_trigrams_va = nlp_task.POS_groupping(grams=3,sentences_pos=removed_pos_va)
removed_unique_trigrams = nlp_task.UniquePosTags(postags=removed_pos_trigrams_va)

# %%
len(removed_unique_trigrams)
# Out:
# 4374

# %%
list_to_remove = ['NNP','CD']
removed_pos_p = nlp_task.RemoveConsecutiveTags(list_to_remove,unigram_pos_no_p)
removed_pos_bigrams_p = nlp_task.POS_groupping(grams=2,sentences_pos=removed_pos_p)

removed_pos_va_p =  nlp_task.RemoveConsecutiveTags(list_to_remove,unigram_pos_no_p_va)
removed_pos_bigrams_va_p = nlp_task.POS_groupping(grams=2,sentences_pos=removed_pos_va_p)

#LIST OF UNIQUE BIGRAMS AFTER REMOVING CONSECUTIVE SAME TAGS
removed_unique_bigrams_p = nlp_task.UniquePosTags(postags=removed_pos_bigrams_p)

# %%
# For example: The/DT economy/NN bled/VBD $/$ 24/CD billion/CD due/JJ to/TO the/DT government/NN shutdown/NN ./.
# In this case having CD_CD is the same as having only CD
# Same with: 
# U.S./NNP Rep./NNP Ron/NNP Kind/NNP ,/, D-Wis./NNP ,/, and/CC his/PRP$ fellow/JJ Democrats/NNS went/VBD on/IN a/DT spending/NN spree/NN and/CC now/RB their/PRP$ credit/NN card/NN is/VBZ maxed/VBN out/RP
# We don't need all those NNPs to find a pattern and it might be noisy to the ML algorithm

for i,big in enumerate(removed_pos_bigrams):
    hasD = False
    for x in big:
        if x.split('_')[0]==x.split('_')[1]:
            print(x)
            hasD=True
    if hasD:
        print(removed_pos[i])
        print(tr_dict['statement'][i])
        hasD=False

# %%
# Trigram POS by different preprocessing type of text
# Trigram of unclean data
trigram_list_tr = nlp_task.UniquePosTags(trigram_pos)
trigram_list_va = nlp_task.UniquePosTags(trigram_pos_va)

# Trigram of no punctuation data
trigram_list_tr_no_p = nlp_task.UniquePosTags(trigram_pos_no_p)
trigram_list_va_no_p = nlp_task.UniquePosTags(trigram_pos_no_p_va)

# Trigram of no punctuation and with lower case
trigram_list_tr_no_p_u = nlp_task.UniquePosTags(trigram_pos_no_p_u) 
trigram_list_va_no_p_u = nlp_task.UniquePosTags(trigram_pos_no_p_u_va)

# Trigram of no punctuation, without lower case and without stop words
trigram_list_tr_no_p_u_sw = nlp_task.UniquePosTags(trigram_pos_no_p_u_sw)
trigram_list_va_no_p_u_sw = nlp_task.UniquePosTags(trigram_pos_no_p_u_sw_va)

# %% [markdown]
# # Create new labels grouping different classes in the dataset

# %%
binary_labels_tr = np.array(preprocessing.create_labels(labels=tr_file['Label'].values,label_values={'false':1, 'true':-1,'pants-fire':1,'barely-true':1,'half-true':0,'mostly-true':-1}))
binary_labels_va = np.array(preprocessing.create_labels(labels=va_file['Label'].values,label_values={'false':1, 'true':-1,'pants-fire':1,'barely-true':1,'half-true':0,'mostly-true':-1}))
binary_labels_te = np.array(preprocessing.create_labels(labels=te_file['Label'].values,label_values={'false':1, 'true':-1,'pants-fire':1,'barely-true':1,'half-true':0,'mostly-true':-1}))

tr_indexes = [i for i,x in enumerate(binary_labels_tr) if x!=0]
va_indexes = [i for i,x in enumerate(binary_labels_va) if x!=0]

# %%
# use countVectorizor to build postag output as features for training ML model
## uni_vocabulary: vocabulary=['cd','jjr','vb','jjs','nnp','in','vbp','to','rb','vbg','md','jj','dt']
## bi_vocabulary: vocabulary=['NNP NNP', 'IN DT', 'JJR IN', 'CD NN', 'IN CD', 'CD NNS', 'DT JJS']
## tri_vocabulary: ['NNP NNP NNP','CD NN IN','VBZ NNP NNP','IN DT NN','IN DT JJ','NN IN DT','<s> VBZ NNP','JJR IN CD','NNP NNP VBD','DT JJ CD','NNS IN DT']

# %% [markdown]
#    # Train machine learning models with different preprocessing data

# %%
#pruned_features_1 = []
#pruned_features_2 = []

pruned_list = list(np.array(trigram_list_tr_no_p)[pruned_features_1])

# %%
trigram_pos_no_p
# Out:
# [['<s>_VBZ_DT',
#   'VBZ_DT_NNPS',
#   'DT_NNPS_VBP',
#   'NNPS_VBP_JJ',
#   'VBP_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_JJ',
#   'VBZ_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_IN'],
#  ['<s>_WRB_VBD',
#   'WRB_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_PRP',
#   'NN_PRP_VBD',
#   'PRP_VBD_WRB',
#   'VBD_WRB_JJ',
#   'WRB_JJ_NN',
#   'JJ_NN_VBD',
#   'NN_VBD_RP',
#   'VBD_RP_WDT',
#   'RP_WDT_VBD',
#   'WDT_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_VBG',
#   'IN_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_NNP',
#   'VB_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN'],
#  ['<s>_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_JJ',
#   'VBZ_JJ_TO',
#   'JJ_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_NN',
#   'JJ_NN_NN'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP$'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_VBP',
#   'NNPS_VBP_VBN',
#   'VBP_VBN_RBR',
#   'VBN_RBR_JJ',
#   'RBR_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_CD',
#   'JJ_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_NNP',
#   'JJ_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_CD'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_PRP',
#   'NN_PRP_VBZ',
#   'PRP_VBZ_IN',
#   'VBZ_IN_NNS'],
#  ['<s>_PRP_NN',
#   'PRP_NN_DT',
#   'NN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_WP',
#   'NN_WP_VBZ',
#   'WP_VBZ_VBN',
#   'VBZ_VBN_RB',
#   'VBN_RB_RB',
#   'RB_RB_JJ',
#   'RB_JJ_NN',
#   'JJ_NN_VBG',
#   'NN_VBG_RP',
#   'VBG_RP_IN',
#   'RP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_IN',
#   'DT_IN_DT',
#   'IN_DT_JJS',
#   'DT_JJS_NNS',
#   'JJS_NNS_NN',
#   'NNS_NN_IN'],
#  ['<s>_RB_PRP',
#   'RB_PRP_VBD',
#   'PRP_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_TO',
#   'NNP_TO_RB',
#   'TO_RB_VB',
#   'RB_VB_DT',
#   'VB_DT_JJ',
#   'DT_JJ_NNP',
#   'JJ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_JJ',
#   'NNP_JJ_NNS',
#   'JJ_NNS_NNP',
#   'NNS_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_WDT',
#   'NN_WDT_VBD',
#   'WDT_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_JJR',
#   'IN_JJR_NN'],
#  ['<s>_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_JJR',
#   'VBZ_JJR_IN',
#   'JJR_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN'],
#  ['<s>_IN_CD',
#   'IN_CD_RB',
#   'CD_RB_CD',
#   'RB_CD_CD',
#   'CD_CD_NNPS',
#   'CD_NNPS_VBP',
#   'NNPS_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_IN',
#   'IN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_CC',
#   'NN_CC_IN'],
#  ['<s>_WRB_NNP',
#   'WRB_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_VBP',
#   'PRP_VBP_RB',
#   'VBP_RB_VB',
#   'RB_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_PRP',
#   'NN_PRP_RB',
#   'PRP_RB_VBD'],
#  ['<s>_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_TO',
#   'JJ_TO_DT',
#   'TO_DT_NN'],
#  ['<s>_JJS_IN',
#   'JJS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_IN',
#   'RB_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBN',
#   'NN_VBN_VBN',
#   'VBN_VBN_CC',
#   'VBN_CC_RB'],
#  ['<s>_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NNS',
#   'JJ_NNS_VBD',
#   'NNS_VBD_RB',
#   'VBD_RB_TO',
#   'RB_TO_VB',
#   'TO_VB_CD',
#   'VB_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_CC',
#   'NNS_CC_CD',
#   'CC_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_VBD',
#   'NNS_VBD_RB',
#   'VBD_RB_TO'],
#  ['<s>_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VB',
#   'NN_VB_NNP',
#   'VB_NNP_VBD',
#   'NNP_VBD_NNS',
#   'VBD_NNS_CC',
#   'NNS_CC_PRP',
#   'CC_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_VB',
#   'DT_VB_JJ',
#   'VB_JJ_NNS',
#   'JJ_NNS_VBD',
#   'NNS_VBD_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_PRP$',
#   'CC_PRP$_JJ',
#   'PRP$_JJ_NNPS',
#   'JJ_NNPS_VBD',
#   'NNPS_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_CC',
#   'NN_CC_RB',
#   'CC_RB_PRP$',
#   'RB_PRP$_NN',
#   'PRP$_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_VBN'],
#  ['<s>_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNPS',
#   'NNP_NNPS_VBD',
#   'NNPS_VBD_VBN',
#   'VBD_VBN_RP',
#   'VBN_RP_TO',
#   'RP_TO_CD',
#   'TO_CD_NN',
#   'CD_NN_WRB',
#   'NN_WRB_DT',
#   'WRB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_JJ'],
#  ['<s>_RB_CD',
#   'RB_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_VBD',
#   'NNS_VBD_NNP',
#   'VBD_NNP_NNP',
#   'NNP_NNP_JJ'],
#  ['<s>_NNS_CC',
#   'NNS_CC_NNS',
#   'CC_NNS_CC',
#   'NNS_CC_VBP',
#   'CC_VBP_VBG',
#   'VBP_VBG_JJR',
#   'VBG_JJR_WRB',
#   'JJR_WRB_PRP',
#   'WRB_PRP_VBP',
#   'PRP_VBP_IN',
#   'VBP_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_WRB',
#   'IN_WRB_NNP',
#   'WRB_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_JJ',
#   'VBD_JJ_VBN'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_VBZ',
#   'NNPS_VBZ_DT',
#   'VBZ_DT_JJS',
#   'DT_JJS_JJ',
#   'JJS_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_PRP_RB',
#   'PRP_RB_VBD',
#   'RB_VBD_DT',
#   'VBD_DT_JJS',
#   'DT_JJS_NN',
#   'JJS_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBG',
#   'VBZ_VBG_RP',
#   'VBG_RP_TO',
#   'RP_TO_CD',
#   'TO_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_CC',
#   'NNS_CC_NNS',
#   'CC_NNS_IN',
#   'NNS_IN_NN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_IN',
#   'JJ_IN_NNP'],
#  ['<s>_PRP_VBP', 'PRP_VBP_VB', 'VBP_VB_WP', 'VB_WP_NNP', 'WP_NNP_NNP'],
#  ['<s>_VB_NNS',
#   'VB_NNS_IN',
#   'NNS_IN_JJ',
#   'IN_JJ_NNPS',
#   'JJ_NNPS_CC',
#   'NNPS_CC_NNS',
#   'CC_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_NNP'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_DT',
#   'VBN_DT_NN',
#   'DT_NN_CC',
#   'NN_CC_VBZ',
#   'CC_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_VBN',
#   'VB_VBN_DT',
#   'VBN_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_CD',
#   'NN_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_NN'],
#  ['<s>_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_DT',
#   'CD_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_DT',
#   'CD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP'],
#  ['<s>_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NNS',
#   'NN_NNS_VBZ',
#   'NNS_VBZ_IN',
#   'VBZ_IN_CD',
#   'IN_CD_TO',
#   'CD_TO_CD'],
#  ['<s>_VBZ_NNP', 'VBZ_NNP_NNP', 'NNP_NNP_VBZ', 'NNP_VBZ_RB', 'VBZ_RB_VBG'],
#  ['<s>_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_IN',
#   'VBP_IN_NNS',
#   'IN_NNS_WDT',
#   'NNS_WDT_VBP',
#   'WDT_VBP_JJ',
#   'VBP_JJ_TO',
#   'JJ_TO_VB',
#   'TO_VB_PRP',
#   'VB_PRP_RB',
#   'PRP_RB_VBP',
#   'RB_VBP_RB',
#   'VBP_RB_VB',
#   'RB_VB_NN',
#   'VB_NN_NNS',
#   'NN_NNS_CC',
#   'NNS_CC_PRP',
#   'CC_PRP_VBP',
#   'PRP_VBP_RB',
#   'VBP_RB_JJ',
#   'RB_JJ_NN'],
#  ['<s>_WP_DT',
#   'WP_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_VBZ',
#   'NN_VBZ_VBG',
#   'VBZ_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_IN',
#   'RP_IN_IN',
#   'IN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NNS',
#   'JJ_NNS_VBZ',
#   'NNS_VBZ_NN',
#   'VBZ_NN_RB',
#   'NN_RB_RB',
#   'RB_RB_VBG',
#   'RB_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_TO',
#   'JJ_TO_VB',
#   'TO_VB_NN',
#   'VB_NN_RB',
#   'NN_RB_RB',
#   'RB_RB_IN',
#   'RB_IN_DT',
#   'IN_DT_VBG'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_NN',
#   'VBD_NN_NNS',
#   'NN_NNS_RB',
#   'NNS_RB_NN',
#   'RB_NN_CD',
#   'NN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NNS',
#   'PRP$_NNS_VBP',
#   'NNS_VBP_VB',
#   'VBP_VB_DT',
#   'VB_DT_NN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_NNP',
#   'IN_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_DT',
#   'VBP_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_WDT',
#   'NN_WDT_VBZ',
#   'WDT_VBZ_PRP',
#   'VBZ_PRP_VBP',
#   'PRP_VBP_DT',
#   'VBP_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_PRP$',
#   'VB_PRP$_NN'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_WDT',
#   'NN_WDT_VBZ',
#   'WDT_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_NN',
#   'IN_NN_DT',
#   'NN_DT_CD',
#   'DT_CD_NNS',
#   'CD_NNS_CC',
#   'NNS_CC_RB',
#   'CC_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBD'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBN',
#   'NN_VBN_IN',
#   'VBN_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_VBZ',
#   'NNP_VBZ_CD',
#   'VBZ_CD_JJ',
#   'CD_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_CD',
#   'DT_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBP',
#   'NNP_VBP_VBN',
#   'VBP_VBN_CD',
#   'VBN_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_JJ'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNPS',
#   'DT_NNPS_IN',
#   'NNPS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_MD',
#   'NNP_MD_NN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_PRP',
#   'NNP_PRP_VBD',
#   'PRP_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_TO',
#   'CD_TO_DT',
#   'TO_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_TO',
#   'CD_TO_DT'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_MD',
#   'NNS_MD_VB',
#   'MD_VB_VBN',
#   'VB_VBN_VBN',
#   'VBN_VBN_IN',
#   'VBN_IN_JJ',
#   'IN_JJ_JJ'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_CD',
#   'VBD_CD_NN',
#   'CD_NN_NNS',
#   'NN_NNS_VBG',
#   'NNS_VBG_CD',
#   'VBG_CD_TO',
#   'CD_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NNPS',
#   'DT_NNPS_TO',
#   'NNPS_TO_VB'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_JJ',
#   'VBZ_JJ_IN',
#   'JJ_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_TO',
#   'NN_TO_NNP',
#   'TO_NNP_DT',
#   'NNP_DT_VBN',
#   'DT_VBN_JJ'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_RB',
#   'NN_RB_VBD',
#   'RB_VBD_IN',
#   'VBD_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NNS',
#   'VBZ_NNS_VBG',
#   'NNS_VBG_DT',
#   'VBG_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_JJ',
#   'DT_JJ_JJ'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_DT',
#   'VBP_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_WP',
#   'NN_WP_MD',
#   'WP_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_CC',
#   'VB_CC_MD',
#   'CC_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_JJ',
#   'NN_JJ_NN',
#   'JJ_NN_CC',
#   'NN_CC_RB',
#   'CC_RB_VBZ',
#   'RB_VBZ_NN',
#   'VBZ_NN_VBN'],
#  ['<s>_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_CD',
#   'VBZ_CD_NN',
#   'CD_NN_JJ',
#   'NN_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_CD'],
#  ['<s>_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_TO',
#   'NN_TO_DT',
#   'TO_DT_JJ',
#   'DT_JJ_NNP',
#   'JJ_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_RB',
#   'NNS_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_RB'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_RB',
#   'VBD_RB_NN',
#   'RB_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_NNS',
#   'NNS_NNS_RB'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_IN',
#   'VBD_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_WDT',
#   'NNP_WDT_VBD',
#   'WDT_VBD_DT',
#   'VBD_DT_NNS',
#   'DT_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_WDT',
#   'NN_WDT_RB',
#   'WDT_RB_VBD',
#   'RB_VBD_NNP',
#   'VBD_NNP_NNP',
#   'NNP_NNP_NNPS'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_VBN',
#   'NN_VBN_NN',
#   'VBN_NN_WDT',
#   'NN_WDT_MD',
#   'WDT_MD_NN',
#   'MD_NN_NN'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNPS',
#   'NNP_NNPS_NN',
#   'NNPS_NN_VBN',
#   'NN_VBN_NN',
#   'VBN_NN_WDT',
#   'NN_WDT_NNP',
#   'WDT_NNP_JJ',
#   'NNP_JJ_NN',
#   'JJ_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_VBG',
#   'NN_VBG_PRP',
#   'VBG_PRP_DT',
#   'PRP_DT_JJS',
#   'DT_JJS_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_WP',
#   'NN_WP_VBD',
#   'WP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_DT',
#   'RP_DT_NNP'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_PRP',
#   'NNS_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_RB',
#   'NN_RB_IN',
#   'RB_IN_NN',
#   'IN_NN_CC',
#   'NN_CC_NN',
#   'CC_NN_NNP',
#   'NN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_JJR',
#   'VBZ_JJR_JJ',
#   'JJR_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_PRP',
#   'IN_PRP_VBZ',
#   'PRP_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_PRP$'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_NNS',
#   'VBP_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_WDT',
#   'NNP_WDT_VBP',
#   'WDT_VBP_IN',
#   'VBP_IN_IN',
#   'IN_IN_NN',
#   'IN_NN_WDT',
#   'NN_WDT_VBP',
#   'WDT_VBP_VBG',
#   'VBP_VBG_TO',
#   'VBG_TO_NN',
#   'TO_NN_IN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNS',
#   'NNP_NNS_VBP',
#   'NNS_VBP_CD',
#   'VBP_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBN',
#   'NN_VBN_IN'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_WDT',
#   'NN_WDT_VBZ',
#   'WDT_VBZ_NNS',
#   'VBZ_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_JJ',
#   'VBZ_JJ_RB',
#   'JJ_RB_IN',
#   'RB_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_PDT',
#   'NN_PDT_DT',
#   'PDT_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_TO',
#   'IN_TO_IN',
#   'TO_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_VBG',
#   'VBD_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_RB',
#   'IN_RB_RB',
#   'RB_RB_JJ',
#   'RB_JJ_IN',
#   'JJ_IN_IN',
#   'IN_IN_IN',
#   'IN_IN_CD',
#   'IN_CD_CC',
#   'CD_CC_PRP',
#   'CC_PRP_VBP',
#   'PRP_VBP_VB',
#   'VBP_VB_JJ',
#   'VB_JJ_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NN',
#   'VBZ_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_PRP',
#   'IN_PRP_VBZ',
#   'PRP_VBZ_VBG',
#   'VBZ_VBG_PRP$'],
#  ['<s>_IN_CD',
#   'IN_CD_RB',
#   'CD_RB_CD',
#   'RB_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_NNPS',
#   'IN_NNPS_IN',
#   'NNPS_IN_NNP',
#   'IN_NNP_VBD',
#   'NNP_VBD_VBN',
#   'VBD_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_CC',
#   'VB_CC_RB',
#   'CC_RB_CD',
#   'RB_CD_NN',
#   'CD_NN_RB',
#   'NN_RB_VBD'],
#  ['<s>_RB_CD',
#   'RB_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_JJ',
#   'JJ_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_NN'],
#  ['<s>_NNP_PRP',
#   'NNP_PRP_VBZ',
#   'PRP_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_WP',
#   'NN_WP_VBZ',
#   'WP_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_RP',
#   'VBN_RP_DT',
#   'RP_DT_NN'],
#  ['<s>_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_CC',
#   'NN_CC_DT',
#   'CC_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_RB',
#   'VBD_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBD'],
#  ['<s>_EX_VBP',
#   'EX_VBP_CD',
#   'VBP_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_EX',
#   'CC_EX_VBP',
#   'EX_VBP_CD',
#   'VBP_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_JJ'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN'],
#  ['<s>_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBP',
#   'NNP_VBP_DT',
#   'VBP_DT_CD',
#   'DT_CD_IN',
#   'CD_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_VBG'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_PRP',
#   'NNP_PRP_VBD',
#   'PRP_VBD_VB',
#   'VBD_VB_DT',
#   'VB_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBG',
#   'NN_VBG_NN',
#   'VBG_NN_VBD',
#   'NN_VBD_NNP',
#   'VBD_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_RB'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_WP',
#   'NN_WP_VBD',
#   'WP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_IN',
#   'PRP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_IN',
#   'CC_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NNS'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_RB',
#   'TO_RB_VB',
#   'RB_VB_IN',
#   'VB_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_DT'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_CD',
#   'VBD_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_CD',
#   'DT_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NNS',
#   'NN_NNS_TO',
#   'NNS_TO_NNP',
#   'TO_NNP_IN'],
#  ['<s>_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_DT',
#   'VBP_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_RB',
#   'NN_RB_IN',
#   'RB_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_VBP',
#   'PRP_VBP_JJ',
#   'VBP_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBD'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NN',
#   'NNP_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_NNS',
#   'NN_NNS_VBD',
#   'NNS_VBD_VBN',
#   'VBD_VBN_CC',
#   'VBN_CC_DT',
#   'CC_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NNP',
#   'JJ_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_IN',
#   'VBZ_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_WP',
#   'NN_WP_VBZ',
#   'WP_VBZ_TO',
#   'VBZ_TO_PRP',
#   'TO_PRP_TO',
#   'PRP_TO_VB',
#   'TO_VB_RB',
#   'VB_RB_JJ',
#   'RB_JJ_IN',
#   'JJ_IN_VBG',
#   'IN_VBG_DT',
#   'VBG_DT_JJ'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_WRB',
#   'NN_WRB_DT',
#   'WRB_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_VBN',
#   'VBZ_VBN_JJR',
#   'VBN_JJR_IN',
#   'JJR_IN_DT',
#   'IN_DT_VBD',
#   'DT_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP'],
#  ['<s>_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_DT',
#   'RB_DT_JJ',
#   'DT_JJ_JJS',
#   'JJ_JJS_NN',
#   'JJS_NN_VBG',
#   'NN_VBG_RP',
#   'VBG_RP_DT',
#   'RP_DT_JJ',
#   'DT_JJ_NN'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_VBN',
#   'VBZ_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_CD',
#   'RB_CD_CD'],
#  ['<s>_IN_IN',
#   'IN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_JJ',
#   'VB_JJ_IN',
#   'JJ_IN_NN'],
#  ['<s>_VBZ_CD',
#   'VBZ_CD_IN',
#   'CD_IN_IN',
#   'IN_IN_CD',
#   'IN_CD_NNP',
#   'CD_NNP_NNP',
#   'NNP_NNP_JJ',
#   'NNP_JJ_NNS',
#   'JJ_NNS_VBZ',
#   'NNS_VBZ_DT'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NNS',
#   'VBZ_NNS_TO',
#   'NNS_TO_DT',
#   'TO_DT_NNP',
#   'DT_NNP_NN'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_PRP',
#   'VBP_PRP_VBZ',
#   'PRP_VBZ_JJ',
#   'VBZ_JJ_IN',
#   'JJ_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_JJR',
#   'VB_JJR_IN',
#   'JJR_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_CC',
#   'NN_CC_IN',
#   'CC_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_CC',
#   'NNS_CC_JJ',
#   'CC_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_IN',
#   'DT_IN_NNP',
#   'IN_NNP_VBN',
#   'NNP_VBN_RB',
#   'VBN_RB_VB',
#   'RB_VB_DT',
#   'VB_DT_NNP'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_NN',
#   'VBD_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_NNS',
#   'VB_NNS_VBP',
#   'NNS_VBP_NNS',
#   'VBP_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_NN'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NNS',
#   'PRP$_NNS_CD',
#   'NNS_CD_IN',
#   'CD_IN_NNS',
#   'IN_NNS_VBP',
#   'NNS_VBP_NN'],
#  ['<s>_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_CD',
#   'JJ_CD_NNS',
#   'CD_NNS_NNP',
#   'NNS_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_JJ',
#   'VBN_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_JJ',
#   'IN_JJ_CC',
#   'JJ_CC_JJ'],
#  ['<s>_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_VBD',
#   'NN_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_NNP',
#   'TO_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_VBP',
#   'NNP_VBP_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_PRP',
#   'NNP_PRP_VBP',
#   'PRP_VBP_NNS',
#   'VBP_NNS_IN',
#   'NNS_IN_JJ'],
#  ['<s>_EX_VBZ',
#   'EX_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_WDT',
#   'NN_WDT_VBZ',
#   'WDT_VBZ_PRP$',
#   'VBZ_PRP$_DT',
#   'PRP$_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_NNS',
#   'VB_NNS_IN',
#   'NNS_IN_NN'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_CD',
#   'DT_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_CD',
#   'IN_CD_CC',
#   'CD_CC_CD',
#   'CC_CD_TO',
#   'CD_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_IN',
#   'RP_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_JJ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NN',
#   'VBZ_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_NN',
#   'RB_NN_TO',
#   'NN_TO_DT',
#   'TO_DT_JJ'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_JJS',
#   'DT_JJS_VBG',
#   'JJS_VBG_NN',
#   'VBG_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_PRP_VBP', 'PRP_VBP_TO', 'VBP_TO_DT', 'TO_DT_NNP'],
#  ['<s>_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_VBP',
#   'NN_VBP_JJ',
#   'VBP_JJ_IN',
#   'JJ_IN_NN'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_PRP',
#   'VBD_PRP_DT',
#   'PRP_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_WP',
#   'NN_WP_MD',
#   'WP_MD_VB',
#   'MD_VB_NNP',
#   'VB_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_IN',
#   'CC_IN_CD'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NNS',
#   'VBD_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_RB',
#   'NN_RB_IN',
#   'RB_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_WDT',
#   'NN_WDT_VBD',
#   'WDT_VBD_IN',
#   'VBD_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_VBD',
#   'PRP_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_IN'],
#  ['<s>_VBZ_NNP', 'VBZ_NNP_JJ', 'NNP_JJ_NNS', 'JJ_NNS_VBG', 'NNS_VBG_NNP'],
#  ['<s>_VBD_PRP',
#   'VBD_PRP_VBP',
#   'PRP_VBP_NNP',
#   'VBP_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_IN',
#   'VBZ_IN_PRP$',
#   'IN_PRP$_JJS',
#   'PRP$_JJS_IN',
#   'JJS_IN_DT',
#   'IN_DT_NNP'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_WP',
#   'NNP_WP_PRP',
#   'WP_PRP_RB',
#   'PRP_RB_VBP',
#   'RB_VBP_IN',
#   'VBP_IN_IN',
#   'IN_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_JJ',
#   'RB_JJ_CC',
#   'JJ_CC_JJR',
#   'CC_JJR_IN',
#   'JJR_IN_WP',
#   'IN_WP_PRP',
#   'WP_PRP_VBP',
#   'PRP_VBP_IN'],
#  ['<s>_IN_CD',
#   'IN_CD_JJR',
#   'CD_JJR_NNS',
#   'JJR_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_VBD',
#   'IN_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_DT',
#   'DT_DT_NNS',
#   'DT_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_WDT',
#   'NN_WDT_MD',
#   'WDT_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_MD',
#   'CD_MD_VB',
#   'MD_VB_DT',
#   'VB_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_VBG',
#   'DT_VBG_NN',
#   'VBG_NN_CC',
#   'NN_CC_NNS',
#   'CC_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_WP',
#   'NNS_WP_VBD',
#   'WP_VBD_PRP$',
#   'VBD_PRP$_NN',
#   'PRP$_NN_CC',
#   'NN_CC_VBD',
#   'CC_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_PRP$'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_NN',
#   'NNP_NN_NNP',
#   'NN_NNP_NN',
#   'NNP_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_VBN',
#   'VB_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_RB',
#   'IN_RB_VBG',
#   'RB_VBG_PRP$'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_VBZ',
#   'NN_VBZ_VBN',
#   'VBZ_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_CD',
#   'VB_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_VBG',
#   'NN_VBG_JJR',
#   'VBG_JJR_IN',
#   'JJR_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_CD'],
#  ['<s>_NNP_DT',
#   'NNP_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_TO',
#   'NN_TO_CD',
#   'TO_CD_CD',
#   'CD_CD_DT',
#   'CD_DT_NN',
#   'DT_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_VB',
#   'VB_VB_RP',
#   'VB_RP_DT',
#   'RP_DT_CD',
#   'DT_CD_NNPS',
#   'CD_NNPS_IN',
#   'NNPS_IN_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_WRB',
#   'NNP_WRB_PRP',
#   'WRB_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_TO',
#   'VBD_TO_NNP',
#   'TO_NNP_CC',
#   'NNP_CC_VBD',
#   'CC_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_RB',
#   'NN_RB_NNP',
#   'RB_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_VBD',
#   'CC_VBD_DT',
#   'VBD_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_IN',
#   'NN_IN_VBG',
#   'IN_VBG_IN'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_VBG',
#   'VBZ_VBG_RP',
#   'VBG_RP_DT',
#   'RP_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_JJ',
#   'NN_JJ_NN',
#   'JJ_NN_RB',
#   'NN_RB_VBG',
#   'RB_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_NN',
#   'VB_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_CC',
#   'PRP_CC_DT',
#   'CC_DT_VBD',
#   'DT_VBD_RB',
#   'VBD_RB_IN',
#   'RB_IN_IN',
#   'IN_IN_WP',
#   'IN_WP_PRP',
#   'WP_PRP_VBD',
#   'PRP_VBD_VBG',
#   'VBD_VBG_CC',
#   'VBG_CC_PRP$',
#   'CC_PRP$_NN',
#   'PRP$_NN_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_VBD',
#   'RB_VBD_DT',
#   'VBD_DT_CD',
#   'DT_CD_NN',
#   'CD_NN_JJ'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_NN',
#   'NN_NN_VBP',
#   'NN_VBP_VBN',
#   'VBP_VBN_RP',
#   'VBN_RP_IN',
#   'RP_IN_IN',
#   'IN_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_RB',
#   'CD_RB_TO',
#   'RB_TO_IN',
#   'TO_IN_CD'],
#  ['<s>_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_VBG',
#   'VBZ_VBG_IN',
#   'VBG_IN_JJR',
#   'IN_JJR_IN',
#   'JJR_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_DT'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_NN',
#   'NNS_NN_NNS',
#   'NN_NNS_MD',
#   'NNS_MD_RB',
#   'MD_RB_RB',
#   'RB_RB_VBP',
#   'RB_VBP_TO',
#   'VBP_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_NNS',
#   'RP_NNS_NNS',
#   'NNS_NNS_CC',
#   'NNS_CC_NNS'],
#  ['<s>_IN_PRP$',
#   'IN_PRP$_CD',
#   'PRP$_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_WP',
#   'NNS_WP_VBP',
#   'WP_VBP_NNP',
#   'VBP_NNP_CD',
#   'NNP_CD_IN',
#   'CD_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_VBP',
#   'NN_VBP_IN',
#   'VBP_IN_CD',
#   'IN_CD_NNS'],
#  ['<s>_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_VBG',
#   'NNS_VBG_NN',
#   'VBG_NN_NNS',
#   'NN_NNS_VBP',
#   'NNS_VBP_RB',
#   'VBP_RB_VBN',
#   'RB_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_NN',
#   'IN_NN_JJ',
#   'NN_JJ_TO',
#   'JJ_TO_JJ',
#   'TO_JJ_NN',
#   'JJ_NN_NN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_DT',
#   'NNS_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_VB',
#   'NN_VB_RP',
#   'VB_RP_IN',
#   'RP_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_NN',
#   'IN_NN_PRP$',
#   'NN_PRP$_VBN',
#   'PRP$_VBN_RP',
#   'VBN_RP_IN',
#   'RP_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_IN'],
#  ['<s>_DT_NNP',
#   'DT_NNP_RB',
#   'NNP_RB_VBD',
#   'RB_VBD_JJ',
#   'VBD_JJ_NNS',
#   'JJ_NNS_NNS',
#   'NNS_NNS_WDT',
#   'NNS_WDT_VBD',
#   'WDT_VBD_JJ',
#   'VBD_JJ_IN',
#   'JJ_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_DT',
#   'NN_DT_NNP',
#   'DT_NNP_VBD',
#   'NNP_VBD_RB',
#   'VBD_RB_VBG',
#   'RB_VBG_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_MD',
#   'NN_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_IN',
#   'VB_IN_CD'],
#  ['<s>_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_VBG',
#   'VBZ_VBG_NNS',
#   'VBG_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJS',
#   'DT_JJS_NN',
#   'JJS_NN_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_RB',
#   'VBD_RB_TO',
#   'RB_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_PRP',
#   'NNS_PRP_MD',
#   'PRP_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_RB',
#   'VB_RB_CC',
#   'RB_CC_MD',
#   'CC_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_VBN',
#   'VB_VBN_IN',
#   'VBN_IN_WP',
#   'IN_WP_PRP'],
#  ['<s>_VB_NNP',
#   'VB_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_VBP',
#   'NNP_VBP_NNS',
#   'VBP_NNS_WP',
#   'NNS_WP_VBP',
#   'WP_VBP_RB',
#   'VBP_RB_VBG',
#   'RB_VBG_IN',
#   'VBG_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_DT',
#   'RB_DT_RBS',
#   'DT_RBS_JJ',
#   'RBS_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_TO',
#   'NNP_TO_VB',
#   'TO_VB_DT'],
#  ['<s>_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_NNS',
#   'VBN_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_PRP'],
#  ['<s>_IN_NNS',
#   'IN_NNS_NN',
#   'NNS_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_CD',
#   'IN_CD_NNS',
#   'CD_NNS_NNPS',
#   'NNS_NNPS_VBD',
#   'NNPS_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_PRP$',
#   'IN_PRP$_CD',
#   'PRP$_CD_NN'],
#  ['<s>_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_DT',
#   'CD_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_CD'],
#  ['<s>_VBZ_CD',
#   'VBZ_CD_NNP',
#   'CD_NNP_NNS',
#   'NNP_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_RB',
#   'IN_RB_CD'],
#  ['<s>_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_CD',
#   'VB_CD_CD',
#   'CD_CD_DT',
#   'CD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_VBD',
#   'NNS_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_TO',
#   'VB_TO_PRP$',
#   'TO_PRP$_JJ',
#   'PRP$_JJ_VBN',
#   'JJ_VBN_NN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_VBZ',
#   'NNP_VBZ_NNP',
#   'VBZ_NNP_PRP',
#   'NNP_PRP_VBD',
#   'PRP_VBD_RP',
#   'VBD_RP_NNP',
#   'RP_NNP_VBZ',
#   'NNP_VBZ_NN',
#   'VBZ_NN_CC',
#   'NN_CC_VBD',
#   'CC_VBD_JJR',
#   'VBD_JJR_IN',
#   'JJR_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_TO',
#   'CD_TO_NNP',
#   'TO_NNP_CC',
#   'NNP_CC_JJ',
#   'CC_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_RBR',
#   'VBD_RBR_NNS',
#   'RBR_NNS_VBG',
#   'NNS_VBG_NN',
#   'VBG_NN_NNS',
#   'NN_NNS_NNS',
#   'NNS_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_CD',
#   'DT_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_CC',
#   'CD_CC_IN',
#   'CC_IN_PRP',
#   'IN_PRP_VBP'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NNS',
#   'VBZ_NNS_TO',
#   'NNS_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_NNS',
#   'VB_NNS_TO',
#   'NNS_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_NNP',
#   'JJ_NNP_NN',
#   'NNP_NN_IN',
#   'NN_IN_JJ'],
#  ['<s>_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_CC',
#   'NNS_CC_NNS',
#   'CC_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_WP',
#   'NNS_WP_RB',
#   'WP_RB_RB',
#   'RB_RB_VB',
#   'RB_VB_DT'],
#  ['<s>_DT_NN', 'DT_NN_NNS', 'NN_NNS_VBP'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_JJ',
#   'VBD_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_DT',
#   'VB_DT_JJR',
#   'DT_JJR_NN',
#   'JJR_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_RB',
#   'IN_RB_NNP'],
#  ['<s>_DT_NNS',
#   'DT_NNS_IN',
#   'NNS_IN_PRP',
#   'IN_PRP_VBD',
#   'PRP_VBD_NN',
#   'VBD_NN_DT',
#   'NN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_RB',
#   'NNP_RB_VBD',
#   'RB_VBD_JJR',
#   'VBD_JJR_NNS',
#   'JJR_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_RB',
#   'VBP_RB_RB',
#   'RB_RB_RB',
#   'RB_RB_TO',
#   'RB_TO_PRP$',
#   'TO_PRP$_CD',
#   'PRP$_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_VBG',
#   'IN_VBG_CD',
#   'VBG_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_CD'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_IN',
#   'VBD_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_NNP',
#   'VB_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VB',
#   'NN_VB_NNS',
#   'VB_NNS_RB',
#   'NNS_RB_RB',
#   'RB_RB_TO'],
#  ['<s>_NNS_VBP',
#   'NNS_VBP_DT',
#   'VBP_DT_JJ',
#   'DT_JJ_DT',
#   'JJ_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_NN',
#   'VB_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_JJ'],
#  ['<s>_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_NNS',
#   'VBD_NNS_VBG',
#   'NNS_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_CD',
#   'RP_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_CC',
#   'JJ_CC_JJ',
#   'CC_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT'],
#  ['<s>_NN_VBZ',
#   'NN_VBZ_IN',
#   'VBZ_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_VBG',
#   'IN_VBG_NNS',
#   'VBG_NNS_NN',
#   'NNS_NN_VBP',
#   'NN_VBP_RB',
#   'VBP_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_IN',
#   'VBP_IN_NN',
#   'IN_NN_VBZ',
#   'NN_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_CC',
#   'NN_CC_VBZ',
#   'CC_VBZ_WP',
#   'VBZ_WP_PRP'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_TO'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_WP',
#   'NN_WP_VBZ',
#   'WP_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_VBP',
#   'NNS_VBP_DT',
#   'VBP_DT_NNS',
#   'DT_NNS_JJ',
#   'NNS_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_IN',
#   'IN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_CD'],
#  ['<s>_IN_RB',
#   'IN_RB_CD',
#   'RB_CD_NNS',
#   'CD_NNS_VBG',
#   'NNS_VBG_IN',
#   'VBG_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_JJ',
#   'NNP_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_CC',
#   'NN_CC_NN',
#   'CC_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_JJR',
#   'VBD_JJR_NN',
#   'JJR_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_DT',
#   'IN_DT_CD',
#   'DT_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_RB'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_JJ',
#   'VBN_JJ_NN',
#   'JJ_NN_VBZ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_RP',
#   'VBN_RP_CD',
#   'RP_CD_CD',
#   'CD_CD_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_RB',
#   'RB_RB_VBN',
#   'RB_VBN_IN'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_RB',
#   'NN_RB_VBZ',
#   'RB_VBZ_JJ'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_VBG',
#   'VBN_VBG_IN',
#   'VBG_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_TO',
#   'NNP_TO_NN',
#   'TO_NN_CD',
#   'NN_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP'],
#  ['<s>_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_IN',
#   'NNP_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_VBG',
#   'VBN_VBG_IN'],
#  ['<s>_VBD_RB',
#   'VBD_RB_VBG',
#   'RB_VBG_CD',
#   'VBG_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_IN'],
#  ['<s>_NNP_NNP', 'NNP_NNP_VBZ', 'NNP_VBZ_VBG'],
#  ['<s>_IN_CD',
#   'IN_CD_NNP',
#   'CD_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_IN'],
#  ['<s>_PRP_NNPS',
#   'PRP_NNPS_VBP',
#   'NNPS_VBP_VBN',
#   'VBP_VBN_JJ',
#   'VBN_JJ_NN',
#   'JJ_NN_VBG',
#   'NN_VBG_NNS',
#   'VBG_NNS_CC',
#   'NNS_CC_VBG',
#   'CC_VBG_PRP$'],
#  ['<s>_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_VBD',
#   'NNP_VBD_PRP$',
#   'VBD_PRP$_NN',
#   'PRP$_NN_NN',
#   'NN_NN_CC',
#   'NN_CC_MD',
#   'CC_MD_RB',
#   'MD_RB_RB',
#   'RB_RB_VB',
#   'RB_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_VBD',
#   'NNS_VBD_RB',
#   'VBD_RB_JJ',
#   'RB_JJ_EX',
#   'JJ_EX_VBD',
#   'EX_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN'],
#  ['<s>_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_TO',
#   'VBP_TO_VB',
#   'TO_VB_PRP',
#   'VB_PRP_CC',
#   'PRP_CC_RB',
#   'CC_RB_PDT',
#   'RB_PDT_PRP$',
#   'PDT_PRP$_JJ',
#   'PRP$_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_TO'],
#  ['<s>_NN_DT',
#   'NN_DT_JJ',
#   'DT_JJ_CD',
#   'JJ_CD_NNS',
#   'CD_NNS_VBN',
#   'NNS_VBN_IN',
#   'VBN_IN_NNS',
#   'IN_NNS_VBG',
#   'NNS_VBG_DT'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_CC',
#   'NN_CC_VBZ',
#   'CC_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_DT'],
#  ['<s>_EX_VBP',
#   'EX_VBP_CD',
#   'VBP_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_CC',
#   'NNS_CC_CD',
#   'CC_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_WDT',
#   'NNS_WDT_VBP',
#   'WDT_VBP_DT',
#   'VBP_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_PRP',
#   'IN_PRP_RB',
#   'PRP_RB_VBD',
#   'RB_VBD_VBG',
#   'VBD_VBG_TO',
#   'VBG_TO_NNP',
#   'TO_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP'],
#  ['<s>_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_JJ',
#   'RB_JJ_TO',
#   'JJ_TO_DT',
#   'TO_DT_NN',
#   'DT_NN_IN'],
#  ['<s>_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_VBZ',
#   'NN_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_IN',
#   'NN_IN_NN'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_NN',
#   'VBD_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_NNS',
#   'CC_NNS_IN'],
#  ['<s>_IN_NNP',
#   'IN_NNP_VBD',
#   'NNP_VBD_NNP',
#   'VBD_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_VBD',
#   'PRP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_PRP$',
#   'VB_PRP$_RB',
#   'PRP$_RB_VBN',
#   'RB_VBN_NNP',
#   'VBN_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_VBG',
#   'VB_VBG_IN',
#   'VBG_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_DT',
#   'NN_DT_NNS',
#   'DT_NNS_WDT',
#   'NNS_WDT_NNP',
#   'WDT_NNP_VBD'],
#  ['<s>_IN_NNP',
#   'IN_NNP_VBZ',
#   'NNP_VBZ_VBG',
#   'VBZ_VBG_PRP$',
#   'VBG_PRP$_NN',
#   'PRP$_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_TO',
#   'NN_TO_CD',
#   'TO_CD_DT',
#   'CD_DT_NN',
#   'DT_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_CD',
#   'VB_CD_JJ',
#   'CD_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_WDT',
#   'NNS_WDT_VBP',
#   'WDT_VBP_DT',
#   'VBP_DT_JJR'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_RBR',
#   'VBP_RBR_JJ',
#   'RBR_JJ_NNS',
#   'JJ_NNS_RB',
#   'NNS_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBD',
#   'PRP_VBD_CD',
#   'VBD_CD_NNS'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_VBG'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_CC',
#   'NNP_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_CD',
#   'VBD_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNPS'],
#  ['<s>_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_MD',
#   'NNS_MD_VB',
#   'MD_VB_RBS',
#   'VB_RBS_NNPS',
#   'RBS_NNPS_TO',
#   'NNPS_TO_VB',
#   'TO_VB_PRP$',
#   'VB_PRP$_NNS',
#   'PRP$_NNS_VBD',
#   'NNS_VBD_RB',
#   'VBD_RB_VBN',
#   'RB_VBN_CC',
#   'VBN_CC_NNS',
#   'CC_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_VBP',
#   'NNS_VBP_PRP$',
#   'VBP_PRP$_JJ',
#   'PRP$_JJ_NN'],
#  ['<s>_JJ_NNS',
#   'JJ_NNS_VBP',
#   'NNS_VBP_RBR',
#   'VBP_RBR_NN',
#   'RBR_NN_VBG',
#   'NN_VBG_IN',
#   'VBG_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_CC',
#   'NNS_CC_DT',
#   'CC_DT_VBZ',
#   'DT_VBZ_DT'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_CD'],
#  ['<s>_EX_VBP',
#   'EX_VBP_RB',
#   'VBP_RB_RBR',
#   'RB_RBR_JJ',
#   'RBR_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_IN',
#   'IN_IN_NN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_JJ',
#   'NNP_JJ_NN',
#   'JJ_NN_NNP',
#   'NN_NNP_NNPS',
#   'NNP_NNPS_RB',
#   'NNPS_RB_NN',
#   'RB_NN_IN',
#   'NN_IN_VBG',
#   'IN_VBG_DT',
#   'VBG_DT_JJ',
#   'DT_JJ_VBD',
#   'JJ_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_WDT',
#   'NN_WDT_MD',
#   'WDT_MD_RB',
#   'MD_RB_VB',
#   'RB_VB_JJ',
#   'VB_JJ_NNS',
#   'JJ_NNS_CC',
#   'NNS_CC_NNS',
#   'CC_NNS_IN',
#   'NNS_IN_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_NNS',
#   'IN_NNS_VBN',
#   'NNS_VBN_NN',
#   'VBN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP'],
#  ['<s>_NNP_VBD',
#   'NNP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_NN',
#   'VB_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NNS',
#   'NN_NNS_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_RB',
#   'RB_RB_CD',
#   'RB_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_CC',
#   'NN_CC_IN',
#   'CC_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_DT',
#   'VBN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_WRB',
#   'NNP_WRB_PRP',
#   'WRB_PRP_VBZ',
#   'PRP_VBZ_TO',
#   'VBZ_TO_NN',
#   'TO_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_JJ'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_IN',
#   'VBD_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_IN',
#   'NNPS_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_NNP',
#   'IN_NNP_RB',
#   'NNP_RB_RB',
#   'RB_RB_IN',
#   'RB_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_VBN',
#   'VBP_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBG',
#   'NN_VBG_DT',
#   'VBG_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NNS'],
#  ['<s>_NN_NNS',
#   'NN_NNS_VBP',
#   'NNS_VBP_VBN',
#   'VBP_VBN_RP',
#   'VBN_RP_CD',
#   'RP_CD_IN',
#   'CD_IN_NNP',
#   'IN_NNP_VBD'],
#  ['<s>_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_WDT',
#   'NN_WDT_MD',
#   'WDT_MD_NN',
#   'MD_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_JJ'],
#  ['<s>_VBZ_NNS',
#   'VBZ_NNS_VB',
#   'NNS_VB_JJR',
#   'VB_JJR_NNS',
#   'JJR_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJR',
#   'DT_JJR_NN',
#   'JJR_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_RB',
#   'NN_RB_IN',
#   'RB_IN_DT'],
#  ['<s>_EX_VBP',
#   'EX_VBP_DT',
#   'VBP_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_WDT',
#   'NN_WDT_VBP',
#   'WDT_VBP_VBN'],
#  ['<s>_JJ_NNS',
#   'JJ_NNS_VBP',
#   'NNS_VBP_CD',
#   'VBP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_IN'],
#  ['<s>_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_RP',
#   'VB_RP_JJR',
#   'RP_JJR_IN',
#   'JJR_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_IN',
#   'NN_IN_IN',
#   'IN_IN_NN',
#   'IN_NN_NN'],
#  ['<s>_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_NNS',
#   'NN_NNS_VBD',
#   'NNS_VBD_VBN',
#   'VBD_VBN_IN',
#   'VBN_IN_NNP',
#   'IN_NNP_PRP',
#   'NNP_PRP_VBZ',
#   'PRP_VBZ_NNP',
#   'VBZ_NNP_DT',
#   'NNP_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_IN_NNP',
#   'IN_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_PRP$',
#   'NN_PRP$_NN',
#   'PRP$_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_CD',
#   'VB_CD_IN',
#   'CD_IN_DT'],
#  ['<s>_EX_VBP',
#   'EX_VBP_JJR',
#   'VBP_JJR_NN',
#   'JJR_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_IN',
#   'NNPS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN'],
#  ['<s>_NNP_NNS',
#   'NNP_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_IN',
#   'JJ_IN_VBG',
#   'IN_VBG_CD',
#   'VBG_CD_CD',
#   'CD_CD_CC',
#   'CD_CC_NN'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_JJ',
#   'VBZ_JJ_IN',
#   'JJ_IN_NN',
#   'IN_NN_VBG',
#   'NN_VBG_VBN',
#   'VBG_VBN_PRP',
#   'VBN_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_RB',
#   'VB_RB_IN',
#   'RB_IN_CD',
#   'IN_CD_CC',
#   'CD_CC_RB',
#   'CC_RB_IN',
#   'RB_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_PRP',
#   'NNS_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_CD',
#   'VB_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_VBP'],
#  ['<s>_PRP_VBZ',
#   'PRP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_NNS',
#   'NN_NNS_VBP',
#   'NNS_VBP_RB',
#   'VBP_RB_RB',
#   'RB_RB_DT',
#   'RB_DT_JJ',
#   'DT_JJ_JJ',
#   'JJ_JJ_IN',
#   'JJ_IN_NNP',
#   'IN_NNP_TO',
#   'NNP_TO_VB',
#   'TO_VB_PRP$',
#   'VB_PRP$_NN',
#   'PRP$_NN_CC',
#   'NN_CC_NN',
#   'CC_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNPS',
#   'NNP_NNPS_NN',
#   'NNPS_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_VBD',
#   'NN_VBD_VBN',
#   'VBD_VBN_RB',
#   'VBN_RB_IN'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_RP',
#   'VBD_RP_DT',
#   'RP_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_IN',
#   'NN_IN_IN',
#   'IN_IN_DT',
#   'IN_DT_NN'],
#  ['<s>_DT_NNPS',
#   'DT_NNPS_VBP',
#   'NNPS_VBP_CD',
#   'VBP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_NNP_SYM',
#   'NNP_SYM_VB',
#   'SYM_VB_NNPS',
#   'VB_NNPS_NN',
#   'NNPS_NN_NN',
#   'NN_NN_VBG',
#   'NN_VBG_IN',
#   'VBG_IN_NNP',
#   'IN_NNP_VBG',
#   'NNP_VBG_DT',
#   'VBG_DT_JJR',
#   'DT_JJR_NN',
#   'JJR_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_NNS',
#   'PRP$_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_VBZ_IN',
#   'VBZ_IN_IN',
#   'IN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NNP',
#   'NN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_TO',
#   'VBD_TO_NN',
#   'TO_NN_NNP',
#   'NN_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_VBD',
#   'NNP_VBD_JJR',
#   'VBD_JJR_NN',
#   'JJR_NN_IN',
#   'NN_IN_JJR',
#   'IN_JJR_RB',
#   'JJR_RB_JJ',
#   'RB_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_VBG',
#   'IN_VBG_CC',
#   'VBG_CC_VBG',
#   'CC_VBG_NN',
#   'VBG_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN'],
#  ['<s>_DT_JJ',
#   'DT_JJ_CD',
#   'JJ_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_CD',
#   'DT_CD_JJ',
#   'CD_JJ_NNS',
#   'JJ_NNS_WP',
#   'NNS_WP_RB',
#   'WP_RB_VBD',
#   'RB_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_DT',
#   'VB_DT_CD',
#   'DT_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_VBG',
#   'IN_VBG_NN',
#   'VBG_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_CD'],
#  ['<s>_IN_NNP',
#   'IN_NNP_DT',
#   'NNP_DT_NNP',
#   'DT_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_JJ',
#   'JJ_JJ_NNS',
#   'JJ_NNS_JJ',
#   'NNS_JJ_IN',
#   'JJ_IN_WP',
#   'IN_WP_MD',
#   'WP_MD_VB',
#   'MD_VB_CD',
#   'VB_CD_NN',
#   'CD_NN_VBZ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_IN',
#   'VBD_IN_VBG',
#   'IN_VBG_NNP',
#   'VBG_NNP_NNP',
#   'NNP_NNP_TO',
#   'NNP_TO_VB',
#   'TO_VB_NNP',
#   'VB_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_VBD',
#   'NNP_VBD_JJ',
#   'VBD_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_JJ'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_NN',
#   'NNS_NN_DT',
#   'NN_DT_PRP',
#   'DT_PRP_VBP',
#   'PRP_VBP_VBD',
#   'VBP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_VBZ',
#   'VB_VBZ_VB',
#   'VBZ_VB_TO',
#   'VB_TO_DT',
#   'TO_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_PRP',
#   'DT_PRP_VBP',
#   'PRP_VBP_VBD',
#   'VBP_VBD_TO',
#   'VBD_TO_VB',
#   'TO_VB_VBZ',
#   'VB_VBZ_NN',
#   'VBZ_NN_PRP',
#   'NN_PRP_TO',
#   'PRP_TO_PRP$',
#   'TO_PRP$_NN',
#   'PRP$_NN_CC',
#   'NN_CC_PRP',
#   'CC_PRP_VBP',
#   'PRP_VBP_VBG',
#   'VBP_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_CD'],
#  ['<s>_RB_CD',
#   'RB_CD_NNP',
#   'CD_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NNS',
#   'DT_NNS_TO',
#   'NNS_TO_VB',
# ...
#   'CC_VBN_RP',
#   'VBN_RP_NNS',
#   'RP_NNS_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_CD',
#   'VBZ_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_NNP',
#   'NN_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_RB'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_IN',
#   'NN_IN_DT'],
#  ['<s>_NNP_RB',
#   'NNP_RB_VBZ',
#   'RB_VBZ_DT',
#   'VBZ_DT_IN',
#   'DT_IN_PRP$',
#   'IN_PRP$_JJ',
#   'PRP$_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_PRP',
#   'NN_PRP_MD',
#   'PRP_MD_VB'],
#  ['<s>_DT_CD',
#   'DT_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_JJ',
#   'NN_JJ_NN',
#   'JJ_NN_VBD',
#   'NN_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_VBN',
#   'VBD_VBN_PRP$',
#   'VBN_PRP$_JJ'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_WDT',
#   'IN_WDT_NN',
#   'WDT_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_RP',
#   'VB_RP_PRP$',
#   'RP_PRP$_NNS',
#   'PRP$_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_NNS',
#   'IN_NNS_CC',
#   'NNS_CC_IN'],
#  ['<s>_DT_VBN',
#   'DT_VBN_CD',
#   'VBN_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_NN',
#   'CD_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_CD',
#   'CD_CD_RB',
#   'CD_RB_VBZ',
#   'RB_VBZ_IN',
#   'VBZ_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_VBN',
#   'NN_VBN_IN',
#   'VBN_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_DT',
#   'NN_DT_RB',
#   'DT_RB_JJ'],
#  ['<s>_VBZ_IN',
#   'VBZ_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_NN',
#   'VBP_NN_CC',
#   'NN_CC_VB',
#   'CC_VB_TO',
#   'VB_TO_VB',
#   'TO_VB_JJ',
#   'VB_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_CD',
#   'DT_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_NNP',
#   'PRP_NNP_VBZ',
#   'NNP_VBZ_RB',
#   'VBZ_RB_IN',
#   'RB_IN_JJR',
#   'IN_JJR_IN',
#   'JJR_IN_CD',
#   'IN_CD_NNS',
#   'CD_NNS_JJ',
#   'NNS_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_PRP',
#   'IN_PRP_CC',
#   'PRP_CC_PRP',
#   'CC_PRP_RB',
#   'PRP_RB_VBZ',
#   'RB_VBZ_RB',
#   'VBZ_RB_IN',
#   'RB_IN_DT'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NNP',
#   'DT_NNP_CD',
#   'NNP_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBG',
#   'NNP_VBG_NN',
#   'VBG_NN_NNS',
#   'NN_NNS_CC',
#   'NNS_CC_VBD',
#   'CC_VBD_NNS',
#   'VBD_NNS_TO',
#   'NNS_TO_DT',
#   'TO_DT_NNS',
#   'DT_NNS_WP',
#   'NNS_WP_VBD',
#   'WP_VBD_NNP',
#   'VBD_NNP_NNP'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_VBP',
#   'NNP_VBP_VB',
#   'VBP_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN'],
#  ['<s>_WRB_VBZ',
#   'WRB_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_RB',
#   'NNP_RB_VBG',
#   'RB_VBG_PRP$',
#   'VBG_PRP$_NN',
#   'PRP$_NN_NNP',
#   'NN_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_JJ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_TO',
#   'VBN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_VBP',
#   'NNS_VBP_RP',
#   'VBP_RP_NNP',
#   'RP_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_CC',
#   'NNS_CC_NN'],
#  ['<s>_NNP_NNS',
#   'NNP_NNS_VBP',
#   'NNS_VBP_NNP',
#   'VBP_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_DT',
#   'IN_DT_NNP'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_JJ',
#   'NNP_JJ_NN',
#   'JJ_NN_CC',
#   'NN_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_CD',
#   'VBN_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_IN',
#   'IN_IN_NN',
#   'IN_NN_CC',
#   'NN_CC_VBN',
#   'CC_VBN_CD',
#   'VBN_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_PRP$',
#   'IN_PRP$_JJ'],
#  ['<s>_RB_VB',
#   'RB_VB_WRB',
#   'VB_WRB_DT',
#   'WRB_DT_NN',
#   'DT_NN_RB',
#   'NN_RB_VBD',
#   'RB_VBD_RB',
#   'VBD_RB_IN',
#   'RB_IN_NNPS',
#   'IN_NNPS_IN',
#   'NNPS_IN_VBG',
#   'IN_VBG_PRP',
#   'VBG_PRP_VBD',
#   'PRP_VBD_PRP',
#   'VBD_PRP_VBD',
#   'PRP_VBD_NN',
#   'VBD_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_VBD',
#   'PRP_VBD_PRP$',
#   'VBD_PRP$_NN',
#   'PRP$_NN_FW',
#   'NN_FW_RB',
#   'FW_RB_CD',
#   'RB_CD_NN',
#   'CD_NN_VBZ',
#   'NN_VBZ_RB',
#   'VBZ_RB_VBN',
#   'RB_VBN_RB',
#   'VBN_RB_IN',
#   'RB_IN_PRP$'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_JJS',
#   'JJ_JJS_NN',
#   'JJS_NN_IN',
#   'NN_IN_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_NN',
#   'VBZ_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNS',
#   'IN_NNS_CC',
#   'NNS_CC_NNS',
#   'CC_NNS_IN',
#   'NNS_IN_JJ'],
#  ['<s>_VBZ_NN',
#   'VBZ_NN_IN',
#   'NN_IN_VBN',
#   'IN_VBN_JJ',
#   'VBN_JJ_NNP',
#   'JJ_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_VBZ',
#   'NN_VBZ_CD',
#   'VBZ_CD_NNS',
#   'CD_NNS_RB',
#   'NNS_RB_IN',
#   'RB_IN_WRB',
#   'IN_WRB_JJ',
#   'WRB_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_VBD'],
#  ['<s>_PRP$_NN',
#   'PRP$_NN_NN',
#   'NN_NN_VBD',
#   'NN_VBD_RB',
#   'VBD_RB_IN',
#   'RB_IN_NNP',
#   'IN_NNP_VBN',
#   'NNP_VBN_IN'],
#  ['<s>_JJ_JJ',
#   'JJ_JJ_NNS',
#   'JJ_NNS_VBP',
#   'NNS_VBP_CD',
#   'VBP_CD_NN',
#   'CD_NN_RBR',
#   'NN_RBR_JJ',
#   'RBR_JJ_TO',
#   'JJ_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_JJ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBD',
#   'NN_VBD_JJR',
#   'VBD_JJR_NNS',
#   'JJR_NNS_IN',
#   'NNS_IN_RB',
#   'IN_RB_CD',
#   'RB_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_VBD',
#   'NNS_VBD_IN',
#   'VBD_IN_IN',
#   'IN_IN_DT'],
#  ['<s>_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_RB',
#   'VBD_RB_VBN',
#   'RB_VBN_DT',
#   'VBN_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_CC',
#   'VB_CC_VB',
#   'CC_VB_IN',
#   'VB_IN_VBG',
#   'IN_VBG_CD',
#   'VBG_CD_CD',
#   'CD_CD_TO',
#   'CD_TO_CD'],
#  ['<s>_WRB_PRP',
#   'WRB_PRP_VBP',
#   'PRP_VBP_VBD',
#   'VBP_VBD_NNS',
#   'VBD_NNS_VBG',
#   'NNS_VBG_RBR',
#   'VBG_RBR_IN',
#   'RBR_IN_CD',
#   'IN_CD_NNS',
#   'CD_NNS_IN',
#   'NNS_IN_JJ',
#   'IN_JJ_NNS',
#   'JJ_NNS_VBP',
#   'NNS_VBP_VBG',
#   'VBP_VBG_IN',
#   'VBG_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_RB',
#   'NN_RB_NN',
#   'RB_NN_VBZ'],
#  ['<s>_VBZ_CD',
#   'VBZ_CD_NN',
#   'CD_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBP'],
#  ['<s>_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_NNS',
#   'NN_NNS_TO',
#   'NNS_TO_JJ',
#   'TO_JJ_NNS',
#   'JJ_NNS_WP',
#   'NNS_WP_VBP',
#   'WP_VBP_RB',
#   'VBP_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_VBG'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_JJS',
#   'DT_JJS_NNS',
#   'JJS_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_IN'],
#  ['<s>_VBZ_NNP',
#   'VBZ_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_NNP',
#   'NN_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_VBN',
#   'VBD_VBN_IN',
#   'VBN_IN_NNP',
#   'IN_NNP_NNP'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NNP',
#   'VBD_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBG',
#   'NN_VBG_RP',
#   'VBG_RP_JJ',
#   'RP_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_PRP$'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_VBD',
#   'NN_VBD_RB',
#   'VBD_RB_VBG',
#   'RB_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_VBZ',
#   'NN_VBZ_VBN',
#   'VBZ_VBN_JJ',
#   'VBN_JJ_NNS',
#   'JJ_NNS_IN'],
#  ['<s>_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_RB',
#   'NNP_RB_VBZ',
#   'RB_VBZ_DT',
#   'VBZ_DT_NNP',
#   'DT_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_RB',
#   'NN_RB_NNP',
#   'RB_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_DT',
#   'VB_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_JJ',
#   'IN_JJ_JJ'],
#  ['<s>_NN_VBZ', 'NN_VBZ_IN', 'VBZ_IN_NNS', 'IN_NNS_IN'],
#  ['<s>_NNPS_VBP',
#   'NNPS_VBP_CD',
#   'VBP_CD_CD',
#   'CD_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_DT',
#   'NNS_DT_NN',
#   'DT_NN_VBG',
#   'NN_VBG_IN',
#   'VBG_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_PRP',
#   'NN_PRP_VBZ',
#   'PRP_VBZ_PRP',
#   'VBZ_PRP_CD',
#   'PRP_CD_CD',
#   'CD_CD_TO',
#   'CD_TO_VB',
#   'TO_VB_IN',
#   'VB_IN_PRP$',
#   'IN_PRP$_NN',
#   'PRP$_NN_NNS'],
#  ['<s>_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_DT',
#   'NN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_MD',
#   'NNP_MD_VB',
#   'MD_VB_IN',
#   'VB_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_IN',
#   'NN_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_PRP',
#   'VBD_PRP_VBG',
#   'PRP_VBG_DT',
#   'VBG_DT_NN',
#   'DT_NN_PRP$',
#   'NN_PRP$_DT',
#   'PRP$_DT_NNP',
#   'DT_NNP_IN',
#   'NNP_IN_NN',
#   'IN_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_NN',
#   'PRP_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_CC',
#   'NN_CC_DT',
#   'CC_DT_NN',
#   'DT_NN_VBG'],
#  ['<s>_NNP_NNS',
#   'NNP_NNS_VBP',
#   'NNS_VBP_JJ',
#   'VBP_JJ_IN',
#   'JJ_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_JJ',
#   'NN_JJ_JJ',
#   'JJ_JJ_IN',
#   'JJ_IN_VBG',
#   'IN_VBG_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_NN',
#   'IN_NN_JJ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_NN',
#   'DT_NN_VBN',
#   'NN_VBN_IN',
#   'VBN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NNS',
#   'NNP_NNS_VBD',
#   'NNS_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_DT',
#   'TO_DT_NNP'],
#  ['<s>_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_JJ',
#   'DT_JJ_JJS',
#   'JJ_JJS_NN',
#   'JJS_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_IN_NNP',
#   'IN_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_VBN',
#   'VBD_VBN_VBG',
#   'VBN_VBG_RP',
#   'VBG_RP_DT',
#   'RP_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_RB',
#   'IN_RB_VBG',
#   'RB_VBG_NNS',
#   'VBG_NNS_TO'],
#  ['<s>_PRP_VBP',
#   'PRP_VBP_RB',
#   'VBP_RB_RB',
#   'RB_RB_NNP',
#   'RB_NNP_WDT',
#   'NNP_WDT_VBZ',
#   'WDT_VBZ_VBG',
#   'VBZ_VBG_IN',
#   'VBG_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_IN',
#   'NNP_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_WDT',
#   'NNP_WDT_VBZ',
#   'WDT_VBZ_DT',
#   'VBZ_DT_RB',
#   'DT_RB_JJ',
#   'RB_JJ_CC',
#   'JJ_CC_JJ',
#   'CC_JJ_NN',
#   'JJ_NN_TO',
#   'NN_TO_DT',
#   'TO_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_IN'],
#  ['<s>_VBZ_VBG',
#   'VBZ_VBG_NNS',
#   'VBG_NNS_IN',
#   'NNS_IN_NN',
#   'IN_NN_NNS',
#   'NN_NNS_CC',
#   'NNS_CC_NN',
#   'CC_NN_MD',
#   'NN_MD_VB',
#   'MD_VB_CD'],
#  ['<s>_DT_JJ',
#   'DT_JJ_CD',
#   'JJ_CD_NNS',
#   'CD_NNS_VBG',
#   'NNS_VBG_DT',
#   'VBG_DT_NN',
#   'DT_NN_VBZ',
#   'NN_VBZ_NNP',
#   'VBZ_NNP_NN',
#   'NNP_NN_VBP',
#   'NN_VBP_IN',
#   'VBP_IN_PRP',
#   'IN_PRP_VBD',
#   'PRP_VBD_NNP',
#   'VBD_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_CD',
#   'IN_CD_CC',
#   'CD_CC_CD'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NN',
#   'VBD_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_CD',
#   'DT_CD_CD',
#   'CD_CD_NNS',
#   'CD_NNS_CC',
#   'NNS_CC_CD',
#   'CC_CD_CD',
#   'CD_CD_JJ',
#   'CD_JJ_NN',
#   'JJ_NN_VBN',
#   'NN_VBN_TO',
#   'VBN_TO_DT',
#   'TO_DT_NN',
#   'DT_NN_CC',
#   'NN_CC_NN'],
#  ['<s>_IN_PRP',
#   'IN_PRP_VBP',
#   'PRP_VBP_NN',
#   'VBP_NN_NN',
#   'NN_NN_PRP',
#   'NN_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_NNS',
#   'VB_NNS_VB',
#   'NNS_VB_RP',
#   'VB_RP_IN',
#   'RP_IN_JJ',
#   'IN_JJ_CD',
#   'JJ_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_JJ'],
#  ['<s>_VBZ_IN',
#   'VBZ_IN_WRB',
#   'IN_WRB_NNP',
#   'WRB_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_NNS',
#   'NN_NNS_TO',
#   'NNS_TO_NNS',
#   'TO_NNS_RB',
#   'NNS_RB_VBN',
#   'RB_VBN_IN',
#   'VBN_IN_NNP',
#   'IN_NNP_DT',
#   'NNP_DT_NN',
#   'DT_NN_VBD',
#   'NN_VBD_JJ',
#   'VBD_JJ_NN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBD',
#   'NNP_VBD_NNP',
#   'VBD_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_TO',
#   'NN_TO_PRP$',
#   'TO_PRP$_NNS',
#   'PRP$_NNS_JJ',
#   'NNS_JJ_NNS',
#   'JJ_NNS_WP',
#   'NNS_WP_VBD',
#   'WP_VBD_TO',
#   'VBD_TO_PRP$',
#   'TO_PRP$_NNS',
#   'PRP$_NNS_CC',
#   'NNS_CC_VBD',
#   'CC_VBD_CD',
#   'VBD_CD_CD',
#   'CD_CD_IN',
#   'CD_IN_NN',
#   'IN_NN_NN'],
#  ['<s>_JJ_TO',
#   'JJ_TO_NNS',
#   'TO_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_DT',
#   'NNP_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_JJ',
#   'NNP_JJ_NN',
#   'JJ_NN_VBD',
#   'NN_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_VBG',
#   'VB_VBG_PRP$',
#   'VBG_PRP$_NNS',
#   'PRP$_NNS_IN',
#   'NNS_IN_PRP$',
#   'IN_PRP$_JJ'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_DT',
#   'VBZ_DT_NN',
#   'DT_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_NN',
#   'VB_NN_NNS',
#   'NN_NNS_CC',
#   'NNS_CC_VBZ',
#   'CC_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_PRP$',
#   'VB_PRP$_NNS',
#   'PRP$_NNS_TO',
#   'NNS_TO_DT',
#   'TO_DT_JJS'],
#  ['<s>_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_VBD',
#   'NNPS_VBD_NNS',
#   'VBD_NNS_VBD',
#   'NNS_VBD_RP',
#   'VBD_RP_IN',
#   'RP_IN_NN',
#   'IN_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_CC',
#   'NNP_CC_RB',
#   'CC_RB_NNP',
#   'RB_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN'],
#  ['<s>_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNPS',
#   'NNP_NNPS_VB',
#   'NNPS_VB_JJ',
#   'VB_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_VBZ'],
#  ['<s>_VBZ_NNS',
#   'VBZ_NNS_VBD',
#   'NNS_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_RB',
#   'NN_RB_TO',
#   'RB_TO_VB',
#   'TO_VB_NNS',
#   'VB_NNS_CD'],
#  ['<s>_NN_IN',
#   'NN_IN_NNP',
#   'IN_NNP_VBZ',
#   'NNP_VBZ_VBN',
#   'VBZ_VBN_IN',
#   'VBN_IN_CD',
#   'IN_CD_NN',
#   'CD_NN_NNS',
#   'NN_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_IN'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_NNPS',
#   'NNP_NNPS_NNP',
#   'NNPS_NNP_NNP',
#   'NNP_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_CC',
#   'NN_CC_NNP',
#   'CC_NNP_NNP',
#   'NNP_NNP_VBP',
#   'NNP_VBP_VBG',
#   'VBP_VBG_RP',
#   'VBG_RP_NN',
#   'RP_NN_NN',
#   'NN_NN_NNS',
#   'NN_NNS_CC',
#   'NNS_CC_VBG',
#   'CC_VBG_PRP$',
#   'VBG_PRP$_NNS',
#   'PRP$_NNS_VBP',
#   'NNS_VBP_TO',
#   'VBP_TO_VB'],
#  ['<s>_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_VBG',
#   'VBZ_VBG_CD',
#   'VBG_CD_CC',
#   'CD_CC_CD',
#   'CC_CD_NN',
#   'CD_NN_JJ',
#   'NN_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_DT',
#   'NN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNS',
#   'DT_NNS_NN',
#   'NNS_NN_VBZ',
#   'NN_VBZ_DT',
#   'VBZ_DT_JJ'],
#  ['<s>_DT_CD',
#   'DT_CD_JJ',
#   'CD_JJ_NN',
#   'JJ_NN_NN',
#   'NN_NN_VBD',
#   'NN_VBD_NN',
#   'VBD_NN_TO',
#   'NN_TO_VB',
#   'TO_VB_IN'],
#  ['<s>_DT_NNPS',
#   'DT_NNPS_RB',
#   'NNPS_RB_VBP',
#   'RB_VBP_TO',
#   'VBP_TO_VB',
#   'TO_VB_NNP',
#   'VB_NNP_NNP',
#   'NNP_NNP_IN',
#   'NNP_IN_NN',
#   'IN_NN_PRP$',
#   'NN_PRP$_JJ',
#   'PRP$_JJ_NN',
#   'JJ_NN_VBZ',
#   'NN_VBZ_TO',
#   'VBZ_TO_VB',
#   'TO_VB_RP',
#   'VB_RP_DT',
#   'RP_DT_NNP',
#   'DT_NNP_NNP',
#   'NNP_NNP_NN',
#   'NNP_NN_NN',
#   'NN_NN_TO',
#   'NN_TO_NNP'],
#  ['<s>_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_DT',
#   'IN_DT_NNP',
#   'DT_NNP_NNS',
#   'NNP_NNS_NNP',
#   'NNS_NNP_VBD',
#   'NNP_VBD_DT',
#   'VBD_DT_NN',
#   'DT_NN_IN',
#   'NN_IN_PRP',
#   'IN_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_NN',
#   'VB_NN_NN',
#   'NN_NN_NN',
#   'NN_NN_VBD',
#   'NN_VBD_IN',
#   'VBD_IN_NN',
#   'IN_NN_NN',
#   'NN_NN_PRP',
#   'NN_PRP_VBD',
#   'PRP_VBD_DT',
#   'VBD_DT_JJ',
#   'DT_JJ_NN',
#   'JJ_NN_CC',
#   'NN_CC_PRP',
#   'CC_PRP_VBD',
#   'PRP_VBD_PRP',
#   'VBD_PRP_VBD',
#   'PRP_VBD_VBG',
#   'VBD_VBG_TO',
#   'VBG_TO_VB',
#   'TO_VB_PRP',
#   'VB_PRP_IN'],
#  ['<s>_VBZ_NNP', 'VBZ_NNP_NN', 'NNP_NN_VBD', 'NN_VBD_JJ', 'VBD_JJ_NN'],
#  ['<s>_CD_IN',
#   'CD_IN_DT',
#   'IN_DT_JJ',
#   'DT_JJ_NNS',
#   'JJ_NNS_IN',
#   'NNS_IN_NNP',
#   'IN_NNP_NNP',
#   'NNP_NNP_VBZ',
#   'NNP_VBZ_IN',
#   'VBZ_IN_IN',
#   'IN_IN_CD',
#   'IN_CD_WRB',
#   'CD_WRB_PRP',
#   'WRB_PRP_VBP',
#   'PRP_VBP_IN',
#   'VBP_IN_DT',
#   'IN_DT_NN',
#   'DT_NN_NN',
#   'NN_NN_JJ',
#   'NN_JJ_NN',
#   'JJ_NN_PRP',
#   'NN_PRP_VBD',
#   'PRP_VBD_RB',
#   'VBD_RB_IN',
#   'RB_IN_NNS',
#   'IN_NNS_RB',
#   'NNS_RB_PRP',
#   'RB_PRP_VBZ',
#   'PRP_VBZ_VBN',
#   'VBZ_VBN_RB',
#   'VBN_RB_RB',
#   'RB_RB_TO',
#   'RB_TO_DT',
#   'TO_DT_JJ',
#   'DT_JJ_VBG',
#   'JJ_VBG_IN',
#   'VBG_IN_PRP',
#   'IN_PRP_MD',
#   'PRP_MD_VB',
#   'MD_VB_VBN',
#   'VB_VBN_NNS',
#   'VBN_NNS_IN',
#   'NNS_IN_JJ'],
#  ...]

# %%
#
#training_data = [unigram_pos, unigram_pos_no_p, unigram_pos_no_p_u, unigram_pos_no_p_u_sw] 
#testing_data = [unigram_pos_va, unigram_pos_no_p_va, unigram_pos_no_p_u_va, unigram_pos_no_p_u_sw_va]
#training_data = [bigrams_pos, bigrams_pos_no_p, bigrams_pos_no_p_u, bigrams_pos_no_p_u_sw] 
#testing_data = [bigrams_pos_va, bigrams_pos_no_p_va, bigrams_pos_no_p_u_va, bigrams_pos_no_p_u_sw_va]
training_data = [trigram_pos, trigram_pos_no_p, trigram_pos_no_p_u, trigram_pos_no_p_u_sw] 
testing_data = [trigram_pos_va, trigram_pos_no_p_va, trigram_pos_no_p_u_va, trigram_pos_no_p_u_sw_va]
testing_title = ['RAW DATA', 'NO PUNCTUATION', 'NO PUNCTUATION LOWER CASE', 'NO PUNCTUATION LC STOP WORDS']

#trda = [fivegrams_no_punct]#training_data[1:2]
trda = [removed_pos_bigrams]
#teda = [fivegrams_no_punct_va]#testing_data[1:2]
teda = [removed_pos_bigrams_va]
tetil = testing_title[0:1]

for i, each_data in enumerate(trda):
    print("TRAINING POSTags:", tetil[i])
    print("Testing with user defined vectors")
    Xtr, Xte = PreparePOSDataForTraining(each_data, teda[i], use_built_in_vectors=False,user_defined_vocabulary=removed_unique_bigrams, binary=True)
    print(len(Xtr))
    print(len(Xte))
    Xtr = Xtr[tr_indexes]
    Xte = Xte[va_indexes]
    Ytr = binary_labels_tr[tr_indexes]
    Yte = binary_labels_va[va_indexes]
    FeatureSelector(Xtr, Xte, Ytr, Yte, removed_unique_bigrams,max_depth=2, threshold=0.000001)
    #print(pruned_features_1)
    #DecisionTreeFeaturesSelector(Xtr, Xte, Ytr, Yte)
    #ExtraTreeFeaturesSelector(Xtr, Xte, Ytr, Yte)
    #TrainModels(Xtr, Xte, Ytr, Yte)
    print("Testing with sklearn built in vectors")
    Xtr, Xte = PreparePOSDataForTraining(each_data, teda[i], use_built_in_vectors=True,user_defined_vocabulary=removed_unique_bigrams, binary=True)
    Xtr = Xtr[tr_indexes]
    Xte = Xte[va_indexes]
    Ytr = binary_labels_tr[tr_indexes]
    Yte = binary_labels_va[va_indexes]
    FeatureSelector(Xtr, Xte, Ytr, Yte, removed_unique_bigrams,max_depth=4,threshold=0.000001)
    #DecisionTreeFeaturesSelector(Xtr, Xte, Ytr, Yte)
    #ExtraTreeFeaturesSelector(Xtr, Xte, Ytr, Yte)
    #TrainModels(Xtr, Xte, Ytr, Yte)
# Out:
# TRAINING POSTags: RAW DATA
# Testing with user defined vectors
# 10240
# 1284
# Accuracy:  0.6341698841698842
#              precision    recall  f1-score   support
#
#          -1       0.68      0.19      0.29       420
#           1       0.63      0.94      0.75       616
#
# avg / total       0.65      0.63      0.57      1036
#
# IN_DT 0.5124131887226123
# JJR_IN 0.2238183439866393
# IN_CD 0.2637684672907483
# ['IN_DT', 'JJR_IN', 'IN_CD']
# Testing with sklearn built in vectors
# Accuracy:  0.637065637065637
#              precision    recall  f1-score   support
#
#          -1       0.61      0.30      0.40       420
#           1       0.64      0.87      0.74       616
#
# avg / total       0.63      0.64      0.60      1036
#
# NNPS_VBP 0.03354963221188884
# VB_NNP 0.04436437157228151
# IN_DT 0.24124833218466715
# VB_JJ 0.021399586892296856
# JJ_CD 0.06544150818477958
# CD_NNS 0.09113572726974419
# DT_JJS 0.09300468462440149
# JJR_IN 0.10537551215985723
# IN_CD 0.12418435789178366
# CC_IN 0.012212846266141244
# RB_VBD 0.02387378667836397
# CD_NN 0.0761397722681706
# NN_TO 0.01982073773294916
# JJR_JJ 0.012165139835414134
# VB_CD 0.03608400422726042
# ['NNPS_VBP', 'VB_NNP', 'IN_DT', 'VB_JJ', 'JJ_CD', 'CD_NNS', 'DT_JJS', 'JJR_IN', 'IN_CD', 'CC_IN', 'RB_VBD', 'CD_NN', 'NN_TO', 'JJR_JJ', 'VB_CD']

# %%
np.array(trigram_list_tr_no_p)[pruned_features_1]
# Out:
# array([], dtype='<U14')

# %%
def DecisionTreeFeaturesSelector(Xtr, Xte, Ytr, Yte):
    for i in range(1,10):
        print('max_depth',i)
        clf = DecisionTreeClassifier(max_depth=i)
        clf.fit(Xtr, Ytr)
        pred = clf.predict(Xte)
        print('Accuracy: ', np.mean(Yte == pred))
        print(classification_report(Yte, pred))

# %%
def ExtraTreeFeaturesSelector(Xtr, Xte, Ytr, Yte):
    for i in range(1,10):
        print('Estimators',i)
        clf = ExtraTreesClassifier(n_estimators=i, max_depth=None,min_samples_split=2, random_state=0)
        clf.fit(Xtr, Ytr)
        pred = clf.predict(Xte)
        print('Accuracy: ', np.mean(Yte == pred))
        print(classification_report(Yte, pred))

# %%
def FeatureSelector(Xtr, Xte, Ytr, Yte,feature_list,max_depth = 1,threshold=0.1):
    clf = DecisionTreeClassifier(max_depth=max_depth)
    clf.fit(Xtr, Ytr)
    pred = clf.predict(Xte)
    print('Accuracy: ', np.mean(Yte == pred))
    print(classification_report(Yte, pred)) 
    
    pos_Tags = list()
    for i,each_f in enumerate(clf.feature_importances_):
        if each_f >=threshold:
            pos_Tags.append(feature_list[i])
            print(feature_list[i], each_f)
    print(pos_Tags)
    return (clf.feature_importances_<=threshold) # return filetered features

# %% [markdown]
# # Function to vectorize data

# %%
#use_built_in_vectors => if True use CountVectorizer, otherwise it uses the version of pos_vectors in preprocessing
def PreparePOSDataForTraining(training_data, testing_data, use_built_in_vectors = False, user_defined_vocabulary=None, binary=True):
    tr_feats = []
    te_feats = []
    if(use_built_in_vectors == False):
        tr_feats, returned_dict = preprocessing.pos_vectors(training_data, vector_dictionary= user_defined_vocabulary, return_dictionary=True)
        if binary:
            te_feats = preprocessing.pos_vectors(testing_data, vector_dictionary= returned_dict)
        else:
            binary_count, te_feats = preprocessing.pos_vectors(testing_data, vector_dictionary= returned_dict, count=True)
    else:
        if user_defined_vocabulary != None:
            user_defined_vocabulary = [x.lower() for x in user_defined_vocabulary]
        training_str = [" ".join(x) for x in training_data]
        testing_str = [" ".join(x) for x in testing_data]
        tr_vectorizer = CountVectorizer(vocabulary=user_defined_vocabulary,binary=binary)
        tr_feats = tr_vectorizer.fit_transform(training_str).toarray()
        te_vectorizer = CountVectorizer(vocabulary=tr_vectorizer.get_feature_names(),binary=binary)
        te_feats = te_vectorizer.fit_transform(testing_str).toarray()
    return tr_feats, te_feats

# %% [markdown]
# # Training Different Models

# %%
def TrainModels(Xtrain, Xtest, Ytrain, Ytest):
    kf = KFold(n_splits=10, shuffle=True)
    # ,'class_weight':{1:.9, 2:.5, 3:.01}
    params = [{'max_depth':1,'criterion':'entropy'},{}, {'loss': 'log', 'penalty': 'l2', 'max_iter':1000},{},{},{}]
    Models = [DecisionTreeClassifier,LogisticRegression, linear_model.SGDClassifier, MultinomialNB, RandomForestClassifier, SVC]
    accuracy_list = list()
    accuracy_metrics = list()
    for param, Model in zip(params, Models):
        total = 0
        for train_indices, test_indices in kf.split(Xtrain):
            train_X = Xtrain[train_indices, :]; train_Y = Ytrain[train_indices]
            test_X = Xtrain[test_indices, :]; test_Y = Ytrain[test_indices]
            reg = Model(**param)
            reg.fit(train_X, train_Y)
            predictions = reg.predict(test_X)
            total += accuracy_score(test_Y, predictions)
        accuracy = total / kf.n_splits
        reg = Model(**param)
        reg.fit(Xtrain, Ytrain)
        predictions = reg.predict(Xtest)
        accuracy_list.append((Model.__name__, accuracy))
        accuracy_metrics.append((Model.__name__, classification_report(Ytest, predictions)))

    for i, value in enumerate(accuracy_list):
        print("Accuracy score of {0}: {1}".format(value[0],value[1]))
        print("accuracy metrics for {0}:\n{1}".format(accuracy_metrics[i][0], accuracy_metrics[i][1]))

#print("Accuracy score of {0}: {1}: {2}: {3}: {4}".format(accuracy_list[0], accuracy_list[]))
#print("accuracy metrics for {0}: {1}: {2}: {3}: {4}".format(Model.__name__, classification_report(y_test, predictions)))
