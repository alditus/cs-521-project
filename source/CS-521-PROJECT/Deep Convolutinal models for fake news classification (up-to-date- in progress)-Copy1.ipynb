# %%
## import dependencies
import pandas as pd
import numpy as np
import keras.utils
import nlp_util
from nltk.corpus import stopwords
import string
import re

from keras import backend as K
from keras.layers import Conv1D, Dense, Input, Lambda, LSTM
from keras.layers.merge import concatenate
from keras.layers.embeddings import Embedding

from keras.utils import to_categorical
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.text import text_to_word_sequence
from keras.preprocessing import sequence
import _pickle as cPickle

from keras.layers import Concatenate, Input, MaxPooling1D
from keras.models import Model
from keras.preprocessing.sequence import pad_sequences # To make vectors the same size. 
# from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Embedding
from keras.layers import Conv1D, GlobalMaxPool1D, MaxPool1D
from keras.optimizers import SGD
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.callbacks import TensorBoard, CSVLogger, EarlyStopping
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
## load dataset
train_file=pd.read_csv('train.tsv', sep='\t', header=None, encoding='utf-8')
test_file=pd.read_csv('test.tsv', sep='\t', header=None, encoding='utf-8')
va_file=pd.read_csv('valid.tsv', sep='\t', header=None, encoding='utf-8')

column_names = ['Id', 'Label','Statement','Subject','Speaker','Speaker Job','State Info','Party','BT','FC','HT','MT','PF','Context']
train_file.columns, test_file.columns, va_file.columns=column_names, column_names, column_names

train_data = train_file[train_file.columns[~train_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]
test_data = test_file[test_file.columns[~test_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]
val_data = va_file[va_file.columns[~va_file.columns.isin(['Id','BT','FC','HT','MT','PF'])]]

# %%
train_data.head(3)
# Out:
#          Label                                          Statement  \
# 0        false  Says the Annies List political group supports ...
# 1    half-true  When did the decline of coal start? It started...
# 2  mostly-true  Hillary Clinton agrees with John McCain "by vo...
#
#                               Subject         Speaker           Speaker Job  \
# 0                            abortion    dwayne-bohac  State representative
# 1  energy,history,job-accomplishments  scott-surovell        State delegate
# 2                      foreign-policy    barack-obama             President
#
#   State Info       Party          Context
# 0      Texas  republican         a mailer
# 1   Virginia    democrat  a floor speech.
# 2   Illinois    democrat           Denver

# %%
multi_labels_dict = {'false':0, 'true':1,'pants-fire':2,'barely-true':3,'half-true':4,'mostly-true':5}
binary_labels = {'false':1, 'true':-1,'pants-fire':1,'barely-true':1,'half-true':0,'mostly-true':-1}


def one_hot_label(label):
    return to_categorical(multi_labels_dict[x], num_classes=6)

train_data['multi_label']=train_data['Label'].apply(lambda x: multi_labels_dict[x])
test_data['multi_label']=test_data['Label'].apply(lambda x: multi_labels_dict[x])
val_data['multi_label']=val_data['Label'].apply(lambda x: multi_labels_dict[x])
# Out:
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %% [markdown]
# ### Metadata processing

# %%
speakers= ['barack-obama', 'donald-trump', 'hillary-clinton', 'mitt-romney', 
                'scott-walker', 'john-mccain', 'rick-perry', 'chain-email', 
                'marco-rubio', 'rick-scott', 'ted-cruz', 'bernie-s', 'chris-christie', 
                'facebook-posts', 'charlie-crist', 'newt-gingrich', 'jeb-bush', 
                'joe-biden', 'blog-posting','paul-ryan']

speaker_dict={}
for cnt, speaker in enumerate(speakers):
    speaker_dict[speaker]=cnt
print(speaker_dict)

def speaker_projection(speaker):
    if isinstance(speaker, str):
        speaker=speaker.lower()
        matched=[s for s in speakers if s in speaker]
        if len(matched)>0:
            return speaker_dict[matched[0]]
        else:
            return len(speakers)
        
##
train_data['speaker_id']=train_data['Speaker'].apply(speaker_projection)
test_data['speaker_id']=test_data['Speaker'].apply(speaker_projection)
val_data['speaker_id']=val_data['Speaker'].apply(speaker_projection)
# Out:
# {'barack-obama': 0, 'donald-trump': 1, 'hillary-clinton': 2, 'mitt-romney': 3, 'scott-walker': 4, 'john-mccain': 5, 'rick-perry': 6, 'chain-email': 7, 'marco-rubio': 8, 'rick-scott': 9, 'ted-cruz': 10, 'bernie-s': 11, 'chris-christie': 12, 'facebook-posts': 13, 'charlie-crist': 14, 'newt-gingrich': 15, 'jeb-bush': 16, 'joe-biden': 17, 'blog-posting': 18, 'paul-ryan': 19}
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## Map job
job_list = ['president', 'u.s. senator', 'governor', 'president-elect', 'presidential candidate', 
                'u.s. representative', 'state senator', 'attorney', 'state representative', 'congress', 'others']


job_dict = {'president':0, 'u.s. senator':1, 'governor':2, 'president-elect':3, 'presidential candidate':4, 
            'u.s. representative':5, 'state senator':6, 'attorney':7, 'state representative':8, 'congress':9, 'others':10}

## Map job

def job_projection(job):
    if isinstance(job, str):
        job=job.lower()
        matched_job=[j for j in job_list if j in job]
        if len(matched_job)>0:
            return job_dict[matched_job[0]]
        else:
            return 10
    else:
        return 10

## job projection output

train_data['job_id']=train_data['Speaker Job'].apply(job_projection)
test_data['job_id']=test_data['Speaker Job'].apply(job_projection)
val_data['job_id']=val_data['Speaker Job'].apply(job_projection)
# Out:
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
### Map political parties
party_dict={'republican':0, 'democrat':1, 'none':2, 'organization':3, 'newsmaker':4, 'rest':5}

def map_political_party(party):
    if party in party_dict:
        return party_dict[party]
    else:
        return 5
    
##
train_data['party_id']=train_data['Party'].apply(map_political_party)
test_data['party_id']=test_data['Party'].apply(map_political_party)
val_data['party_id']=val_data['Party'].apply(map_political_party)
# Out:
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
## Map states
all_states = ['Alabama','Alaska','Arizona','Arkansas','California','Colorado',
              'Connecticut','Delaware','Florida','Georgia','Hawaii','Idaho', 
              'Illinois','Indiana','Iowa','Kansas','Kentucky','Louisiana',
              'Maine' 'Maryland','Massachusetts','Michigan','Minnesota',
              'Mississippi', 'Missouri','Montana','Nebraska','Nevada',
              'New Hampshire','New Jersey','New Mexico','New York',
              'North Carolina','North Dakota','Ohio',    
              'Oklahoma','Oregon','Pennsylvania','Rhode Island',
              'South  Carolina','South Dakota','Tennessee','Texas','Utah',
              'Vermont','Virginia','Washington','West Virginia',
              'Wisconsin','Wyoming']


states_dict = {'wyoming': 48, 'colorado': 5, 'washington': 45, 'hawaii': 10, 
               'tennessee': 40, 'wisconsin': 47, 'nevada': 26, 'north dakota': 32, 
               'mississippi': 22, 'south dakota': 39, 'new jersey': 28, 'oklahoma': 34, 
               'delaware': 7, 'minnesota': 21, 'north carolina': 31, 'illinois': 12, 
               'new york': 30, 'arkansas': 3, 'west virginia': 46, 'indiana': 13, 
               'louisiana': 17, 'idaho': 11, 'south  carolina': 38, 'arizona': 2, 
               'iowa': 14, 'mainemaryland': 18, 'michigan': 20, 'kansas': 15, 
               'utah': 42, 'virginia': 44, 'oregon': 35, 'connecticut': 6, 'montana': 24, 
               'california': 4, 'massachusetts': 19, 'rhode island': 37, 'vermont': 43, 
               'georgia': 9, 'pennsylvania': 36, 'florida': 8, 'alaska': 1, 'kentucky': 16,
               'nebraska': 25, 'new hampshire': 27, 'texas': 41, 'missouri': 23, 'ohio': 33,
               'alabama': 0, 'new mexico': 29, 'rest':50}


def state_projection(state):
    if isinstance(state, str):
        state=state.lower()
        if state in states_dict:
            return states_dict[state]
        else:
            if 'washington' in state:
                return states_dict['washington']
            else:
                return 50
    else:
        return 50
    
## state mapping output:
train_data['state_id']=train_data['State Info'].apply(state_projection)
test_data['state_id']=test_data['State Info'].apply(state_projection)
val_data['state_id']=val_data['State Info'].apply(state_projection)
# Out:
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:43: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:44: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\jvret\AppData\Local\Programs\Python\Python36\lib\site-packages\ipykernel_launcher.py:45: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
## map subject
subject_list = ['health','tax','immigration','election','education',
    'candidates-biography','economy','gun','jobs','federal-budget','energy','abortion','foreign-policy']

subject_dict = {'health':0,'tax':1,'immigration':2,'election':3,'education':4,
                'candidates-biography':5,'economy':6,'gun':7,'jobs':8,'federal-budget':9,
                'energy':10,'abortion':11,'foreign-policy':12, 'others':13}

## mapping subject
def subject_projection(subject):
    if isinstance(subject, str):
        subject=subject.lower()
        matched_subject=[subj for subj in subject_list if subj in subject]
        
        if len(matched_subject)>0:
            return subject_dict[matched_subject[0]]
        else:
            return 13
    else:
        return 13
    
##
train_data['subject_id']=train_data['Subject'].apply(subject_projection)
test_data['subject_id']=test_data['Subject'].apply(subject_projection)
val_data['subject_id']=val_data['Subject'].apply(subject_projection)

# %%
## Context mapping
Context_list = ['news release','interview','tv','radio',
                'campaign','news conference','press conference','press release',
                'tweet','facebook','email']

Context_dict = {'news release':0,'interview':1,'tv':2,'radio':3,
                'campaign':4,'news conference':5,'press conference':6,'press release':7,
                'tweet':8,'facebook':9,'email':10, 'others':11}

def Context_projection(context):
    if isinstance(context, str):
        context=context.lower()
        matched_context=[cntx for cntx in Context_list if cntx in context]
        if len(matched_context)>0:
            return Context_dict[matched_context[0]]
        else:
            return 11
    else:
        return 11
    
## context projection output
train_data['context_id']=train_data['Context'].apply(Context_projection)
test_data['context_id']=test_data['Context'].apply(Context_projection)
val_data['context_id']=val_data['Context'].apply(Context_projection)

# %%
### tokenize fake news statement and build vocabulary
vocab_dict={}

tokenizer = Tokenizer(num_words=20000)
tokenizer.fit_on_texts(train_data['Statement'])
vocab_dict=tokenizer.word_index
cPickle.dump(tokenizer.word_index, open("vocab.p","wb"))
print("vocab dictionary is created")
print("saved vocan dictionary to pickle file")
# Out:
# vocab dictionary is created
# saved vocan dictionary to pickle file

# %%
## data preprocessing

# def preprocessing_txt(dataset):
#     stop_words = set(stopwords.words('english'))
#     corpus=[]
#     for elm in range(0, len(dataset.index)):
#         res=' '.join([i for i in dataset['Statement'][elm].lower().split() if i not in stop_words])
#         res=re.sub("</?.*?>"," <> ",dataset['Statement'][elm])    # remove tags
#         res=re.sub("(\\d|\\W)+"," ",dataset['Statement'][elm])        # remove special characte
#         res=re.sub(r'@([A-Za-z0-9_]+)', "",dataset['Statement'][elm])  # remove twitter handler
#         res=re.sub('(\r)+', "", dataset['Statement'][elm])            # remove newline character
#         res=re.sub('[^\x00-\x7F]+', "", dataset['Statement'][elm])    # remove non-ascii characters
#         res=''.join(x for x in dataset['Statement'][elm] if x not in set(string.punctuation))   ## remove punctuation
#         corpus.append(res)
#     return corpus

# %%
### TODO: END

# %%
vocab_length = len(vocab_dict.keys())
hidden_size = 128 #Has to be same as EMBEDDING_DIM
lstm_size = 100
num_steps = 64
num_epochs = 30
batch_size = 64
#Hyperparams for CNN
kernel_sizes = [2,3,5,7]
filter_size = 128
#Meta data related hyper params
num_party = 6
num_state = 51
num_context = 12
num_job = 11
num_sub = 14
num_speaker = 21
embedding_dims=300
max_features = len(tokenizer.word_index)+1

# %%
### create embedding layer
num_words=len(vocab_dict)+1

def loadGloveModel(gloveFile):
    print("Loading Glove Model")
    embeddings_index = {}
    f = open(gloveFile, encoding='utf8')
    for line in f:
        values = line.split()
        word = ''.join(values[:-300])
        coefs = np.asarray(values[-300:], dtype='float32')
        embeddings_index[word] = coefs
    f.close()
    return embeddings_index

glove_model = loadGloveModel('glove.6B.300d.txt')

def build_glove_embedding_layers():
    embed_matrix=np.zeros((max_features, embedding_dims))
    for word, indx in tokenizer.word_index.items():
        if indx >= max_features:
            continue
        if word in glove_model:
            embed_vec=glove_model[word]
            if embed_vec is not None:
                embed_matrix[indx]=embed_vec
    return embed_matrix

embedding_weights=build_glove_embedding_layers()
# Out:
# Loading Glove Model

# %%
### data preprocessing
def preprocessing_txt_keras(statement):
    txt=text_to_word_sequence(statement)
    val=[0]*64
    val=[vocab_dict[t] for t in txt if t in vocab_dict]   ##replace unknown words with zero index
    return val

# %%
## training instances list

from nltk.corpus import stopwords
import string
stop = set(stopwords.words('english'))

### remove stopwords fitst
train_data['Statement'] = list(map(' '.join, train_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))
test_data['Statement'] = list(map(' '.join, test_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))
val_data['Statement'] = list(map(' '.join, val_data['Statement'].apply(lambda x: [item for item in x.lower().split() if item not in stop])))

# %%
train_data['word_id']=train_data['Statement'].apply(preprocessing_txt_keras)
test_data['word_id']=test_data['Statement'].apply(preprocessing_txt_keras)
val_data['word_id']=val_data['Statement'].apply(preprocessing_txt_keras)

x_train=train_data['word_id']
x_test=test_data['word_id']
x_val=val_data['word_id']

y_train=train_data['multi_label']
y_val=val_data['multi_label']

##
x_train=sequence.pad_sequences(x_train, maxlen=num_steps, padding='post', truncating='post')
y_train=to_categorical(y_train, num_classes=6)
x_val=sequence.pad_sequences(x_val, maxlen=num_steps, padding='post', truncating='post')
y_val=to_categorical(y_val, num_classes=6)
x_test=sequence.pad_sequences(x_test, maxlen=num_steps, padding='post', truncating='post')

## meta data preparation
tr_party=to_categorical(train_data['party_id'], num_classes=num_party)
tr_state=to_categorical(train_data['state_id'], num_classes=num_state)
tr_cont=to_categorical(train_data['context_id'], num_classes=num_context)
tr_job=to_categorical(train_data['job_id'], num_classes=num_job)
tr_subj=to_categorical(train_data['subject_id'], num_classes=num_sub)
# tr_speaker=to_categorical(train_data['speaker_id'], num_classes=num_speaker)

# ## put all metadata of train data together in one stack
# x_train_metadata=np.hstack(tr_party, tr_state, tr_job, tr_subj, tr_speaker, tr_cont)
x_train_metadata=np.hstack((tr_party, tr_state, tr_cont,tr_job, tr_subj))


# #********************************************************************************#
val_party=to_categorical(val_data['party_id'], num_classes=num_party)
val_state=to_categorical(val_data['state_id'], num_classes=num_state)
val_cont=to_categorical(val_data['context_id'], num_classes=num_context)
val_job=to_categorical(val_data['job_id'], num_classes=num_job)
val_subj=to_categorical(val_data['subject_id'], num_classes=num_sub)
# val_speaker=to_categorical(val_data['speaker_id'], num_classes=num_speaker)


# ## put all metadata of train data together in one stack
# x_val_metadata=np.hstack(val_party, val_state, val_job, val_subj, val_speaker, val_cont)
x_val_metadata=np.hstack((val_party, val_state, val_cont,val_job, val_subj, ))

# #********************************************************************************#
te_party=to_categorical(test_data['party_id'], num_classes=num_party)
te_state=to_categorical(test_data['state_id'], num_classes=num_state)
te_cont=to_categorical(test_data['context_id'], num_classes=num_context)
te_job=to_categorical(test_data['job_id'], num_classes=num_job)
te_subj=to_categorical(test_data['subject_id'], num_classes=num_sub)
# te_speaker=to_categorical(test_data['speaker_id'], num_classes=num_speaker)

# ## put all metadata of train data together in one stack
x_test_metadata=np.hstack((te_party, te_state, te_cont,te_job, te_subj))

# %% [markdown]
# ### Define CNN model

# %%
kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int64', name='main_input')
x = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

for kernel in kernel_sizes:
    x_1 = Conv1D(filters=filter_size,kernel_size=kernel, padding="valid", activation="relu", strides=1)(x)
    x_1 = Dropout(0.6)(x_1)
    x_1 = GlobalMaxPool1D()(x_1)
    kernel_arr.append(x_1)

conv_in = keras.layers.concatenate(kernel_arr)
conv_in = Dropout(0.5)(conv_in)
conv_in = Dense(128, activation='relu')(conv_in)

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_meta = Dense(64, activation='relu')(meta_input)
x = keras.layers.concatenate([conv_in, x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)
model = Model(inputs=[statement_input, meta_input], outputs=[main_output])

#************************************************************************#
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

model.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=4)
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history= model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                   {'main_output': y_train},epochs=20, batch_size=batch_size,
                   validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                  callbacks=[tb,csv_logger,checkpoint, es])
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# main_input (InputLayer)         (None, 100)          0
# __________________________________________________________________________________________________
# embedding_6 (Embedding)         (None, 100, 300)     3722700     main_input[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 98, 128)      115328      embedding_6[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 97, 128)      153728      embedding_6[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 96, 128)      192128      embedding_6[0][0]
# __________________________________________________________________________________________________
# dropout_21 (Dropout)            (None, 98, 128)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# dropout_22 (Dropout)            (None, 97, 128)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# dropout_23 (Dropout)            (None, 96, 128)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_18 (Global (None, 128)          0           dropout_21[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_19 (Global (None, 128)          0           dropout_22[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_20 (Global (None, 128)          0           dropout_23[0][0]
# __________________________________________________________________________________________________
# aux_input (InputLayer)          (None, 94)           0
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 384)          0           global_max_pooling1d_18[0][0]
#                                                                  global_max_pooling1d_19[0][0]
#                                                                  global_max_pooling1d_20[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 32)           3040        aux_input[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 416)          0           concatenate_11[0][0]
#                                                                  dense_9[0][0]
# __________________________________________________________________________________________________
# main_output (Dense)             (None, 6)            2502        concatenate_12[0][0]
# ==================================================================================================
# Total params: 4,189,426
# Trainable params: 466,726
# Non-trainable params: 3,722,700
# __________________________________________________________________________________________________
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 74s 7ms/step - loss: 2.0027 - categorical_accuracy: 0.2055 - val_loss: 1.7355 - val_categorical_accuracy: 0.2368
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23676, saving model to weights.best.hdf5
# Epoch 2/20
# 10240/10240 [==============================] - 72s 7ms/step - loss: 1.7181 - categorical_accuracy: 0.2555 - val_loss: 1.7191 - val_categorical_accuracy: 0.2274
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.23676
# Epoch 3/20
# 10240/10240 [==============================] - 80s 8ms/step - loss: 1.6877 - categorical_accuracy: 0.2739 - val_loss: 1.7141 - val_categorical_accuracy: 0.2414
#
# Epoch 00003: val_categorical_accuracy improved from 0.23676 to 0.24143, saving model to weights.best.hdf5
# Epoch 4/20
# 10240/10240 [==============================] - 71s 7ms/step - loss: 1.6464 - categorical_accuracy: 0.2997 - val_loss: 1.7054 - val_categorical_accuracy: 0.2484
#
# Epoch 00004: val_categorical_accuracy improved from 0.24143 to 0.24844, saving model to weights.best.hdf5
# Epoch 5/20
# 10240/10240 [==============================] - 72s 7ms/step - loss: 1.6156 - categorical_accuracy: 0.3155 - val_loss: 1.6953 - val_categorical_accuracy: 0.2593
#
# Epoch 00005: val_categorical_accuracy improved from 0.24844 to 0.25935, saving model to weights.best.hdf5
# Epoch 6/20
# 10240/10240 [==============================] - 72s 7ms/step - loss: 1.5668 - categorical_accuracy: 0.3517 - val_loss: 1.7021 - val_categorical_accuracy: 0.2671
#
# Epoch 00006: val_categorical_accuracy improved from 0.25935 to 0.26713, saving model to weights.best.hdf5
# Epoch 7/20
# 10240/10240 [==============================] - 83s 8ms/step - loss: 1.5353 - categorical_accuracy: 0.3683 - val_loss: 1.6958 - val_categorical_accuracy: 0.2609
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.26713
# Epoch 8/20
#  5120/10240 [==============>...............] - ETA: 34s - loss: 1.4914 - categorical_accuracy: 0.3906
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-7830258188c8> in <module>
#      42                    {'main_output': y_train},epochs=20, batch_size=batch_size,
#      43                    validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
# ---> 44                   callbacks=[tb,csv_logger,checkpoint, es])
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1037                                         initial_epoch=initial_epoch,
#    1038                                         steps_per_epoch=steps_per_epoch,
# -> 1039                                         validation_steps=validation_steps)
#    1040
#    1041     def evaluate(self, x=None, y=None,
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\engine\training_arrays.py in fit_loop(model, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#     197                     ins_batch[i] = ins_batch[i].toarray()
#     198
# --> 199                 outs = f(ins_batch)
#     200                 outs = to_list(outs)
#     201                 for l, o in zip(out_labels, outs):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\backend\tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\client\session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# KeyboardInterrupt:

# %%
accu_curve=plt.figure()
plt.plot(history.history['categorical_accuracy'],'r',linewidth=3.0)
plt.plot(history.history['val_categorical_accuracy'],'b',linewidth=3.0)
plt.legend(['Training Accuracy', 'Validation Accuracy'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Accuracy',fontsize=12)
plt.title('Accuracy Curves : CNN',fontsize=12)
accu_curve.savefig('accuracy_cnn_improved.png')
plt.show()
##^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^##
loss_curve = plt.figure()
plt.plot(history.history['loss'],'r',linewidth=3.0)
plt.plot(history.history['val_loss'],'b',linewidth=3.0)
plt.legend(['Training loss', 'Validation Loss'],fontsize=12)
plt.xlabel('Epochs ',fontsize=12)
plt.ylabel('Loss',fontsize=12)
plt.title('Loss Curves :CNN',fontsize=12)
loss_curve.savefig('loss_cnn_improved.png')
loss_curve.show()

# %% [markdown]
# #### if we run the model multiple times (Experiment)

# %%
kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int32', name='main_input')
x = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

for kernel in kernel_sizes:
    x_1 = Conv1D(filters=filter_size,kernel_size=kernel)(x)
    x_1 = Dropout(0.6)(x_1)
    x_1 = GlobalMaxPool1D()(x_1)
    kernel_arr.append(x_1)

conv_in = keras.layers.concatenate(kernel_arr)
conv_in = Dropout(0.6)(conv_in)
conv_in = Dense(100, activation='relu')(conv_in)

#Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_meta = Dense(64, activation='relu')(meta_input)
x = keras.layers.concatenate([conv_in, x_meta])

main_output = Dense(6, activation='softmax', name='main_output')(x)

####
runs=5
histories = []

for i in range(runs):
    print('Running iteration %i/%i' % (i+1, runs))
    model = Model(inputs=[statement_input, meta_input], outputs=[main_output])
    model.compile(optimizer=sgd,
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])
    
    ####
    tb = TensorBoard()
    csv_logger = keras.callbacks.CSVLogger('training.log')
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
    #filepath= "weights.best.hdf5"
    # checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
    #                                              monitor='val_categorical_accuracy', 
    #                                              verbose=1, save_best_only=True, mode='max')

    history= model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                       {'main_output': y_train},epochs=20, batch_size=batch_size, verbose=1,
                       validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                       callbacks=[keras.callbacks.ModelCheckpoint('model-%i.h5'%(i+1), 
                                                                  monitor='val_categorical_accuracy', verbose=1, 
                                                                  save_best_only=True, mode='max'),es, tb, csv_logger])
                       #callbacks=[tb,csv_logger,checkpoint, es])
    print()
    histories.append(history.history)
# Out:
# Running iteration 1/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.8142 - categorical_accuracy: 0.2097 - val_loss: 1.7435 - val_categorical_accuracy: 0.2329
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.23287, saving model to model-1.h5
# Epoch 2/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.7317 - categorical_accuracy: 0.2384 - val_loss: 1.7241 - val_categorical_accuracy: 0.2321
#
# Epoch 00002: val_categorical_accuracy did not improve from 0.23287
# Epoch 3/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.7145 - categorical_accuracy: 0.2471 - val_loss: 1.7162 - val_categorical_accuracy: 0.2321
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.23287
# Epoch 4/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.7079 - categorical_accuracy: 0.2520 - val_loss: 1.7103 - val_categorical_accuracy: 0.2438
#
# Epoch 00004: val_categorical_accuracy improved from 0.23287 to 0.24377, saving model to model-1.h5
# Epoch 5/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.6961 - categorical_accuracy: 0.2582 - val_loss: 1.7057 - val_categorical_accuracy: 0.2477
#
# Epoch 00005: val_categorical_accuracy improved from 0.24377 to 0.24766, saving model to model-1.h5
# Epoch 6/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6917 - categorical_accuracy: 0.2624 - val_loss: 1.7039 - val_categorical_accuracy: 0.2461
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.24766
# Epoch 7/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6873 - categorical_accuracy: 0.2659 - val_loss: 1.6993 - val_categorical_accuracy: 0.2625
#
# Epoch 00007: val_categorical_accuracy improved from 0.24766 to 0.26246, saving model to model-1.h5
# Epoch 8/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6813 - categorical_accuracy: 0.2679 - val_loss: 1.6996 - val_categorical_accuracy: 0.2469
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.26246
# Epoch 9/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.6733 - categorical_accuracy: 0.2742 - val_loss: 1.6978 - val_categorical_accuracy: 0.2500
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.26246
# Epoch 10/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.6679 - categorical_accuracy: 0.2781 - val_loss: 1.6976 - val_categorical_accuracy: 0.2430
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.26246
# Epoch 11/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.6637 - categorical_accuracy: 0.2827 - val_loss: 1.6915 - val_categorical_accuracy: 0.2539
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.26246
# Epoch 12/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6550 - categorical_accuracy: 0.2870 - val_loss: 1.6900 - val_categorical_accuracy: 0.2586
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.26246
# Epoch 13/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6471 - categorical_accuracy: 0.2899 - val_loss: 1.6840 - val_categorical_accuracy: 0.2632
#
# Epoch 00013: val_categorical_accuracy improved from 0.26246 to 0.26324, saving model to model-1.h5
# Epoch 14/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6392 - categorical_accuracy: 0.2990 - val_loss: 1.6793 - val_categorical_accuracy: 0.2640
#
# Epoch 00014: val_categorical_accuracy improved from 0.26324 to 0.26402, saving model to model-1.h5
# Epoch 15/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.6276 - categorical_accuracy: 0.3068 - val_loss: 1.6829 - val_categorical_accuracy: 0.2516
#
# Epoch 00015: val_categorical_accuracy did not improve from 0.26402
# Epoch 16/20
# 10240/10240 [==============================] - 51s 5ms/step - loss: 1.6183 - categorical_accuracy: 0.3159 - val_loss: 1.6810 - val_categorical_accuracy: 0.2609
#
# Epoch 00016: val_categorical_accuracy did not improve from 0.26402
# Epoch 17/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.6145 - categorical_accuracy: 0.3193 - val_loss: 1.6771 - val_categorical_accuracy: 0.2710
#
# Epoch 00017: val_categorical_accuracy improved from 0.26402 to 0.27103, saving model to model-1.h5
# Epoch 18/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.5987 - categorical_accuracy: 0.3213 - val_loss: 1.6743 - val_categorical_accuracy: 0.2586
#
# Epoch 00018: val_categorical_accuracy did not improve from 0.27103
# Epoch 19/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.5892 - categorical_accuracy: 0.3281 - val_loss: 1.6782 - val_categorical_accuracy: 0.2570
#
# Epoch 00019: val_categorical_accuracy did not improve from 0.27103
# Epoch 20/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.5721 - categorical_accuracy: 0.3353 - val_loss: 1.6736 - val_categorical_accuracy: 0.2625
#
# Epoch 00020: val_categorical_accuracy did not improve from 0.27103
#
# Running iteration 2/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.5683 - categorical_accuracy: 0.3443 - val_loss: 1.6721 - val_categorical_accuracy: 0.2687
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.26869, saving model to model-2.h5
# Epoch 2/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.5525 - categorical_accuracy: 0.3516 - val_loss: 1.6692 - val_categorical_accuracy: 0.2710
#
# Epoch 00002: val_categorical_accuracy improved from 0.26869 to 0.27103, saving model to model-2.h5
# Epoch 3/20
# 10240/10240 [==============================] - 50s 5ms/step - loss: 1.5366 - categorical_accuracy: 0.3570 - val_loss: 1.6647 - val_categorical_accuracy: 0.2710
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.27103
# Epoch 4/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.5258 - categorical_accuracy: 0.3629 - val_loss: 1.6716 - val_categorical_accuracy: 0.2625
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.27103
# Epoch 5/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.5066 - categorical_accuracy: 0.3753 - val_loss: 1.6767 - val_categorical_accuracy: 0.2695
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.27103
# Epoch 6/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.4930 - categorical_accuracy: 0.3858 - val_loss: 1.6737 - val_categorical_accuracy: 0.2640
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.27103
# Epoch 7/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.4827 - categorical_accuracy: 0.3934 - val_loss: 1.6699 - val_categorical_accuracy: 0.2718
#
# Epoch 00007: val_categorical_accuracy improved from 0.27103 to 0.27181, saving model to model-2.h5
# Epoch 8/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.4634 - categorical_accuracy: 0.4003 - val_loss: 1.6738 - val_categorical_accuracy: 0.2710
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.27181
# Epoch 9/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.4429 - categorical_accuracy: 0.4051 - val_loss: 1.6773 - val_categorical_accuracy: 0.2664
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.27181
# Epoch 10/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.4317 - categorical_accuracy: 0.4131 - val_loss: 1.6766 - val_categorical_accuracy: 0.2765
#
# Epoch 00010: val_categorical_accuracy improved from 0.27181 to 0.27648, saving model to model-2.h5
# Epoch 11/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.4071 - categorical_accuracy: 0.4254 - val_loss: 1.6869 - val_categorical_accuracy: 0.2741
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.27648
# Epoch 12/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.3899 - categorical_accuracy: 0.4368 - val_loss: 1.6954 - val_categorical_accuracy: 0.2687
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.27648
# Epoch 13/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.3790 - categorical_accuracy: 0.4395 - val_loss: 1.6997 - val_categorical_accuracy: 0.2702
#
# Epoch 00013: val_categorical_accuracy did not improve from 0.27648
# Epoch 00013: early stopping
#
# Running iteration 3/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.3531 - categorical_accuracy: 0.4545 - val_loss: 1.7262 - val_categorical_accuracy: 0.2609
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.26090, saving model to model-3.h5
# Epoch 2/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.3317 - categorical_accuracy: 0.4664 - val_loss: 1.7195 - val_categorical_accuracy: 0.2687
#
# Epoch 00002: val_categorical_accuracy improved from 0.26090 to 0.26869, saving model to model-3.h5
# Epoch 3/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.3174 - categorical_accuracy: 0.4771 - val_loss: 1.7623 - val_categorical_accuracy: 0.2531
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.26869
# Epoch 4/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.3093 - categorical_accuracy: 0.4760 - val_loss: 1.7315 - val_categorical_accuracy: 0.2710
#
# Epoch 00004: val_categorical_accuracy improved from 0.26869 to 0.27103, saving model to model-3.h5
# Epoch 5/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.2756 - categorical_accuracy: 0.4877 - val_loss: 1.7440 - val_categorical_accuracy: 0.2679
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.27103
# Epoch 6/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 1.2673 - categorical_accuracy: 0.4938 - val_loss: 1.7591 - val_categorical_accuracy: 0.2671
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.27103
# Epoch 7/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.2477 - categorical_accuracy: 0.5076 - val_loss: 1.7898 - val_categorical_accuracy: 0.2570
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.27103
# Epoch 8/20
# 10240/10240 [==============================] - 50s 5ms/step - loss: 1.2281 - categorical_accuracy: 0.5103 - val_loss: 1.8579 - val_categorical_accuracy: 0.2484
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.27103
# Epoch 9/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.2048 - categorical_accuracy: 0.5289 - val_loss: 1.8402 - val_categorical_accuracy: 0.2640
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.27103
# Epoch 10/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.1785 - categorical_accuracy: 0.5395 - val_loss: 1.8769 - val_categorical_accuracy: 0.2601
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.27103
# Epoch 11/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.1733 - categorical_accuracy: 0.5411 - val_loss: 1.8827 - val_categorical_accuracy: 0.2640
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.27103
# Epoch 12/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.1549 - categorical_accuracy: 0.5473 - val_loss: 1.9471 - val_categorical_accuracy: 0.2679
#
# Epoch 00012: val_categorical_accuracy did not improve from 0.27103
# Epoch 00012: early stopping
#
# Running iteration 4/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 1.1388 - categorical_accuracy: 0.5560 - val_loss: 1.9698 - val_categorical_accuracy: 0.2570
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.25701, saving model to model-4.h5
# Epoch 2/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.1203 - categorical_accuracy: 0.5606 - val_loss: 1.9930 - val_categorical_accuracy: 0.2625
#
# Epoch 00002: val_categorical_accuracy improved from 0.25701 to 0.26246, saving model to model-4.h5
# Epoch 3/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.1013 - categorical_accuracy: 0.5774 - val_loss: 2.0080 - val_categorical_accuracy: 0.2788
#
# Epoch 00003: val_categorical_accuracy improved from 0.26246 to 0.27882, saving model to model-4.h5
# Epoch 4/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0868 - categorical_accuracy: 0.5829 - val_loss: 2.0546 - val_categorical_accuracy: 0.2671
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.27882
# Epoch 5/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0670 - categorical_accuracy: 0.5852 - val_loss: 2.1076 - val_categorical_accuracy: 0.2632
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.27882
# Epoch 6/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0604 - categorical_accuracy: 0.5904 - val_loss: 2.1644 - val_categorical_accuracy: 0.2625
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.27882
# Epoch 7/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0501 - categorical_accuracy: 0.5955 - val_loss: 2.2362 - val_categorical_accuracy: 0.2578
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.27882
# Epoch 8/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0281 - categorical_accuracy: 0.6063 - val_loss: 2.2327 - val_categorical_accuracy: 0.2609
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.27882
# Epoch 9/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0037 - categorical_accuracy: 0.6145 - val_loss: 2.3243 - val_categorical_accuracy: 0.2570
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.27882
# Epoch 10/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.9933 - categorical_accuracy: 0.6158 - val_loss: 2.3408 - val_categorical_accuracy: 0.2640
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.27882
# Epoch 11/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 1.0037 - categorical_accuracy: 0.6165 - val_loss: 2.4670 - val_categorical_accuracy: 0.2523
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.27882
# Epoch 00011: early stopping
#
# Running iteration 5/5
# Train on 10240 samples, validate on 1284 samples
# Epoch 1/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 0.9655 - categorical_accuracy: 0.6333 - val_loss: 2.5045 - val_categorical_accuracy: 0.2531
#
# Epoch 00001: val_categorical_accuracy improved from -inf to 0.25312, saving model to model-5.h5
# Epoch 2/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.9655 - categorical_accuracy: 0.6292 - val_loss: 2.5931 - val_categorical_accuracy: 0.2539
#
# Epoch 00002: val_categorical_accuracy improved from 0.25312 to 0.25389, saving model to model-5.h5
# Epoch 3/20
# 10240/10240 [==============================] - 49s 5ms/step - loss: 0.9408 - categorical_accuracy: 0.6464 - val_loss: 2.6396 - val_categorical_accuracy: 0.2453
#
# Epoch 00003: val_categorical_accuracy did not improve from 0.25389
# Epoch 4/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.9218 - categorical_accuracy: 0.6493 - val_loss: 2.8444 - val_categorical_accuracy: 0.2500
#
# Epoch 00004: val_categorical_accuracy did not improve from 0.25389
# Epoch 5/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.9193 - categorical_accuracy: 0.6578 - val_loss: 3.0439 - val_categorical_accuracy: 0.2469
#
# Epoch 00005: val_categorical_accuracy did not improve from 0.25389
# Epoch 6/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.9028 - categorical_accuracy: 0.6564 - val_loss: 2.9273 - val_categorical_accuracy: 0.2492
#
# Epoch 00006: val_categorical_accuracy did not improve from 0.25389
# Epoch 7/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.8940 - categorical_accuracy: 0.6594 - val_loss: 3.1061 - val_categorical_accuracy: 0.2360
#
# Epoch 00007: val_categorical_accuracy did not improve from 0.25389
# Epoch 8/20
# 10240/10240 [==============================] - 48s 5ms/step - loss: 0.8864 - categorical_accuracy: 0.6638 - val_loss: 3.2873 - val_categorical_accuracy: 0.2368
#
# Epoch 00008: val_categorical_accuracy did not improve from 0.25389
# Epoch 9/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 0.8675 - categorical_accuracy: 0.6672 - val_loss: 3.3671 - val_categorical_accuracy: 0.2445
#
# Epoch 00009: val_categorical_accuracy did not improve from 0.25389
# Epoch 10/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 0.8624 - categorical_accuracy: 0.6744 - val_loss: 3.4344 - val_categorical_accuracy: 0.2313
#
# Epoch 00010: val_categorical_accuracy did not improve from 0.25389
# Epoch 11/20
# 10240/10240 [==============================] - 47s 5ms/step - loss: 0.8494 - categorical_accuracy: 0.6728 - val_loss: 3.3960 - val_categorical_accuracy: 0.2383
#
# Epoch 00011: val_categorical_accuracy did not improve from 0.25389
# Epoch 00011: early stopping

# %%
### plot the output
with open('history.pkl', 'wb') as f:
    cPickle.dump(histories, f)

# %%
histories = cPickle.load(open('history.pkl', 'rb'))

# %%
def get_avg(histories, his_key):
    tmp = []
    for history in histories:
        tmp.append(history[his_key][np.argmin(history['val_loss'])])
    return np.mean(tmp)
    
print('Training: \t%0.4f loss / %0.4f acc' % (get_avg(histories, 'loss'),
                                              get_avg(histories, 'categorical_accuracy')))
print('Validation: \t%0.4f loss / %0.4f acc' % (get_avg(histories, 'val_loss'),
                                                get_avg(histories, 'val_categorical_accuracy')))
# Out:
# Training: 	1.3090 loss / 0.4696 acc
# Validation: 	1.9064 loss / 0.2625 acc

# %%
def plot_acc_loss(title, histories, key_acc, key_loss):
    fig, (ax1, ax2) = plt.subplots(1, 2)
    # Accuracy
    ax1.set_title('Model accuracy (%s)' % title)
    names = []
    for i, model in enumerate(histories):
        ax1.plot(model[key_acc])
        ax1.set_xlabel('epoch')
        names.append('Model %i' % (i+1))
        ax1.set_ylabel('accuracy')
    ax1.legend(names, loc='lower right')
    # Loss
    ax2.set_title('Model loss (%s)' % title)
    for model in histories:
        ax2.plot(model[key_loss])
        ax2.set_xlabel('epoch')
        ax2.set_ylabel('loss')
    ax2.legend(names, loc='upper right')
    fig.set_size_inches(20, 5)
    plt.show()

# %%
plot_acc_loss('training', histories, 'categorical_accuracy', 'loss')
plot_acc_loss('validation', histories, 'val_categorical_accuracy', 'val_loss')

# %%
### Make prediction
from keras.models import load_model
#Load a pre-trained model if any
model1 = load_model('weights.best.hdf5')
preds = model1.predict([x_test,x_test_metadata], batch_size=batch_size, verbose=1)
print(np.array(preds))
# Out:
# 1267/1267 [==============================] - 2s 2ms/step
# [[0.2339262  0.08675115 0.18008143 0.18238442 0.19402519 0.12283161]
#  [0.21698949 0.14054851 0.04024055 0.15862547 0.21648441 0.22711153]
#  [0.37754112 0.05388047 0.2438285  0.18233532 0.09576442 0.04665018]
#  ...
#  [0.26225013 0.11336583 0.07458698 0.17128097 0.17038243 0.20813368]
#  [0.15930183 0.23672773 0.06315657 0.1558833  0.23714441 0.14778607]
#  [0.21353503 0.12819347 0.03141575 0.15193172 0.2270546  0.24786939]]

# %%
# from keras.utils.np_utils import accuracy
# acc = accuracy(y_test, np.round(np.array(preds)))

# %% [markdown]
# ###  C-LSTM model for fake news classification

# %%
## C-LSTM model implementation (trail version)
from keras.layers import LSTM
from keras.optimizers import Adam
from keras.layers import LSTM, Bidirectional

adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)


kernel_arr = []
statement_input = Input(shape=(num_steps,), dtype='int32', name='main_input')
x = Embedding(vocab_length+1,embedding_dims,weights=[embedding_weights],input_length=num_steps,trainable=False)(statement_input) #Preloaded glove embeddings
# x = Embedding(output_dim=hidden_size, input_dim=vocab_length+1, input_length=num_steps)(statement_input) #Train embeddings from scratch

for kernel in kernel_sizes:
    x_1 = Conv1D(filters=filter_size,kernel_size=kernel)(x)
    x_1 = GlobalMaxPool1D()(x_1)
    x_1 = Flatten()(x_1)
    #x_1 = Dropout(0.8)(x_1)
    kernel_arr.append(x_1)
    
cnn_feats_maps = keras.layers.concatenate(kernel_arr)
sent_encoder = LSTM(lstm_size,dropout=0.25)(cnn_feats_maps)
# sent_encoder = Bidirectional(LSTM(128, return_sequences=False))(cnn_feats_maps)
fc_layer = Dense(128, activation="relu")(sent_encoder)
conv_in = Dropout(0.6)(fc_layer)
conv_in = Dense(128, activation='relu')(conv_in)

###Meta input
meta_input = Input(shape=(x_train_metadata.shape[1],), name='aux_input')
x_meta_ = Dense(64, activation='relu')(meta_input)
x_ = keras.layers.concatenate([conv_in, x_meta_])

### Define model
main_output = Dense(6, activation='softmax', name='main_output')(x_)
model_CLSTM = Model(inputs=[statement_input, meta_input], outputs=[main_output])

## compile model
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model_CLSTM.compile(optimizer=sgd,
                    loss='categorical_crossentropy',
                    metrics=['categorical_accuracy'])

model_CLSTM.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history_clstm= model_CLSTM.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                               {'main_output': y_train},epochs=num_epochs, batch_size=batch_size,
                               validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                               callbacks=[tb,csv_logger,checkpoint])

# %% [markdown]
# ### Character level CNN model for fake news classification

# %%
from keras import Model
from keras.layers import Input, Dense, Concatenate, Embedding, Flatten
from keras.layers import AlphaDropout
from keras.layers import ThresholdedReLU
from keras.callbacks import TensorBoard
from keras.layers import Convolution1D, GlobalMaxPooling1D

# %%
## parameter list
conv_layers=[[256,7,3],
            [256,7,3],
            [256,7,None],
            [256,7,None],
            [256,7,None],
            [256,7,3]]

fully_connected_layers=[1024,1024]

nb_class=6
input_size=32
alphabet_size=69
embedding_size=64
droprate=0.4
threshold=1e-6

## build CNN model with character embedding

sequence_input = Input(shape=(input_size,), name='sent_input', dtype='int64')
x = Embedding(alphabet_size+1, embedding_size, input_length=input_size)(sequence_input)

# %%
import tensorflow as tf
from keras import layers
from keras import backend as K
from math import sqrt

K.set_image_dim_ordering('th')

# %%
# convs=[]
# for nm_filters, filter_width in conv_layers:
#     conv_in=Convolution1D(filters=nm_filters,
#                           kernel_size=filter_width,
#                           activation='tanh')(x)
#     l_pool = GlobalMaxPool1D()(conv_in)
#     l_flatten = Flatten(l_pool)
#     convs.append(l_flatten)

conc_l=tf.concat([tf.zeros([1, alphabet_size]), 
                  tf.one_hot(list(range(alphabet_size)), alphabet_size, 1.0, 0.0)],0,  name='conc_l')
x=layers.Lambda(lambda i: K.gather(conc_l, K.cast(i, 'int64')))(sequence_input)
x=layers.Lambda(lambda i: K.expand_dims(i,-1))(x)

for cl in conv_layers:
    x=layers.Conv2D(filters=cl[0],
                   kernel_size=(cl[1], x.get_shape()[2].value),
                   kernel_initializer='random_uniform')(x)
    
    stdval=1/(sqrt(cl[0]*cl[1]))
    b=K.random_uniform([cl[0]], minval=-stdval, maxval=stdval)
    x=layers.Lambda(lambda i: K.bias_add(i,b))(x)
    x=layers.ThresholdedReLU(threshold)(x)
    if cl[-1] is not None:
        x=layers.MaxPool2D(pool_size=(cl[-1],1))(x)
    x=layers.Lambda(lambda i: K.permute_dimensions(i, [0,1,3,2]))(x)
    
x=Flatten()(x)
for fl in fully_connected_layers:
    x=layers.Dense(fl)(x)
    x=ThresholdedReLU(threshold)(x)
    x=Dropout(droprate)(x)

model_output=Dense(6, activation='softmax')(x)
Model_charcnn=Model(inputs=sequence_input, outputs=model_output)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1627   try:
# -> 1628     c_op = c_api.TF_FinishOperation(op_desc)
#    1629   except errors.InvalidArgumentError as e:
#
# InvalidArgumentError: Negative dimension size caused by subtracting 69 from 1 for 'conv2d_14/convolution' (op: 'Conv2D') with input shapes: [?,69,1,32], [7,69,32,256].
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-ab4572a3ee89> in <module>
#      16     x=layers.Conv2D(filters=cl[0],
#      17                    kernel_size=(cl[1], x.get_shape()[2].value),
# ---> 18                    kernel_initializer='random_uniform')(x)
#      19
#      20     stdval=1/(sqrt(cl[0]*cl[1]))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\engine\base_layer.py in __call__(self, inputs, **kwargs)
#     455             # Actually call the layer,
#     456             # collecting output(s), mask(s), and shape(s).
# --> 457             output = self.call(inputs, **kwargs)
#     458             output_mask = self.compute_mask(inputs, previous_mask)
#     459
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\layers\convolutional.py in call(self, inputs)
#     169                 padding=self.padding,
#     170                 data_format=self.data_format,
# --> 171                 dilation_rate=self.dilation_rate)
#     172         if self.rank == 3:
#     173             outputs = K.conv3d(
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\keras\backend\tensorflow_backend.py in conv2d(x, kernel, strides, padding, data_format, dilation_rate)
#    3648         strides=strides,
#    3649         padding=padding,
# -> 3650         data_format=tf_data_format)
#    3651
#    3652     if data_format == 'channels_first' and tf_data_format == 'NHWC':
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\ops\nn_ops.py in convolution(input, filter, padding, strides, dilation_rate, name, data_format)
#     778         name=name,
#     779         data_format=data_format)
# --> 780     return op(input, filter)
#     781
#     782
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\ops\nn_ops.py in __call__(self, inp, filter)
#     866
#     867   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 868     return self.conv_op(inp, filter)
#     869
#     870
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\ops\nn_ops.py in __call__(self, inp, filter)
#     518
#     519   def __call__(self, inp, filter):  # pylint: disable=redefined-builtin
# --> 520     return self.call(inp, filter)
#     521
#     522
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\ops\nn_ops.py in __call__(self, inp, filter)
#     202         padding=self.padding,
#     203         data_format=self.data_format,
# --> 204         name=self.name)
#     205
#     206
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\ops\gen_nn_ops.py in conv2d(input, filter, strides, padding, use_cudnn_on_gpu, data_format, dilations, name)
#    1041         "Conv2D", input=input, filter=filter, strides=strides,
#    1042         padding=padding, use_cudnn_on_gpu=use_cudnn_on_gpu,
# -> 1043         data_format=data_format, dilations=dilations, name=name)
#    1044     _result = _op.outputs[:]
#    1045     _inputs_flat = _op.inputs
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\util\deprecation.py in new_func(*args, **kwargs)
#     486                 'in a future version' if date is None else ('after %s' % date),
#     487                 instructions)
# --> 488       return func(*args, **kwargs)
#     489     return tf_decorator.make_decorator(func, new_func, 'deprecated',
#     490                                        _add_deprecated_arg_notice_to_docstring(
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\ops.py in create_op(***failed resolving arguments***)
#    3272           input_types=input_types,
#    3273           original_op=self._default_original_op,
# -> 3274           op_def=op_def)
#    3275       self._create_op_helper(ret, compute_device=compute_device)
#    3276     return ret
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1790           op_def, inputs, node_def.attr)
#    1791       self._c_op = _create_c_op(self._graph, node_def, grouped_inputs,
# -> 1792                                 control_input_ops)
#    1793
#    1794     # Initialize self._outputs.
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\tensorflow\python\framework\ops.py in _create_c_op(graph, node_def, inputs, control_inputs)
#    1629   except errors.InvalidArgumentError as e:
#    1630     # Convert to ValueError for backwards compatibility.
# -> 1631     raise ValueError(str(e))
#    1632
#    1633   return c_op
#
# ValueError: Negative dimension size caused by subtracting 69 from 1 for 'conv2d_14/convolution' (op: 'Conv2D') with input shapes: [?,69,1,32], [7,69,32,256].

# %%
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
charcnn_model.compile(optimizer=sgd,
                      loss='categorical_crossentropy',
                      metrics=['categorical_accuracy'])

charcnn_model.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history_charcnn= charcnn_model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                                   {'main_output': y_train},epochs=num_epochs, batch_size=batch_size,
                                   validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                                   callbacks=[tb,csv_logger,checkpoint])

# %% [markdown]
# #### character level classification (simple version)

# %%
conv_layers=[[256, 7, 3],
             [256, 7, 3],
             [256, 3, -1],
             [256, 3, -1],
             [256, 3, -1],
             [256, 3, 3]]

fully_connected_layers=[1024, 1024]
dropout_p=0.5
threshold=1e-06
input_size=300
alphabet='abcdefghijklmnopqrstuvwxyz0123456789-,;.!?:\'"/\\|_@#$%^&*~`+-=<>()[]{}'
batch_size=128
checkpoint_every=100
epochs=5000
evaluate_every=100
batch_size=128
checkpoint_every=100
epochs=5000
evaluate_every=100
embedding_size=128
alphabet_size=69

# %%
inputs = Input(shape=(input_size,), name='sent_input', dtype='int64')  # shape=(?, 1014)
# Embedding layer
conv = Embedding(alphabet_size+1, embedding_size, input_length=input_size)(inputs)
# Conv 
for filter_num, filter_size, pooling_size in conv_layers:
    conv = Conv1D(filter_num, filter_size)(conv) 
    conv = Activation('relu')(conv)
    if pooling_size != -1:
        conv = MaxPooling1D(pool_size=pooling_size)(conv) # Final shape=(None, 34, 256)
x = Flatten()(conv) # (None, 8704)
# Fully connected layers 
for dense_size in fully_connected_layers:
    x = Dense(dense_size, activation='relu')(x) # dense_size == 1024
    x = Dropout(dropout_p)(x)
model_output = Dense(6, activation='softmax')(x)
# Build model
adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)

model = Model(inputs=inputs, outputs=predictions)
model.compile(optimizer=adam,
              loss='categorical_crossentropy',
              metrics=['categorical_accuracy'])

model.summary()

# model.compile(optimizer=adam, loss=loss) # Adam, categorical_crossentropy
# model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sent_input (InputLayer)      (None, 1014)              0
# _________________________________________________________________
# embedding_6 (Embedding)      (None, 1014, 128)         8960
# _________________________________________________________________
# conv1d_31 (Conv1D)           (None, 1008, 256)         229632
# _________________________________________________________________
# activation_31 (Activation)   (None, 1008, 256)         0
# _________________________________________________________________
# max_pooling1d_16 (MaxPooling (None, 336, 256)          0
# _________________________________________________________________
# conv1d_32 (Conv1D)           (None, 330, 256)          459008
# _________________________________________________________________
# activation_32 (Activation)   (None, 330, 256)          0
# _________________________________________________________________
# max_pooling1d_17 (MaxPooling (None, 110, 256)          0
# _________________________________________________________________
# conv1d_33 (Conv1D)           (None, 108, 256)          196864
# _________________________________________________________________
# activation_33 (Activation)   (None, 108, 256)          0
# _________________________________________________________________
# conv1d_34 (Conv1D)           (None, 106, 256)          196864
# _________________________________________________________________
# activation_34 (Activation)   (None, 106, 256)          0
# _________________________________________________________________
# conv1d_35 (Conv1D)           (None, 104, 256)          196864
# _________________________________________________________________
# activation_35 (Activation)   (None, 104, 256)          0
# _________________________________________________________________
# conv1d_36 (Conv1D)           (None, 102, 256)          196864
# _________________________________________________________________
# activation_36 (Activation)   (None, 102, 256)          0
# _________________________________________________________________
# max_pooling1d_18 (MaxPooling (None, 34, 256)           0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 8704)              0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1024)              8913920
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 1024)              1049600
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 1024)              0
# _________________________________________________________________
# dense_17 (Dense)             (None, 6)                 6150
# =================================================================
# Total params: 11,454,726
# Trainable params: 11,454,726
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Recurrent CNN model for fake news classification

# %%
import gensim
import numpy as np
import string
import gensim
from gensim.models import Word2Vec
from gensim.utils import simple_preprocess
from gensim.models.keyedvectors import KeyedVectors

# %%
word2vec = KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin', binary=True)

# %%
word2vec.syn0.shape[0]
word2vec.syn0.shape[1]

# %%
# word2vec = gensim.models.Word2Vec.load("word2vec.gensim")
embeddings = np.zeros((word2vec.syn0.shape[0] + 1, word2vec.syn0.shape[1]), dtype = "float32")
embeddings[:word2vec.syn0.shape[0]] = word2vec.syn0

MAX_TOKENS = word2vec.syn0.shape[0]
embedding_dim = word2vec.syn0.shape[1]
hidden_dim_1 = 200
hidden_dim_2 = 100
NUM_CLASSES = 10

document = Input(shape = (None, ), dtype = "int32")
left_context = Input(shape = (None, ), dtype = "int32")
right_context = Input(shape = (None, ), dtype = "int32")

embedder = Embedding(MAX_TOKENS + 1, embedding_dim, weights = [embeddings], trainable = False)
doc_embedding = embedder(document)
l_embedding = embedder(left_context)
r_embedding = embedder(right_context)

forward = LSTM(hidden_dim_1, return_sequences = True)(l_embedding)
backward = LSTM(hidden_dim_1, return_sequences = True, go_backwards = True)(r_embedding)

# Keras returns the output sequences in reverse order.
backward = Lambda(lambda x: backend.reverse(x, axes = 1))(backward)
together = concatenate([forward, doc_embedding, backward], axis = 2)

semantic = Conv1D(hidden_dim_2, kernel_size = 1, activation = "tanh")(together)

## define customized maxpooling layer
pool_rnn = Lambda(lambda x: backend.max(x, axis = 1), output_shape = (hidden_dim_2, ))(semantic)
model_output = Dense(NUM_CLASSES, input_dim = hidden_dim_2, activation = "softmax")(pool_rnn)

## define and compile RCNN mode
RCNN_model = Model(inputs = [document, left_context, right_context], outputs = model_output)
model.compile(optimizer = "adadelta", loss = "categorical_crossentropy", metrics = ["accuracy"])


adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.2)
sgd = SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
RCNN_model.compile(optimizer=sgd,
                   loss='categorical_crossentropy',
                   metrics=['categorical_accuracy'])

RCNN_model.summary()

tb = TensorBoard()
csv_logger = keras.callbacks.CSVLogger('training.log')
filepath= "weights.best.hdf5"
checkpoint = keras.callbacks.ModelCheckpoint(filepath, 
                                             monitor='val_categorical_accuracy', 
                                             verbose=1, save_best_only=True, mode='max')

history_rcnn= RCNN_model.fit({'main_input': x_train, 'aux_input': x_train_metadata},
                             {'main_output': y_train},epochs=num_epochs, batch_size=batch_size,
                             validation_data=({'main_input': x_val, 'aux_input': x_val_metadata},{'main_output': y_val}),
                             callbacks=[tb,csv_logger,checkpoint])

# %%
text = "This is some example text."
text = text.strip().lower().translate(str.maketrans({key: " {0} ".format(key) for key in string.punctuation}))
tokens = text.split()
tokens = [word2vec.vocab[token].index if token in word2vec.vocab else MAX_TOKENS for token in tokens]

doc_as_array = np.array([tokens])
# We shift the document to the right to obtain the left-side contexts.
left_context_as_array = np.array([[MAX_TOKENS] + tokens[:-1]])
# We shift the document to the left to obtain the right-side contexts.
right_context_as_array = np.array([tokens[1:] + [MAX_TOKENS]])

target = np.array([NUM_CLASSES * [0]])
target[0][3] = 1

history = model.fit([doc_as_array, left_context_as_array, right_context_as_array], target, epochs = 1, verbose = 0)
loss = history.history["loss"][0]
