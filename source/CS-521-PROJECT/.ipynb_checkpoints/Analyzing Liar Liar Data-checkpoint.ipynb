# %% [markdown]
# # Importing necessary Libraries

# %%
# http://aclweb.org/anthology/Q16-1005
# https://www.cs.purdue.edu/homes/dgoldwas/papers/JGACL17.pdf

# %%
# import pandas library for data management
# import Stanford Core NLP for data analisys
            
import pandas as pd
from pycorenlp import StanfordCoreNLP

# %%
# setup StanfordCoreNlp
# Run the server using all jars in the current directory (e.g., the CoreNLP home directory)
# java -mx4g -cp "*" edu.stanford.nlp.pipeline.StanfordCoreNLPServer -port 9000 -timeout 15000
nlp = StanfordCoreNLP('http://localhost:9000')

# %% [markdown]
# # Load training data

# %%
train_data = pd.read_excel('..\\dataset\\train_annotated.xlsx')

# %%
train_data
# Out:
#                ID                                          Statement  \
# 0       2635.json  Says the Annies List political group supports ...
# 1      10540.json  When did the decline of coal start? It started...
# 2        324.json  Hillary Clinton agrees with John McCain "by vo...
# 3       1123.json  Health care reform legislation is likely to ma...
# 4       9028.json  The economic turnaround started at the end of ...
# 5      12465.json  The Chicago Bears have had more starting quart...
# 6       2342.json  Jim Dunnam has not lived in the district he re...
# 7        153.json  I'm the only person on this stage who has work...
# 8       5602.json  However, it took $19.5 million in Oregon Lotte...
# 9       9741.json  Says GOP primary opponents Glenn Grothman and ...
# 10      7115.json  For the first time in history, the share of th...
# 11      4148.json  Since 2000, nearly 12 million Americans have s...
# 12      5947.json  When Mitt Romney was governor of Massachusetts...
# 13      8616.json  The economy bled $24 billion due to the govern...
# 14      8705.json  Most of the (Affordable Care Act) has already ...
# 15     10683.json  In this last election in November, ... 63 perc...
# 16       620.json  McCain opposed a requirement that the governme...
# 17      3863.json  U.S. Rep. Ron Kind, D-Wis., and his fellow Dem...
# 18     12372.json  Water rates in Manila, Philippines, were raise...
# 19     12385.json  Almost 100,000 people left Puerto Rico last year.
# 20     10173.json  Women and men both are making less when you ad...
# 21      9867.json  The United States has the highest corporate ta...
# 22     12408.json  We just had the best year for the auto industr...
# 23      2673.json  Says Scott Walker favors cutting up to 350,000...
# 24      7057.json  Says Mitt Romney wants to get rid of Planned P...
# 25     10215.json              I dont know who (Jonathan Gruber) is.
# 26     12517.json  Hate crimes against American Muslims and mosqu...
# 27      3910.json  Rick Perry has never lost an election and rema...
# 28     11092.json  ISIS supporter tweeted at 10:34 a.m. Shooting ...
# 29     12163.json  Youth unemployment in minority communities is ...
# ...           ...                                                ...
# 10239   8119.json  Since the Affordable Care Act passed, 90 perce...
# 10240   1550.json  Debt has almost doubled in Austin under Gov. P...
# 10241   4077.json  Lets say (Republicans) take away half of our d...
# 10242  11207.json  Theres a tremendous other number of public off...
# 10243   4216.json  Under last years health care reform, a bunch o...
# 10244   9365.json  The Obama administration spent $205,075 in sti...
# 10245    981.json  There has been no net global warming for over ...
# 10246  11074.json  Thanks to the Obama administrations negotiatio...
# 10247   1674.json  This race will be the Democrats top target thi...
# 10248   6032.json  Georgia Public Service Commission member Stan ...
# 10249   7388.json  Says he and Mitt Romney agreed on tying minimu...
# 10250  10166.json  As a result of Obamacare, California seniors f...
# 10251   8371.json  For the first time since the Korean War, total...
# 10252   3744.json  Says Rick Perry turned down our invitation to ...
# 10253   8262.json  In 2012, the state put together a list of over...
# 10254   1918.json  The Republican Party lost 1.1 million register...
# 10255   4614.json  The proudest accomplishment (of my tenure) was...
# 10256  13344.json  Recently though, the media has reported on tho...
# 10257  13239.json  Stopped by Smiley Cookie to pick up some great...
# 10258   4423.json   Mike Trainor...still owes $250,000 to the state.
# 10259  11018.json  The Supreme Courts views are radically out of ...
# 10260   2930.json  When it comes to the state deficit, Wisconsin ...
# 10261   4886.json  Eighty percent of the net new jobs created in ...
# 10262   4388.json  Mayor Fung wants to punish our childrens educa...
# 10263   1592.json  Under the ruling of the Supreme Court, any lob...
# 10264   5473.json  There are a larger number of shark attacks in ...
# 10265   3408.json  Democrats have now become the party of the [At...
# 10266   3959.json  Says an alternative to Social Security that op...
# 10267   2253.json  On lifting the U.S. Cuban embargo and allowing...
# 10268   1155.json  The Department of Veterans Affairs has a manua...
#
#                                                  Subject        Label  \
# 0                                               abortion        False
# 1                     energy,history,job-accomplishments    half-true
# 2                                         foreign-policy  mostly-true
# 3                                            health-care        False
# 4                                           economy,jobs    half-true
# 5                                              education         True
# 6                                   candidates-biography  barely-true
# 7                                                 ethics    half-true
# 8                                                   jobs    half-true
# 9              energy,message-machine-2014,voting-record  mostly-true
# 10                                             elections  mostly-true
# 11               economy,jobs,new-hampshire-2012,poverty    half-true
# 12                                  history,state-budget        False
# 13                    economy,federal-budget,health-care  mostly-true
# 14                                           health-care  barely-true
# 15                                             elections    half-true
# 16                                        federal-budget         True
# 17                                        federal-budget  barely-true
# 18             financial-regulation,foreign-policy,water    half-true
# 19                         bankruptcy,economy,population  mostly-true
# 20                                        economy,income        False
# 21                                    corporations,taxes  mostly-true
# 22                                               economy  mostly-true
# 23                           health-care,message-machine    half-true
# 24                   abortion,federal-budget,health-care  barely-true
# 25                                           health-care        False
# 26           crime,diversity,homeland-security,terrorism  mostly-true
# 27                                  candidates-biography    half-true
# 28                                  technology,terrorism        False
# 29                                diversity,economy,jobs  mostly-true
# ...                                                  ...          ...
# 10239                               economy,jobs,workers         True
# 10240                                            economy         True
# 10241                                          elections    half-true
# 10242                            technology,transparency  barely-true
# 10243                                        health-care        False
# 10244                                   economy,stimulus  barely-true
# 10245                         climate-change,environment        False
# 10246           foreign-policy,homeland-security,nuclear    half-true
# 10247                                   elections,states        False
# 10248                                   campaign-finance    half-true
# 10249                                    poverty,workers  mostly-true
# 10250  federal-budget,health-care,medicare,message-ma...        False
# 10251                                     federal-budget         True
# 10252                         bipartisanship,immigration  mostly-true
# 10253                                          elections  barely-true
# 10254                           bipartisanship,elections    half-true
# 10255                  state-budget,state-finances,taxes  mostly-true
# 10256                                          elections   pants-fire
# 10257                                               food  barely-true
# 10258                    bankruptcy,economy,legal-issues  mostly-true
# 10259              gays-and-lesbians,polls,supreme-court  barely-true
# 10260                                       state-budget    half-true
# 10261                                       economy,jobs    half-true
# 10262  children,city-budget,deficit,education,state-b...   pants-fire
# 10263                             corporations,elections    half-true
# 10264                                  animals,elections  mostly-true
# 10265                                          elections  mostly-true
# 10266                         retirement,social-security    half-true
# 10267                             florida,foreign-policy        False
# 10268                               health-care,veterans   pants-fire
#
#                                                  Context  \
# 0                                               a mailer
# 1                                        a floor speech.
# 2                                                 Denver
# 3                                         a news release
# 4                                    an interview on CNN
# 5                              a an online opinion-piece
# 6                                       a press release.
# 7               a Democratic debate in Philadelphia, Pa.
# 8                                             a website
# 9                                        an online video
# 10                                              a speech
# 11                                               a tweet
# 12                            an interview with CBN News
# 13               a Doonesbury strip in the Sunday comics
# 14                         comments on "Fox News Sunday"
# 15                          a town hall in Austin, Texas
# 16                                            a radio ad
# 17                                        a news release
# 18                               a congressional hearing
# 19                      an interview with Bloomberg News
# 20                                     a campaign debate
# 21                  a discussion on Fox News' "The Five"
# 22                           remarks at a Kentucky rally
# 23                                      a campaign TV ad
# 24                                            a radio ad
# 25                                     a news conference
# 26          a speech after a terrorist attack in Orlando
# 27                                       an oped column.
# 28                                              a tweet
# 29                                a gubernatorial debate
# ...                                                  ...
# 10239             an interview with Bloomberg television
# 10240                                           a speech
# 10241  an interview with the "St. Petersburg Times" e...
# 10242                      an interview on "Morning Joe"
# 10243                                  a news conference
# 10244                                           a report
# 10245                         a political advertisement.
# 10246                                           an op-ed
# 10247                                           a mailer
# 10248                                        a statement
# 10249                     the State of the Union address
# 10250                                      a campaign ad
# 10251                    an op-ed in the Tampa Bay Times
# 10252               a press gaggle aboard Air Force One.
# 10253                    a speech to Louisiana Democrats
# 10254                                    a press release
# 10255                               an interview on NJTV
# 10256                                          a debate.
# 10257                                   a Facebook post.
# 10258                             a talk show discussion
# 10259                                an interview on NPR
# 10260                             a television interview
# 10261                       a New York magazine article.
# 10262  a recorded telephone message to Cranston resid...
# 10263                    an interview on ABC's This Week
# 10264                  interview on "The Colbert Report"
# 10265                                       an interview
# 10266                   a Republican presidential debate
# 10267  a televised debate on Miami's WPLG-10 against ...
# 10268                               a Fox News interview
#
#                                                 Word POS  \
# 0      Says/VBZ the/DT Annies/NNPS List/VBP political...
# 1      When/WRB did/VBD the/DT decline/NN of/IN coal/...
# 2      Hillary/NNP Clinton/NNP agrees/VBZ with/IN Joh...
# 3      Health/NNP care/NN reform/NN legislation/NN is...
# 4      The/DT economic/JJ turnaround/NN started/VBD a...
# 5      The/DT Chicago/NNP Bears/NNPS have/VBP had/VBN...
# 6      Jim/NNP Dunnam/NNP has/VBZ not/RB lived/VBN in...
# 7      I/PRP 'm/VBP the/DT only/JJ person/NN on/IN th...
# 8      However/RB ,/, it/PRP took/VBD $/$ 19.5/CD mil...
# 9      Says/VBZ GOP/NNP primary/JJ opponents/NNS Glen...
# 10     For/IN the/DT first/JJ time/NN in/IN history/N...
# 11     Since/IN 2000/CD ,/, nearly/RB 12/CD million/C...
# 12     When/WRB Mitt/NNP Romney/NNP was/VBD governor/...
# 13     The/DT economy/NN bled/VBD $/$ 24/CD billion/C...
# 14     Most/JJS of/IN the/DT -LRB-/-LRB- Affordable/N...
# 15     In/IN this/DT last/JJ election/NN in/IN Novemb...
# 16     McCain/NNP opposed/VBD a/DT requirement/NN tha...
# 17     U.S./NNP Rep./NNP Ron/NNP Kind/NNP ,/, D-Wis./...
# 18     Water/NN rates/NNS in/IN Manila/NNP ,/, Philip...
# 19     Almost/RB 100,000/CD people/NNS left/VBD Puert...
# 20     Women/NNS and/CC men/NNS both/CC are/VBP makin...
# 21     The/DT United/NNP States/NNPS has/VBZ the/DT h...
# 22     We/PRP just/RB had/VBD the/DT best/JJS year/NN...
# 23     Says/VBZ Scott/NNP Walker/NNP favors/VBZ cutti...
# 24     Says/VBZ Mitt/NNP Romney/NNP wants/VBZ to/TO g...
# 25     I/PRP dont/VBP know/VB who/WP -LRB-/-LRB- Jona...
# 26     Hate/VB crimes/NNS against/IN American/JJ Musl...
# 27     Rick/NNP Perry/NNP has/VBZ never/RB lost/VBN a...
# 28     ISIS/NNP supporter/NN tweeted/VBD at/IN 10:34/...
# 29     Youth/NN unemployment/NN in/IN minority/NN com...
# ...                                                  ...
# 10239  Since/IN the/DT Affordable/NNP Care/NNP Act/NN...
# 10240  Debt/NN has/VBZ almost/RB doubled/VBN in/IN Au...
# 10241  Lets/NNS say/VBP -LRB-/-LRB- Republicans/NNPS ...
# 10242  Theres/VBZ a/DT tremendous/JJ other/JJ number/...
# 10243  Under/IN last/JJ years/NNS health/NN care/NN r...
# 10244  The/DT Obama/NNP administration/NN spent/VBD $...
# 10245  There/EX has/VBZ been/VBN no/DT net/JJ global/...
# 10246  Thanks/NNS to/TO the/DT Obama/NNP administrati...
# 10247  This/DT race/NN will/MD be/VB the/DT Democrats...
# 10248  Georgia/NNP Public/NNP Service/NNP Commission/...
# 10249  Says/VBZ he/PRP and/CC Mitt/NNP Romney/NNP agr...
# 10250  As/IN a/DT result/NN of/IN Obamacare/NNP ,/, C...
# 10251  For/IN the/DT first/JJ time/NN since/IN the/DT...
# 10252  Says/VBZ Rick/NNP Perry/NNP turned/VBD down/RP...
# 10253  In/IN 2012/CD ,/, the/DT state/NN put/VBN toge...
# 10254  The/DT Republican/NNP Party/NNP lost/VBD 1.1/C...
# 10255  The/DT proudest/JJS accomplishment/NN -LRB-/-L...
# 10256  Recently/RB though/RB ,/, the/DT media/NNS has...
# 10257  Stopped/VBN by/IN Smiley/NNP Cookie/NNP to/TO ...
# 10258  Mike/NNP Trainor/NNP .../: still/RB owes/VBZ $...
# 10259  The/DT Supreme/NNP Courts/NNPS views/NNS are/V...
# 10260  When/WRB it/PRP comes/VBZ to/TO the/DT state/N...
# 10261  Eighty/CD percent/NN of/IN the/DT net/JJ new/J...
# 10262  Mayor/NNP Fung/NNP wants/VBZ to/TO punish/VB o...
# 10263  Under/IN the/DT ruling/NN of/IN the/DT Supreme...
# 10264  There/EX are/VBP a/DT larger/JJR number/NN of/...
# 10265  Democrats/NNS have/VBP now/RB become/VB the/DT...
# 10266  Says/VBZ an/DT alternative/JJ to/TO Social/NNP...
# 10267  On/IN lifting/VBG the/DT U.S./NNP Cuban/NNP em...
# 10268  The/DT Department/NNP of/IN Veterans/NNP Affai...
#
#                                                      POS  Word Count  \
# 0      ['<s>', 'VBZ', 'DT', 'NNPS', 'VBP', 'JJ', 'NN'...          12
# 1      ['<s>', 'WRB', 'VBD', 'DT', 'NN', 'IN', 'NN', ...          28
# 2      ['<s>', 'NNP', 'NNP', 'VBZ', 'IN', 'NNP', 'NNP...          22
# 3      ['<s>', 'NNP', 'NN', 'NN', 'NN', 'VBZ', 'JJ', ...          13
# 4      ['<s>', 'DT', 'JJ', 'NN', 'VBD', 'IN', 'DT', '...          11
# 5      ['<s>', 'DT', 'NNP', 'NNPS', 'VBP', 'VBN', 'RB...          30
# 6      ['<s>', 'NNP', 'NNP', 'VBZ', 'RB', 'VBN', 'IN'...          14
# 7      ['<s>', 'PRP', 'VBP', 'DT', 'JJ', 'NN', 'IN', ...          31
# 8      ['<s>', 'RB', ',', 'PRP', 'VBD', '$', 'CD', 'C...          26
# 9      ['<s>', 'VBZ', 'NNP', 'JJ', 'NNS', 'NNP', 'NNP...          23
# 10     ['<s>', 'IN', 'DT', 'JJ', 'NN', 'IN', 'NN', ',...          23
# 11     ['<s>', 'IN', 'CD', ',', 'RB', 'CD', 'CD', 'NN...          18
# 12     ['<s>', 'WRB', 'NNP', 'NNP', 'VBD', 'NN', 'IN'...          25
# 13     ['<s>', 'DT', 'NN', 'VBD', '$', 'CD', 'CD', 'J...          12
# 14     ['<s>', 'JJS', 'IN', 'DT', '-LRB-', 'NNP', 'NN...          19
# 15     ['<s>', 'IN', 'DT', 'JJ', 'NN', 'IN', 'NNP', '...          39
# 16     ['<s>', 'NNP', 'VBD', 'DT', 'NN', 'IN', 'DT', ...          23
# 17     ['<s>', 'NNP', 'NNP', 'NNP', 'NNP', ',', 'NNP'...          24
# 18     ['<s>', 'NN', 'NNS', 'IN', 'NNP', ',', 'NNP', ...          25
# 19     ['<s>', 'RB', 'CD', 'NNS', 'VBD', 'NNP', 'NNP'...           9
# 20     ['<s>', 'NNS', 'CC', 'NNS', 'CC', 'VBP', 'VBG'...          21
# 21     ['<s>', 'DT', 'NNP', 'NNPS', 'VBZ', 'DT', 'JJS...          14
# 22     ['<s>', 'PRP', 'RB', 'VBD', 'DT', 'JJS', 'NN',...          15
# 23     ['<s>', 'VBZ', 'NNP', 'NNP', 'VBZ', 'VBG', 'RP...          15
# 24     ['<s>', 'VBZ', 'NNP', 'NNP', 'VBZ', 'TO', 'VB'...          11
# 25     ['<s>', 'PRP', 'VBP', 'VB', 'WP', '-LRB-', 'NN...          10
# 26     ['<s>', 'VB', 'NNS', 'IN', 'JJ', 'NNPS', 'CC',...          15
# 27     ['<s>', 'NNP', 'NNP', 'VBZ', 'RB', 'VBN', 'DT'...          24
# 28     ['<s>', 'NNP', 'NN', 'VBD', 'IN', 'CD', 'RB', ...          16
# 29     ['<s>', 'NN', 'NN', 'IN', 'NN', 'NNS', 'VBZ', ...          12
# ...                                                  ...         ...
# 10239  ['<s>', 'IN', 'DT', 'NNP', 'NNP', 'NNP', 'VBD'...          18
# 10240  ['<s>', 'NN', 'VBZ', 'RB', 'VBN', 'IN', 'NNP',...          10
# 10241  ['<s>', 'NNS', 'VBP', '-LRB-', 'NNPS', '-RRB-'...          26
# 10242  ['<s>', 'VBZ', 'DT', 'JJ', 'JJ', 'NN', 'IN', '...          23
# 10243  ['<s>', 'IN', 'JJ', 'NNS', 'NN', 'NN', 'NN', '...          26
# 10244  ['<s>', 'DT', 'NNP', 'NN', 'VBD', '$', 'CD', '...          19
# 10245  ['<s>', 'EX', 'VBZ', 'VBN', 'DT', 'JJ', 'JJ', ...          13
# 10246  ['<s>', 'NNS', 'TO', 'DT', 'NNP', 'NNS', 'NNS'...          28
# 10247  ['<s>', 'DT', 'NN', 'MD', 'VB', 'DT', 'NNPS', ...          11
# 10248  ['<s>', 'NNP', 'NNP', 'NNP', 'NNP', 'NN', 'NNP...          26
# 10249  ['<s>', 'VBZ', 'PRP', 'CC', 'NNP', 'NNP', 'VBD...          14
# 10250  ['<s>', 'IN', 'DT', 'NN', 'IN', 'NNP', ',', 'N...          16
# 10251  ['<s>', 'IN', 'DT', 'JJ', 'NN', 'IN', 'DT', 'J...          22
# 10252  ['<s>', 'VBZ', 'NNP', 'NNP', 'VBD', 'RP', 'PRP...          16
# 10253  ['<s>', 'IN', 'CD', ',', 'DT', 'NN', 'VBN', 'R...          29
# 10254  ['<s>', 'DT', 'NNP', 'NNP', 'VBD', 'CD', 'CD',...          32
# 10255  ['<s>', 'DT', 'JJS', 'NN', '-LRB-', 'IN', 'PRP...          37
# 10256  ['<s>', 'RB', 'RB', ',', 'DT', 'NNS', 'VBZ', '...          17
# 10257  ['<s>', 'VBN', 'IN', 'NNP', 'NNP', 'TO', 'VB',...          18
# 10258  ['<s>', 'NNP', 'NNP', ':', 'RB', 'VBZ', '$', '...          11
# 10259  ['<s>', 'DT', 'NNP', 'NNPS', 'NNS', 'VBP', 'RB...          21
# 10260  ['<s>', 'WRB', 'PRP', 'VBZ', 'TO', 'DT', 'NN',...          21
# 10261  ['<s>', 'CD', 'NN', 'IN', 'DT', 'JJ', 'JJ', 'N...          20
# 10262  ['<s>', 'NNP', 'NNP', 'VBZ', 'TO', 'VB', 'PRP$...          37
# 10263  ['<s>', 'IN', 'DT', 'NN', 'IN', 'DT', 'NNP', '...          43
# 10264  ['<s>', 'EX', 'VBP', 'DT', 'JJR', 'NN', 'IN', ...          18
# 10265  ['<s>', 'NNS', 'VBP', 'RB', 'VB', 'DT', 'NN', ...          17
# 10266  ['<s>', 'VBZ', 'DT', 'JJ', 'TO', 'NNP', 'NNP',...          31
# 10267  ['<s>', 'IN', 'VBG', 'DT', 'NNP', 'NNP', 'NN',...          12
# 10268  ['<s>', 'DT', 'NNP', 'IN', 'NNP', 'NNP', 'VBZ'...          36
#
#       Sentiment  Sentiment Value  \
# 0      Negative                1
# 1       Neutral                2
# 2      Negative                1
# 3      Negative                1
# 4       Neutral                2
# 5      Negative                1
# 6      Negative                1
# 7      Negative                1
# 8       Neutral                2
# 9      Negative                1
# 10     Positive                3
# 11     Negative                1
# 12     Negative                1
# 13      Neutral                2
# 14     Negative                1
# 15     Negative                1
# 16     Negative                1
# 17     Positive                3
# 18     Negative                1
# 19     Negative                1
# 20      Neutral                2
# 21     Positive                3
# 22     Positive                3
# 23     Negative                1
# 24     Negative                1
# 25     Negative                1
# 26     Negative                1
# 27     Negative                1
# 28     Negative                1
# 29     Negative                1
# ...         ...              ...
# 10239  Negative                1
# 10240  Negative                1
# 10241  Positive                3
# 10242  Positive                3
# 10243  Negative                1
# 10244  Negative                1
# 10245  Negative                1
# 10246  Negative                1
# 10247   Neutral                2
# 10248  Negative                1
# 10249  Negative                1
# 10250  Negative                1
# 10251  Negative                1
# 10252  Negative                1
# 10253  Negative                1
# 10254  Negative                1
# 10255  Negative                1
# 10256   Neutral                2
# 10257  Positive                3
# 10258   Neutral                2
# 10259  Negative                1
# 10260  Negative                1
# 10261  Negative                1
# 10262  Negative                1
# 10263  Negative                1
# 10264  Negative                1
# 10265  Negative                1
# 10266  Negative                1
# 10267   Neutral                2
# 10268  Positive                3
#
#                                                   Bigram  \
# 0      ['<s> VBZ', 'VBZ DT', 'DT NNPS', 'NNPS VBP', '...
# 1      ['<s> WRB', 'WRB VBD', 'VBD DT', 'DT NN', 'NN ...
# 2      ['<s> NNP', 'NNP NNP', 'NNP VBZ', 'VBZ IN', 'I...
# 3      ['<s> NNP', 'NNP NN', 'NN NN', 'NN NN', 'NN VB...
# 4      ['<s> DT', 'DT JJ', 'JJ NN', 'NN VBD', 'VBD IN...
# 5      ['<s> DT', 'DT NNP', 'NNP NNPS', 'NNPS VBP', '...
# 6      ['<s> NNP', 'NNP NNP', 'NNP VBZ', 'VBZ RB', 'R...
# 7      ['<s> PRP', 'PRP VBP', 'VBP DT', 'DT JJ', 'JJ ...
# 8      ['<s> RB', 'RB ,', ', PRP', 'PRP VBD', 'VBD $'...
# 9      ['<s> VBZ', 'VBZ NNP', 'NNP JJ', 'JJ NNS', 'NN...
# 10     ['<s> IN', 'IN DT', 'DT JJ', 'JJ NN', 'NN IN',...
# 11     ['<s> IN', 'IN CD', 'CD ,', ', RB', 'RB CD', '...
# 12     ['<s> WRB', 'WRB NNP', 'NNP NNP', 'NNP VBD', '...
# 13     ['<s> DT', 'DT NN', 'NN VBD', 'VBD $', '$ CD',...
# 14     ['<s> JJS', 'JJS IN', 'IN DT', 'DT -LRB-', '-L...
# 15     ['<s> IN', 'IN DT', 'DT JJ', 'JJ NN', 'NN IN',...
# 16     ['<s> NNP', 'NNP VBD', 'VBD DT', 'DT NN', 'NN ...
# 17     ['<s> NNP', 'NNP NNP', 'NNP NNP', 'NNP NNP', '...
# 18     ['<s> NN', 'NN NNS', 'NNS IN', 'IN NNP', 'NNP ...
# 19     ['<s> RB', 'RB CD', 'CD NNS', 'NNS VBD', 'VBD ...
# 20     ['<s> NNS', 'NNS CC', 'CC NNS', 'NNS CC', 'CC ...
# 21     ['<s> DT', 'DT NNP', 'NNP NNPS', 'NNPS VBZ', '...
# 22     ['<s> PRP', 'PRP RB', 'RB VBD', 'VBD DT', 'DT ...
# 23     ['<s> VBZ', 'VBZ NNP', 'NNP NNP', 'NNP VBZ', '...
# 24     ['<s> VBZ', 'VBZ NNP', 'NNP NNP', 'NNP VBZ', '...
# 25     ['<s> PRP', 'PRP VBP', 'VBP VB', 'VB WP', 'WP ...
# 26     ['<s> VB', 'VB NNS', 'NNS IN', 'IN JJ', 'JJ NN...
# 27     ['<s> NNP', 'NNP NNP', 'NNP VBZ', 'VBZ RB', 'R...
# 28     ['<s> NNP', 'NNP NN', 'NN VBD', 'VBD IN', 'IN ...
# 29     ['<s> NN', 'NN NN', 'NN IN', 'IN NN', 'NN NNS'...
# ...                                                  ...
# 10239  ['<s> IN', 'IN DT', 'DT NNP', 'NNP NNP', 'NNP ...
# 10240  ['<s> NN', 'NN VBZ', 'VBZ RB', 'RB VBN', 'VBN ...
# 10241  ['<s> NNS', 'NNS VBP', 'VBP -LRB-', '-LRB- NNP...
# 10242  ['<s> VBZ', 'VBZ DT', 'DT JJ', 'JJ JJ', 'JJ NN...
# 10243  ['<s> IN', 'IN JJ', 'JJ NNS', 'NNS NN', 'NN NN...
# 10244  ['<s> DT', 'DT NNP', 'NNP NN', 'NN VBD', 'VBD ...
# 10245  ['<s> EX', 'EX VBZ', 'VBZ VBN', 'VBN DT', 'DT ...
# 10246  ['<s> NNS', 'NNS TO', 'TO DT', 'DT NNP', 'NNP ...
# 10247  ['<s> DT', 'DT NN', 'NN MD', 'MD VB', 'VB DT',...
# 10248  ['<s> NNP', 'NNP NNP', 'NNP NNP', 'NNP NNP', '...
# 10249  ['<s> VBZ', 'VBZ PRP', 'PRP CC', 'CC NNP', 'NN...
# 10250  ['<s> IN', 'IN DT', 'DT NN', 'NN IN', 'IN NNP'...
# 10251  ['<s> IN', 'IN DT', 'DT JJ', 'JJ NN', 'NN IN',...
# 10252  ['<s> VBZ', 'VBZ NNP', 'NNP NNP', 'NNP VBD', '...
# 10253  ['<s> IN', 'IN CD', 'CD ,', ', DT', 'DT NN', '...
# 10254  ['<s> DT', 'DT NNP', 'NNP NNP', 'NNP VBD', 'VB...
# 10255  ['<s> DT', 'DT JJS', 'JJS NN', 'NN -LRB-', '-L...
# 10256  ['<s> RB', 'RB RB', 'RB ,', ', DT', 'DT NNS', ...
# 10257  ['<s> VBN', 'VBN IN', 'IN NNP', 'NNP NNP', 'NN...
# 10258  ['<s> NNP', 'NNP NNP', 'NNP :', ': RB', 'RB VB...
# 10259  ['<s> DT', 'DT NNP', 'NNP NNPS', 'NNPS NNS', '...
# 10260  ['<s> WRB', 'WRB PRP', 'PRP VBZ', 'VBZ TO', 'T...
# 10261  ['<s> CD', 'CD NN', 'NN IN', 'IN DT', 'DT JJ',...
# 10262  ['<s> NNP', 'NNP NNP', 'NNP VBZ', 'VBZ TO', 'T...
# 10263  ['<s> IN', 'IN DT', 'DT NN', 'NN IN', 'IN DT',...
# 10264  ['<s> EX', 'EX VBP', 'VBP DT', 'DT JJR', 'JJR ...
# 10265  ['<s> NNS', 'NNS VBP', 'VBP RB', 'RB VB', 'VB ...
# 10266  ['<s> VBZ', 'VBZ DT', 'DT JJ', 'JJ TO', 'TO NN...
# 10267  ['<s> IN', 'IN VBG', 'VBG DT', 'DT NNP', 'NNP ...
# 10268  ['<s> DT', 'DT NNP', 'NNP IN', 'IN NNP', 'NNP ...
#
#                                                  Trigram
# 0      ['<s> VBZ DT', 'VBZ DT NNPS', 'DT NNPS VBP', '...
# 1      ['<s> WRB VBD', 'WRB VBD DT', 'VBD DT NN', 'DT...
# 2      ['<s> NNP NNP', 'NNP NNP VBZ', 'NNP VBZ IN', '...
# 3      ['<s> NNP NN', 'NNP NN NN', 'NN NN NN', 'NN NN...
# 4      ['<s> DT JJ', 'DT JJ NN', 'JJ NN VBD', 'NN VBD...
# 5      ['<s> DT NNP', 'DT NNP NNPS', 'NNP NNPS VBP', ...
# 6      ['<s> NNP NNP', 'NNP NNP VBZ', 'NNP VBZ RB', '...
# 7      ['<s> PRP VBP', 'PRP VBP DT', 'VBP DT JJ', 'DT...
# 8      ['<s> RB ,', 'RB , PRP', ', PRP VBD', 'PRP VBD...
# 9      ['<s> VBZ NNP', 'VBZ NNP JJ', 'NNP JJ NNS', 'J...
# 10     ['<s> IN DT', 'IN DT JJ', 'DT JJ NN', 'JJ NN I...
# 11     ['<s> IN CD', 'IN CD ,', 'CD , RB', ', RB CD',...
# 12     ['<s> WRB NNP', 'WRB NNP NNP', 'NNP NNP VBD', ...
# 13     ['<s> DT NN', 'DT NN VBD', 'NN VBD $', 'VBD $ ...
# 14     ['<s> JJS IN', 'JJS IN DT', 'IN DT -LRB-', 'DT...
# 15     ['<s> IN DT', 'IN DT JJ', 'DT JJ NN', 'JJ NN I...
# 16     ['<s> NNP VBD', 'NNP VBD DT', 'VBD DT NN', 'DT...
# 17     ['<s> NNP NNP', 'NNP NNP NNP', 'NNP NNP NNP', ...
# 18     ['<s> NN NNS', 'NN NNS IN', 'NNS IN NNP', 'IN ...
# 19     ['<s> RB CD', 'RB CD NNS', 'CD NNS VBD', 'NNS ...
# 20     ['<s> NNS CC', 'NNS CC NNS', 'CC NNS CC', 'NNS...
# 21     ['<s> DT NNP', 'DT NNP NNPS', 'NNP NNPS VBZ', ...
# 22     ['<s> PRP RB', 'PRP RB VBD', 'RB VBD DT', 'VBD...
# 23     ['<s> VBZ NNP', 'VBZ NNP NNP', 'NNP NNP VBZ', ...
# 24     ['<s> VBZ NNP', 'VBZ NNP NNP', 'NNP NNP VBZ', ...
# 25     ['<s> PRP VBP', 'PRP VBP VB', 'VBP VB WP', 'VB...
# 26     ['<s> VB NNS', 'VB NNS IN', 'NNS IN JJ', 'IN J...
# 27     ['<s> NNP NNP', 'NNP NNP VBZ', 'NNP VBZ RB', '...
# 28     ['<s> NNP NN', 'NNP NN VBD', 'NN VBD IN', 'VBD...
# 29     ['<s> NN NN', 'NN NN IN', 'NN IN NN', 'IN NN N...
# ...                                                  ...
# 10239  ['<s> IN DT', 'IN DT NNP', 'DT NNP NNP', 'NNP ...
# 10240  ['<s> NN VBZ', 'NN VBZ RB', 'VBZ RB VBN', 'RB ...
# 10241  ['<s> NNS VBP', 'NNS VBP -LRB-', 'VBP -LRB- NN...
# 10242  ['<s> VBZ DT', 'VBZ DT JJ', 'DT JJ JJ', 'JJ JJ...
# 10243  ['<s> IN JJ', 'IN JJ NNS', 'JJ NNS NN', 'NNS N...
# 10244  ['<s> DT NNP', 'DT NNP NN', 'NNP NN VBD', 'NN ...
# 10245  ['<s> EX VBZ', 'EX VBZ VBN', 'VBZ VBN DT', 'VB...
# 10246  ['<s> NNS TO', 'NNS TO DT', 'TO DT NNP', 'DT N...
# 10247  ['<s> DT NN', 'DT NN MD', 'NN MD VB', 'MD VB D...
# 10248  ['<s> NNP NNP', 'NNP NNP NNP', 'NNP NNP NNP', ...
# 10249  ['<s> VBZ PRP', 'VBZ PRP CC', 'PRP CC NNP', 'C...
# 10250  ['<s> IN DT', 'IN DT NN', 'DT NN IN', 'NN IN N...
# 10251  ['<s> IN DT', 'IN DT JJ', 'DT JJ NN', 'JJ NN I...
# 10252  ['<s> VBZ NNP', 'VBZ NNP NNP', 'NNP NNP VBD', ...
# 10253  ['<s> IN CD', 'IN CD ,', 'CD , DT', ', DT NN',...
# 10254  ['<s> DT NNP', 'DT NNP NNP', 'NNP NNP VBD', 'N...
# 10255  ['<s> DT JJS', 'DT JJS NN', 'JJS NN -LRB-', 'N...
# 10256  ['<s> RB RB', 'RB RB ,', 'RB , DT', ', DT NNS'...
# 10257  ['<s> VBN IN', 'VBN IN NNP', 'IN NNP NNP', 'NN...
# 10258  ['<s> NNP NNP', 'NNP NNP :', 'NNP : RB', ': RB...
# 10259  ['<s> DT NNP', 'DT NNP NNPS', 'NNP NNPS NNS', ...
# 10260  ['<s> WRB PRP', 'WRB PRP VBZ', 'PRP VBZ TO', '...
# 10261  ['<s> CD NN', 'CD NN IN', 'NN IN DT', 'IN DT J...
# 10262  ['<s> NNP NNP', 'NNP NNP VBZ', 'NNP VBZ TO', '...
# 10263  ['<s> IN DT', 'IN DT NN', 'DT NN IN', 'NN IN D...
# 10264  ['<s> EX VBP', 'EX VBP DT', 'VBP DT JJR', 'DT ...
# 10265  ['<s> NNS VBP', 'NNS VBP RB', 'VBP RB VB', 'RB...
# 10266  ['<s> VBZ DT', 'VBZ DT JJ', 'DT JJ TO', 'JJ TO...
# 10267  ['<s> IN VBG', 'IN VBG DT', 'VBG DT NNP', 'DT ...
# 10268  ['<s> DT NNP', 'DT NNP IN', 'NNP IN NNP', 'IN ...
#
# [10269 rows x 12 columns]

# %%
# Create a dictionary to represent data and better manipulation
data_dict =  dict()
data_dict['ids'] = train_data[['ID']].values[:,0]
data_dict['labels'] = train_data[['Label']].values[:,0]
data_dict['statements'] = train_data[['Statement']].values[:,0]
data_dict['subjects'] = train_data[['Subject']].values[:,0]
data_dict['contexts'] = train_data[['Context']].values[:,0]
data_dict['pos'] = train_data[['POS']].values[:,0]
data_dict['word_count'] = train_data[['Word Count']].values[:,0]
data_dict['sentiment'] = train_data[['Sentiment']].values[:,0]
data_dict['sentiment_value'] = train_data[['Sentiment Value']].values[:,0]
data_dict['pos_bigrams'] = train_data[['Bigram']].values[:,0]
data_dict['pos_trigrams'] = train_data[['Trigram']].values[:,0]

# %%
# Replace boolean values to str
data_dict['labels'] = np.array([x if x!= True else 'true' for x in data_dict['labels']])
data_dict['labels'] = np.array([x.lower() for x in data_dict['labels']])

# %%
data_dict['labels'][20:40]
# Out:
# array(['false', 'mostly-true', 'mostly-true', 'half-true', 'barely-true',
#        'false', 'mostly-true', 'half-true', 'false', 'mostly-true',
#        'true', 'barely-true', 'false', 'mostly-true', 'mostly-true',
#        'true', 'true', 'true', 'pants-fire', 'true'], dtype='<U11')

# %%
new_labels = list()
for labels in data_dict['labels']:
    if labels in ['false','barely-true','pants-fire']:
        new_labels.append('false')
    else:
        new_labels.append('true')

# %%
# add a new column dividing statements into false and new
data_dict['new_labels'] = new_labels

# %% [markdown]
# ## Create a graph to visualize the distribution of statements given their labels

# %%
# import needed libraries first
import matplotlib.pyplot as plt
import numpy as np

# %%
# create plot labels and values
statement_labels,statement_count = np.unique(data_dict['labels'], return_counts=True)

# %%
# create the plot itself
plt.rcdefaults()
fig, ax = plt.subplots()

y_pos = np.arange(len(statement_labels))
ax.barh(y_pos, statement_count, align='center',
        color='#006699', ecolor='black')
ax.set_yticks(y_pos)
ax.set_yticklabels(statement_labels)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Number of statements')
ax.set_title('Train data distribution')

plt.show()

# %%
# Consider two big group of data: True and False
false_statements = data_dict['statements'][[i for i,x in enumerate(data_dict['labels']) if x in ['false','barely-true','pants-fire']]]
true_statements = data_dict['statements'][[i for i,x in enumerate(data_dict['labels']) if x in ['true','mostly-true','half-true']]]

# %%
plt.rcdefaults()
fig, ax = plt.subplots()

#define labels
total = len(false_statements) + len(true_statements)
ax.set_title('Train data after re-grouped the labels')
# Pie with news labels distribution after grouped them by True or False labels
labels = 'True', 'False'
sizes = [(len(true_statements)*100)/total, (len(false_statements)*100)/total]
explode = (0, 0.1)

ax.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# %% [markdown]
# # Features selection

# %% [markdown]
# ### POS unigram, bigram and trigram counts

# %%
# Preprocess all POS data. unigram, bigram, trigram wise
import ast
unigram_pos_list = list()
bigram_pos_list = list()
trigram_pos_list = list()

print('Procesing sentences')
for statement_id, statement in enumerate(data_dict['statements']):
    output = nlp.annotate(statement, properties={
      'annotators': 'tokenize,pos',
      'outputFormat': 'json'
      })
    result_pos = list()
    bigram_pos = list()
    trigram_pos = list()
    for o in output['sentences']:
        result_pos.append('<s>')
        for t in o['tokens']:
            result_pos.append('{0}'.format(t['pos']))
        for rpIndex, rp in enumerate(result_pos):
            if rpIndex < len(result_pos)-1 and len(result_pos)>=2:
                bigram_pos.append('{0} {1}'.format(rp, result_pos[rpIndex+1]))
            if rpIndex < len(result_pos)-2 and len(result_pos)>=3:
                trigram_pos.append('{0} {1} {2}'.format(rp, result_pos[rpIndex+1], result_pos[rpIndex+2]))
   
    unigram_pos_list.append(result_pos)
    bigram_pos_list.append(bigram_pos)
    trigram_pos_list.append(trigram_pos)

# %%
data_dict['pos'] = unigram_pos_list
data_dict['pos_bigrams'] = bigram_pos_list
data_dict['pos_trigrams'] = trigram_pos_list

# %%
unique_unigrams_pos = list()
unique_bigrams_pos = list()
unique_trigrams_pos = list()
for index, each_pos in enumerate(data_dict['pos']):
    for each_unigram in each_pos:
        if each_unigram not in unique_unigrams_pos:
            unique_unigrams_pos.append(each_unigram)
    for each_bigram in data_dict['pos_bigrams'][index]:
        if each_bigram not in unique_bigrams_pos:
            unique_bigrams_pos.append(each_bigram)
    for each_trigram in data_dict['pos_trigrams'][index]:
        if each_trigram not in unique_trigrams_pos:
            unique_trigrams_pos.append(each_trigram)

# %% [markdown]
# ### Number of unique POS tags among all statements

# %% [markdown]
# ##### Unigrams POS

# %%
len(unique_unigrams_pos)
# Out:
# 46

# %% [markdown]
# ##### Bigrams POS

# %%
len(unique_bigrams_pos)
# Out:
# 1163

# %% [markdown]
# ##### Tigrams POS

# %%
len(unique_trigrams_pos)
# Out:
# 10838

# %% [markdown]
# ### Count POS tags grouped by labels

# %%
pos_counts = dict()
pos_counts['false'] = dict()
pos_counts['true'] = dict()
pos_counts['false']['unigrams'] = dict()
pos_counts['false']['bigrams'] = dict()
pos_counts['false']['trigrams'] = dict()
pos_counts['true']['unigrams'] = dict()
pos_counts['true']['bigrams'] = dict()
pos_counts['true']['trigrams'] = dict()

# %%
# initialize all dictionaries
for each_unigram in unique_unigrams_pos:
    pos_counts['true']['unigrams'][each_unigram] = 0
    pos_counts['false']['unigrams'][each_unigram] = 0
for each_bigram in unique_bigrams_pos:
    pos_counts['true']['bigrams'][each_bigram] = 0
    pos_counts['false']['bigrams'][each_bigram] = 0
for each_trigram in unique_trigrams_pos:
    pos_counts['true']['trigrams'][each_trigram] = 0
    pos_counts['false']['trigrams'][each_trigram] = 0

# %%
# count
for index, label in enumerate(data_dict['new_labels']):
    for each_unigram in data_dict['pos'][index]:
        pos_counts[label]['unigrams'][each_unigram] += 1
    for each_bigram in data_dict['pos_bigrams'][index]:
        pos_counts[label]['bigrams'][each_bigram] +=1
    for each_trigram in data_dict['pos_trigrams'][index]:
        pos_counts[label]['trigrams'][each_trigram] +=1

# %%
false_unigram_pairs = list()
elements = pos_counts['false']['unigrams']
for item in elements:
    false_unigram_pairs.append((elements[item], item))

# %%
true_unigram_pairs = list()
elements = pos_counts['true']['unigrams']
for item in elements:
    true_unigram_pairs.append((elements[item], item))

# %% [markdown]
# ### Number of unigram POS tags by label

# %% [markdown]
# #### FALSE

# %%
false_unigram_pairs
# Out:
# [(4945, '<s>'),
#  (3245, 'VBZ'),
#  (6845, 'DT'),
#  (581, 'NNPS'),
#  (1590, 'VBP'),
#  (4710, 'JJ'),
#  (12643, 'NN'),
#  (5503, 'NNS'),
#  (9568, 'IN'),
#  (4788, '.'),
#  (258, 'WRB'),
#  (2786, 'VBD'),
#  (2626, 'VB'),
#  (1901, 'PRP'),
#  (298, 'RP'),
#  (430, 'WDT'),
#  (2145, 'TO'),
#  (447, '-LRB-'),
#  (10031, 'NNP'),
#  (447, '-RRB-'),
#  (227, '``'),
#  (1482, 'VBG'),
#  (233, "''"),
#  (1047, 'PRP$'),
#  (1771, 'VBN'),
#  (127, 'RBR'),
#  (2837, 'CD'),
#  (2403, 'RB'),
#  (266, 'WP'),
#  (2178, ','),
#  (215, 'JJS'),
#  (516, '$'),
#  (1450, 'CC'),
#  (342, 'JJR'),
#  (313, ':'),
#  (72, 'POS'),
#  (775, 'MD'),
#  (33, 'PDT'),
#  (126, 'EX'),
#  (52, 'RBS'),
#  (3, '#'),
#  (4, 'SYM'),
#  (9, 'UH'),
#  (3, 'WP$'),
#  (14, 'FW'),
#  (0, 'LS')]

# %% [markdown]
# #### TRUE

# %%
true_unigram_pairs
# Out:
# [(6509, '<s>'),
#  (4021, 'VBZ'),
#  (9614, 'DT'),
#  (815, 'NNPS'),
#  (2437, 'VBP'),
#  (6696, 'JJ'),
#  (17388, 'NN'),
#  (7822, 'NNS'),
#  (14221, 'IN'),
#  (6341, '.'),
#  (354, 'WRB'),
#  (3496, 'VBD'),
#  (2753, 'VB'),
#  (2496, 'PRP'),
#  (339, 'RP'),
#  (534, 'WDT'),
#  (2337, 'TO'),
#  (610, '-LRB-'),
#  (11021, 'NNP'),
#  (611, '-RRB-'),
#  (274, '``'),
#  (1639, 'VBG'),
#  (282, "''"),
#  (1318, 'PRP$'),
#  (2570, 'VBN'),
#  (263, 'RBR'),
#  (5122, 'CD'),
#  (3495, 'RB'),
#  (332, 'WP'),
#  (3120, ','),
#  (514, 'JJS'),
#  (771, '$'),
#  (2136, 'CC'),
#  (830, 'JJR'),
#  (489, ':'),
#  (103, 'POS'),
#  (838, 'MD'),
#  (58, 'PDT'),
#  (201, 'EX'),
#  (87, 'RBS'),
#  (5, '#'),
#  (5, 'SYM'),
#  (3, 'UH'),
#  (3, 'WP$'),
#  (11, 'FW'),
#  (2, 'LS')]

# %%
dtype = [('count', int), ('name', 'U10')]
ordered_false_unigrams = np.flip(np.sort(np.array(false_unigram_pairs, dtype=dtype),order='count'))

# %%
ordered_false_unigrams
# Out:
# array([(12643, 'NN'), (10031, 'NNP'), ( 9568, 'IN'), ( 6845, 'DT'),
#        ( 5503, 'NNS'), ( 4945, '<s>'), ( 4788, '.'), ( 4710, 'JJ'),
#        ( 3245, 'VBZ'), ( 2837, 'CD'), ( 2786, 'VBD'), ( 2626, 'VB'),
#        ( 2403, 'RB'), ( 2178, ','), ( 2145, 'TO'), ( 1901, 'PRP'),
#        ( 1771, 'VBN'), ( 1590, 'VBP'), ( 1482, 'VBG'), ( 1450, 'CC'),
#        ( 1047, 'PRP$'), (  775, 'MD'), (  581, 'NNPS'), (  516, '$'),
#        (  447, '-RRB-'), (  447, '-LRB-'), (  430, 'WDT'), (  342, 'JJR'),
#        (  313, ':'), (  298, 'RP'), (  266, 'WP'), (  258, 'WRB'),
#        (  233, "''"), (  227, '``'), (  215, 'JJS'), (  127, 'RBR'),
#        (  126, 'EX'), (   72, 'POS'), (   52, 'RBS'), (   33, 'PDT'),
#        (   14, 'FW'), (    9, 'UH'), (    4, 'SYM'), (    3, 'WP$'),
#        (    3, '#'), (    0, 'LS')],
#       dtype=[('count', '<i4'), ('name', '<U10')])

# %%
dtype = [('count', int), ('name','U10')]
ordered_true_unigrams = np.flip(np.sort(np.array(true_unigram_pairs, dtype=dtype),order='count'))

# %%
ordered_true_unigrams
# Out:
# array([(17388, 'NN'), (14221, 'IN'), (11021, 'NNP'), ( 9614, 'DT'),
#        ( 7822, 'NNS'), ( 6696, 'JJ'), ( 6509, '<s>'), ( 6341, '.'),
#        ( 5122, 'CD'), ( 4021, 'VBZ'), ( 3496, 'VBD'), ( 3495, 'RB'),
#        ( 3120, ','), ( 2753, 'VB'), ( 2570, 'VBN'), ( 2496, 'PRP'),
#        ( 2437, 'VBP'), ( 2337, 'TO'), ( 2136, 'CC'), ( 1639, 'VBG'),
#        ( 1318, 'PRP$'), (  838, 'MD'), (  830, 'JJR'), (  815, 'NNPS'),
#        (  771, '$'), (  611, '-RRB-'), (  610, '-LRB-'), (  534, 'WDT'),
#        (  514, 'JJS'), (  489, ':'), (  354, 'WRB'), (  339, 'RP'),
#        (  332, 'WP'), (  282, "''"), (  274, '``'), (  263, 'RBR'),
#        (  201, 'EX'), (  103, 'POS'), (   87, 'RBS'), (   58, 'PDT'),
#        (   11, 'FW'), (    5, 'SYM'), (    5, '#'), (    3, 'WP$'),
#        (    3, 'UH'), (    2, 'LS')],
#       dtype=[('count', '<i4'), ('name', '<U10')])

# %%
y_false_values = list()
y_true_values = list()
x_labels = [x[1] for x in ordered_true_unigrams]
for each_label in x_labels:
    y_false_values.append([x[0] for x in ordered_false_unigrams if x[1]==each_label][0])
    y_true_values.append([x[0] for x in ordered_true_unigrams if x[1]==each_label][0])

# %%
y_false_values = (np.array(y_false_values)*100)/sum(y_false_values)
y_true_values = (np.array(y_true_values)*100)/sum(y_true_values)

# %% [markdown]
# ## Plot POS unigram wise

# %%
width = 0.35  # the width of the bars
ind = np.arange(len(x_labels))
x_labels = [x.replace('b','') for x in x_labels]
fig, ax = plt.subplots(figsize=(20, 10))
rects1 = ax.bar(x_ticks - width/2, y_true_values, width,
                color='SkyBlue', label='True')
rects2 = ax.bar(x_ticks + width/2, y_false_values, width,
                color='IndianRed', label='False')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Counting')
ax.set_title('Counting POS unigram wise by type of news')
ax.set_xticks(ind)
ax.set_xticklabels((x_labels),fontsize=16)
ax.legend()
plt.xticks(rotation=90)
plt.show()
